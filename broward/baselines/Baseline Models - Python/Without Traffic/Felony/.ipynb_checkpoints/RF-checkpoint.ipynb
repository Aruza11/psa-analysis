# %%
import pandas as pd 
import numpy as np
import csv

from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import roc_curve, auc
from sklearn.utils import shuffle

import matplotlib.pyplot as plt
from tabulate import tabulate

# %%
## load data sets
train_pd = pd.read_csv("~/Documents/Duke/Cynthia Research/KY-analysis-mytrials/broward/data/Without Traffic Data/train_recid_F.csv")
test_pd = pd.read_csv("~/Documents/Duke/Cynthia Research/KY-analysis-mytrials/broward//data/Without Traffic Data/test_recid_F.csv")

## get rid of the record with 'p_age_first_offense' == 0
train_pd = train_pd.drop(['person_id', 'screening_date'], axis=1)
test_pd = test_pd.drop(['person_id', 'screening_date'], axis=1)
test_pd = test_pd[test_pd['p_age_first_offense'] != 0]

## split train and test
x_train, y_train = train_pd.values[:, :-1], train_pd.values[:, -1]
x_test, y_test = test_pd.values[:, :-1], test_pd.values[:, -1]

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Cross Validation

# %%
def crossvalidation(X, Y, nfold, depth, N, min_samples_split=2, min_impurity_decrease=0, seed=816):

    """
    
    @parameters:
    - xtrain: training set -- features
    - ytrain: training set -- response variable
    - nfold: n-folds cross validation
    - depth: max split depth
    - N: number of trees
    - min_samples_splits: the minimum number of samples required to split an internal node
    - min_impurity_decrease: a node will be split if that split induced a decrease of the impurity greater
                             than or equal to this value
    - seed: random state
    
    """
    
    ## nfolds cross-validation set up
    #cv = KFold(n_splits=nfold, random_state=seed, shuffle=True)
    cv = StratifiedKFold(n_splits=nfold, random_state=seed, shuffle=True)
    
    ## classifier
    classifier = RandomForestClassifier(max_depth=depth,
                                        n_estimators=N, 
                                        min_impurity_decrease=min_impurity_decrease,
                                        min_samples_split= min_samples_split,
                                        bootstrap=True, 
                                        random_state=seed)
    train_acc, test_acc = [], []
    train_auc, test_auc = [], []

    i = 0
    for train, test in cv.split(X, Y):
    
        ## data & classifier
        X_train, Y_train = X[train], Y[train]
        X_test, Y_test = X[test], Y[test]
        fit_model = classifier.fit(X_train, Y_train)
    
        ## accuracy & probability
        train_acc.append(fit_model.score(X_train, Y_train))
        test_acc.append(fit_model.score(X_test, Y_test))
    
        train_prob = fit_model.predict_proba(X_train)[:,1]
        test_prob = fit_model.predict_proba(X_test)[:,1]
    
        ## compute ROC curve and AUC
    
        train_fpr, train_tpr, train_thresholds = roc_curve(Y_train, train_prob)
        test_fpr, test_tpr, test_thresholds = roc_curve(Y_test, test_prob)
        train_roc_auc = auc(train_fpr, train_tpr)
        test_roc_auc = auc(test_fpr, test_tpr)
    
        train_auc.append(train_roc_auc)
        test_auc.append(test_roc_auc)
        i += 1
    
    return train_acc, test_acc, train_auc, test_auc

# %% [markdown]
# ### Tune Parameters
# -- To prevent overfitting and get as good performance as possible.
#
# -- criteria: difference between the avg. train accuracy and test accuracy and the difference between avg. train auc and avg. test auc are both smaller than 3%.

# %%
Depth = [1,2,3,4,5]
num_estimator = [30, 40, 50, 60, 70, 80, 90, 100]
min_impurity_decrease = [0.007, 0.008, 0.009, 0.011]

# %%
results = []
for d in Depth:
    for n in num_estimator:
        for i in min_impurity_decrease:
            train_acc, test_acc, train_auc, test_auc = crossvalidation(x_train, y_train, 5, depth=d, N=n, min_impurity_decrease=i)
            auc_diff = np.mean(train_auc) - np.mean(test_auc)
            results.append([d, n, i, np.mean(test_auc), auc_diff])

# %%
table = pd.DataFrame(results, columns=['Depth', 'Number of Estimators', 'Min Impurity Decrease', 'Validation AUC', 'AUC Diff'])

# %%
table.sort_values(by = ['Validation AUC', 'AUC Diff'], axis=0, ascending = [False, True])
# Out:
#      Depth  Number of Estimators  Min Impurity Decrease  Validation AUC  \
# 40       2                    50                  0.007        0.621584
# 72       3                    50                  0.007        0.621584
# 104      4                    50                  0.007        0.621584
# 136      5                    50                  0.007        0.621584
# 8        1                    50                  0.007        0.619826
# 60       2                   100                  0.007        0.618026
# 92       3                   100                  0.007        0.617831
# 124      4                   100                  0.007        0.617831
# 156      5                   100                  0.007        0.617831
# 28       1                   100                  0.007        0.617793
# 56       2                    90                  0.007        0.616092
# 52       2                    80                  0.007        0.615894
# 41       2                    50                  0.008        0.615853
# 73       3                    50                  0.008        0.615853
# 105      4                    50                  0.008        0.615853
# 137      5                    50                  0.008        0.615853
# 88       3                    90                  0.007        0.615828
# 120      4                    90                  0.007        0.615828
# 152      5                    90                  0.007        0.615828
# 84       3                    80                  0.007        0.615526
# 116      4                    80                  0.007        0.615526
# 148      5                    80                  0.007        0.615526
# 61       2                   100                  0.008        0.614747
# 93       3                   100                  0.008        0.614747
# 125      4                   100                  0.008        0.614747
# 157      5                   100                  0.008        0.614747
# 48       2                    70                  0.007        0.614747
# 80       3                    70                  0.007        0.614476
# 112      4                    70                  0.007        0.614476
# 144      5                    70                  0.007        0.614476
# ..     ...                   ...                    ...             ...
# 51       2                    70                  0.011        0.597009
# 83       3                    70                  0.011        0.597009
# 115      4                    70                  0.011        0.597009
# 147      5                    70                  0.011        0.597009
# 59       2                    90                  0.011        0.596870
# 91       3                    90                  0.011        0.596870
# 123      4                    90                  0.011        0.596870
# 155      5                    90                  0.011        0.596870
# 19       1                    70                  0.011        0.596870
# 27       1                    90                  0.011        0.596703
# 38       2                    40                  0.009        0.594904
# 70       3                    40                  0.009        0.594904
# 102      4                    40                  0.009        0.594904
# 134      5                    40                  0.009        0.594904
# 15       1                    60                  0.011        0.594807
# 47       2                    60                  0.011        0.594807
# 79       3                    60                  0.011        0.594807
# 111      4                    60                  0.011        0.594807
# 143      5                    60                  0.011        0.594807
# 6        1                    40                  0.009        0.594758
# 7        1                    40                  0.011        0.591681
# 39       2                    40                  0.011        0.591681
# 71       3                    40                  0.011        0.591681
# 103      4                    40                  0.011        0.591681
# 135      5                    40                  0.011        0.591681
# 3        1                    30                  0.011        0.580014
# 35       2                    30                  0.011        0.580014
# 67       3                    30                  0.011        0.580014
# 99       4                    30                  0.011        0.580014
# 131      5                    30                  0.011        0.580014
#
#      AUC Diff
# 40   0.016348
# 72   0.016348
# 104  0.016348
# 136  0.016348
# 8    0.015870
# 60   0.028212
# 92   0.028277
# 124  0.028277
# 156  0.028277
# 28   0.023892
# 56   0.028787
# 52   0.029180
# 41   0.020966
# 73   0.020966
# 105  0.020966
# 137  0.020966
# 88   0.029050
# 120  0.029050
# 152  0.029050
# 84   0.029554
# 116  0.029554
# 148  0.029554
# 61   0.028277
# 93   0.028277
# 125  0.028277
# 157  0.028277
# 48   0.028081
# 80   0.028369
# 112  0.028369
# 144  0.028369
# ..        ...
# 51   0.035823
# 83   0.035823
# 115  0.035823
# 147  0.035823
# 59   0.035704
# 91   0.035704
# 123  0.035704
# 155  0.035704
# 19   0.035875
# 27   0.035769
# 38   0.040682
# 70   0.040682
# 102  0.040682
# 134  0.040682
# 15   0.036395
# 47   0.036395
# 79   0.036395
# 111  0.036395
# 143  0.036395
# 6    0.040492
# 7    0.039228
# 39   0.039228
# 71   0.039228
# 103  0.039228
# 135  0.039228
# 3    0.031043
# 35   0.031043
# 67   0.031043
# 99   0.031043
# 131  0.031043
#
# [160 rows x 5 columns]

# %% [markdown]
# ### Best Parameters:
# - depth: 2 / estimators: 50 / impurity decrease: 0.007

# %%
train_acc, test_acc, train_auc, test_auc = crossvalidation(x_train, y_train, 5, depth=2, N=50, min_impurity_decrease=0.007)

# %%
np.mean(train_acc), np.mean(test_acc), np.mean(train_auc), np.mean(test_auc)
# Out:
# (0.8208572981614708, 0.8208568853936266, 0.6379320066299581, 0.621583904035228)

# %% [markdown]
# #### Heldout Test Set
# -- use 0.5 as threshold

# %%
rf = RandomForestClassifier(max_depth=2, n_estimators=50, min_impurity_decrease=0.007, bootstrap=True, random_state=816).fit(x_train, y_train)
heldout_test_acc = rf.score(x_test, y_test)
heldout_test_acc
# Out:
# 0.8387096774193549

# %%
prob = rf.predict_proba(x_test)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, prob)
heldout_test_auc = auc(fpr, tpr)
heldout_test_auc
# Out:
# 0.6910790598290597

# %% [markdown]
# -- use optimal threshold

# %% [markdown]
# #optimal_index = np.argmin(np.sqrt(np.square(1-tpr) + np.square(fpr)))
# optimal_index = np.argmax(abs(tpr - fpr))
# optimal_threshold = thresholds[optimal_index]
# optimal_threshold

# %% [markdown]
# prediction = rf.predict_proba(x_test)[:,1]
# heldout_test_acc = np.mean((prediction > optimal_threshold) == y_test)
# heldout_test_acc

# %% [markdown]
# #### Log Results

# %%
#log model results to the model performance folder, as per standards
path = "C:\\Users\\binha\\Documents\\Duke\\Cynthia Research\\KY-analysis-mytrials\\broward\\broward models\\Baseline Model Results\\Without Traffic\\Felony\\"

train_auc_mean, train_auc_std = np.mean(train_auc), np.std(train_auc)
test_auc_mean, test_auc_std = np.mean(test_auc), np.std(test_auc)
                   
results = ["RF", train_auc_mean, train_auc_std, test_auc_mean, test_auc_std, heldout_test_auc, heldout_test_acc ]

with open(path + 'Felony Summary.csv', 'a') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerow(results)
