# %%
import pandas as pd 
import numpy as np
import csv

from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import roc_curve, auc
from sklearn.utils import shuffle

import matplotlib.pyplot as plt
from tabulate import tabulate

# %%
## load data sets
train_pd = pd.read_csv("~/Documents/Duke/Cynthia Research/KY-analysis-mytrials/broward/data/Without Traffic Data/train_recid_F.csv")
test_pd = pd.read_csv("~/Documents/Duke/Cynthia Research/KY-analysis-mytrials/broward//data/Without Traffic Data/test_recid_F.csv")

## get rid of the record with 'p_age_first_offense' == 0
train_pd = train_pd.drop(['person_id', 'screening_date'], axis=1)
test_pd = test_pd.drop(['person_id', 'screening_date'], axis=1)
test_pd = test_pd[test_pd['p_age_first_offense'] != 0]

## split train and test
x_train, y_train = train_pd.values[:, :-1], train_pd.values[:, -1]
x_test, y_test = test_pd.values[:, :-1], test_pd.values[:, -1]

# %% [markdown]
# ### CART

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### Cross Validation

# %%
def crossvalidation(X, Y, nfold, depth, min_sample_split=2, min_impurity_decrease=0, seed = 816):
    
    """
    
    @parameters:
    - X: training set -- features
    - Y: training set -- response variable
    - nfold: n-folds cross validation
    - depth: max split depth
    - min_sample_split
    - min_impurity_decrease
    - seed: random state
    
    """
    
    
    ## n-folds cross validation set up
    #cv = KFold(n_splits=nfold, random_state=seed, shuffle=True)
    cv = StratifiedKFold(n_splits=nfold, random_state=seed, shuffle=True)
    
    ## classifier: logistic regression
    classifier = DecisionTreeClassifier(max_depth=depth, min_samples_split= min_sample_split, 
                                        min_impurity_decrease=min_impurity_decrease, random_state=seed)
    train_acc, test_acc = [], []
    train_auc, test_auc = [], []

    i = 0
    for train, test in cv.split(X, Y):
    
        ## data & classifier
        X_train, Y_train = X[train], Y[train]
        X_test, Y_test = X[test], Y[test]
        fit_model = classifier.fit(X_train, Y_train)
    
        ## accuracy & probability
        train_acc.append(fit_model.score(X_train, Y_train))
        test_acc.append(fit_model.score(X_test, Y_test))
    
        train_prob = fit_model.predict_proba(X_train)[:,1]
        test_prob = fit_model.predict_proba(X_test)[:,1]
    
        ## compute AUC
    
        train_fpr, train_tpr, train_thresholds = roc_curve(Y_train, train_prob)
        test_fpr, test_tpr, test_thresholds = roc_curve(Y_test, test_prob)    
        train_auc.append(auc(train_fpr, train_tpr))
        test_auc.append(auc(test_fpr, test_tpr))
        i += 1

    return train_acc, test_acc, train_auc, test_auc

# %% [markdown]
# ### Tune Parameters
# -- To prevent overfitting and get as good performance as possible.
#
# -- criteria: difference between the avg. train accuracy and test accuracy and the difference between avg. train auc and avg. test auc are both smaller than 3%.

# %%
DEPTH = [1,2]
IMPURITY = [0, 0.001, 0.003, 0.005, 0.007, 0.009, 0.011]
SPLIT = [2,3,4,5,6,7,8,9]

# %%
results = []

for d in DEPTH:
    for i in IMPURITY:
        for s in SPLIT:
            train_acc, test_acc, train_auc, test_auc = crossvalidation(x_train, y_train, 5, depth=d, min_impurity_decrease=i, min_sample_split=s)
            auc_diff = np.mean(train_auc) - np.mean(test_auc)
            results.append([d, i, s, np.mean(test_auc), auc_diff])

# %%
table = pd.DataFrame(results, columns=['Depth', 'Impurity Decrease','Min Split', 'Validation AUC', 'AUC Diff'])

# %%
table = table[table['AUC Diff'] <= 0.025]

# %%
table.sort_values(by = 'Validation AUC', axis=0, ascending =False)
# Out:
#      Depth  Impurity Decrease  Min Split  Validation AUC  AUC Diff
# 0        1              0.000          2        0.558866  0.020179
# 28       1              0.005          6        0.558866  0.020179
# 30       1              0.005          8        0.558866  0.020179
# 31       1              0.005          9        0.558866  0.020179
# 88       2              0.007          2        0.558866  0.020179
# 33       1              0.007          3        0.558866  0.020179
# 34       1              0.007          4        0.558866  0.020179
# 35       1              0.007          5        0.558866  0.020179
# 36       1              0.007          6        0.558866  0.020179
# 37       1              0.007          7        0.558866  0.020179
# 38       1              0.007          8        0.558866  0.020179
# 39       1              0.007          9        0.558866  0.020179
# 1        1              0.000          3        0.558866  0.020179
# 95       2              0.007          9        0.558866  0.020179
# 94       2              0.007          8        0.558866  0.020179
# 93       2              0.007          7        0.558866  0.020179
# 92       2              0.007          6        0.558866  0.020179
# 91       2              0.007          5        0.558866  0.020179
# 90       2              0.007          4        0.558866  0.020179
# 89       2              0.007          3        0.558866  0.020179
# 80       2              0.005          2        0.558866  0.020179
# 81       2              0.005          3        0.558866  0.020179
# 82       2              0.005          4        0.558866  0.020179
# 83       2              0.005          5        0.558866  0.020179
# 84       2              0.005          6        0.558866  0.020179
# 85       2              0.005          7        0.558866  0.020179
# 86       2              0.005          8        0.558866  0.020179
# 29       1              0.005          7        0.558866  0.020179
# 32       1              0.007          2        0.558866  0.020179
# 27       1              0.005          5        0.558866  0.020179
# ..     ...                ...        ...             ...       ...
# 103      2              0.009          9        0.532434  0.021623
# 102      2              0.009          8        0.532434  0.021623
# 101      2              0.009          7        0.532434  0.021623
# 100      2              0.009          6        0.532434  0.021623
# 96       2              0.009          2        0.532434  0.021623
# 98       2              0.009          4        0.532434  0.021623
# 44       1              0.009          6        0.532434  0.021623
# 43       1              0.009          5        0.532434  0.021623
# 40       1              0.009          2        0.532434  0.021623
# 47       1              0.009          9        0.532434  0.021623
# 46       1              0.009          8        0.532434  0.021623
# 45       1              0.009          7        0.532434  0.021623
# 42       1              0.009          4        0.532434  0.021623
# 41       1              0.009          3        0.532434  0.021623
# 110      2              0.011          8        0.506504  0.010073
# 109      2              0.011          7        0.506504  0.010073
# 108      2              0.011          6        0.506504  0.010073
# 107      2              0.011          5        0.506504  0.010073
# 106      2              0.011          4        0.506504  0.010073
# 105      2              0.011          3        0.506504  0.010073
# 104      2              0.011          2        0.506504  0.010073
# 55       1              0.011          9        0.506504  0.010073
# 54       1              0.011          8        0.506504  0.010073
# 48       1              0.011          2        0.506504  0.010073
# 49       1              0.011          3        0.506504  0.010073
# 50       1              0.011          4        0.506504  0.010073
# 51       1              0.011          5        0.506504  0.010073
# 52       1              0.011          6        0.506504  0.010073
# 53       1              0.011          7        0.506504  0.010073
# 111      2              0.011          9        0.506504  0.010073
#
# [88 rows x 5 columns]

# %% [markdown]
# ### Best Parameter
# depth: 1 / Impurity Decrease: 0.000 / Min Split: 2

# %%
train_acc, test_acc, train_auc, test_auc = crossvalidation(x_train, y_train, 5, depth=1, min_impurity_decrease=0.00, min_sample_split=2)

# %%
np.mean(train_acc), np.mean(test_acc), np.mean(train_auc), np.mean(test_auc)
# Out:
# (0.8208572981614708,
#  0.8208568853936266,
#  0.5790449656476472,
#  0.5588660366870484)

# %% [markdown]
# #### Heldout Test Set
# -- using 0.5 as threshold

# %%
cart = DecisionTreeClassifier(max_depth=1, min_samples_split=2, min_impurity_decrease=0.000, random_state=816).fit(x_train, y_train)
heldout_test_acc = cart.score(x_test, y_test)
heldout_test_acc
# Out:
# 0.8387096774193549

# %%
prob = cart.predict_proba(x_test)[:,1]
fpr,tpr,thresholds = roc_curve(y_test, prob)
heldout_test_auc = auc(fpr, tpr)
heldout_test_auc
# Out:
# 0.5932692307692307

# %% [markdown]
# -- using optimal threshold

# %% [markdown]
# #optimal_index = np.argmin(np.sqrt(np.square(1-tpr) + np.square(fpr)))
# optimal_index = np.argmax(abs(tpr - fpr))
# optimal_threshold = thresholds[optimal_index]
# optimal_threshold

# %% [markdown]
# prediction = cart.predict_proba(x_test)[:,1]
# heldout_test_acc = np.mean((prediction > optimal_threshold) == y_test)
# heldout_test_acc

# %% [markdown]
# #### Log Results

# %%
#log model results to the model performance folder, as per standards
path = "C:\\Users\\binha\\Documents\\Duke\\Cynthia Research\\KY-analysis-mytrials\\broward\\broward models\\Baseline Model Results\\Without Traffic\\Felony\\"

train_auc_mean, train_auc_std = np.mean(train_auc), np.std(train_auc)
test_auc_mean, test_auc_std = np.mean(test_auc), np.std(test_auc)
                   
results = ["CART", train_auc_mean, train_auc_std, test_auc_mean, test_auc_std, heldout_test_auc, heldout_test_acc ]

with open(path + 'Felony Summary.csv', 'a') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerow(results)
