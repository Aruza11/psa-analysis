# %%
import os 
os.chdir('../../../../')
print("Current working directory is now: ", os.getcwd())

import pandas as pd 
import numpy as np
import csv
import utils.baseline_functions as base
import stumps
import RiskSLIM as slim

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.metrics import roc_auc_score

# restore saved variables
# %store -r summary_drug2_broward_interpret
# Out:
# Current working directory is now:  C:\Users\binha\Documents\Duke\Cynthia Research\psa-analysis - test
# no stored variable summary_drug2_broward_interpret
# C:\Users\binha\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning:
#
# The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).

# %% [markdown]
# ### CART & EBM

# %%
data = pd.read_csv("~/Documents/Duke/Cynthia Research/KY-analysis-mytrials/broward/data/broward_data.csv")
x = data.loc[:,:'five_year']
y = data['recid_drug2'].values

# %%
#### CART
depth = [1,2]
impurity = [0.001, 0.003]
split = [2,3,4]
cart_summary = base.CART(X=x,
                         Y=y,
                         depth=depth,
                         split=split,
                         impurity=impurity, 
                         seed = 816)

#### EBM
estimators = [60, 80, 100]
depth = [1]
learning_rate = [0.05]
holdout_split = [0.9]
ebm_summary = base.EBM(X=x,
                       Y=y,
                       learning_rate = learning_rate,
                       depth = depth,
                       estimators=estimators,
                       holdout_split=holdout_split,
                       seed=816)
# Out:
# model_id, score_thresholds 0 {'rank_abs': [0]}
# get_disparity_predefined_group()
# model_id, score_thresholds 0 {'rank_abs': [3]}
# get_disparity_predefined_group()
# model_id, score_thresholds 0 {'rank_abs': [1]}
# get_disparity_predefined_group()
# model_id, score_thresholds 0 {'rank_abs': [0]}
# get_disparity_predefined_group()
# model_id, score_thresholds 0 {'rank_abs': [0]}
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# get_disparity_predefined_group()
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# model_id, score_thresholds 0 {'rank_abs': [0]}
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# get_disparity_predefined_group()
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# model_id, score_thresholds 0 {'rank_abs': [0]}
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# get_disparity_predefined_group()
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# model_id, score_thresholds 0 {'rank_abs': [0]}
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# get_disparity_predefined_group()
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# model_id, score_thresholds 0 {'rank_abs': [0]}
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# get_disparity_predefined_group()
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# WARNING:interpret.utils.all:Passing a numpy array to schema autogen when it should be dataframe.
# model_id, score_thresholds 0 {'rank_abs': [0]}
# get_disparity_predefined_group()

# %%
np.mean(cart_summary['holdout_test_auc']), np.mean(cart_summary['auc_diffs'])
# Out:
# (0.6362388977391955, 0.03216264372495723)

# %%
np.mean(ebm_summary['holdout_test_auc']), np.mean(ebm_summary['auc_diffs'])
# Out:
# (0.6669158292052909, 0.07706052267336123)

# %% [markdown]
# ## Lasso Stumps

# %%
## load whole data
data = pd.read_csv("~/Documents/Duke/Cynthia Research/KY-analysis-mytrials/broward/data/broward_stumps.csv")
X_stumps, Y_stumps = data.loc[:,:'five_year>=1'], data['recid_drug2'].values
Y_stumps[Y_stumps == -1] = 0
cols = X_stumps.columns[3:]

## load train & test data
train_stumps = pd.read_csv("~/Documents/Duke/Cynthia Research/KY-analysis-mytrials/broward/data/broward_train_stumps.csv")
test_stumps = pd.read_csv("~/Documents/Duke/Cynthia Research/KY-analysis-mytrials/broward/data/broward_test_stumps.csv")

X_train_stumps, Y_train_stumps = train_stumps.loc[:,:'five_year>=1'], train_stumps['recid_drug2'].values
X_test_stumps, Y_test_stumps = test_stumps.loc[:,:'five_year>=1'], test_stumps['recid_drug2'].values

Y_train_stumps[Y_train_stumps == -1] = 0
Y_test_stumps[Y_test_stumps == -1] = 0

# %% [markdown]
# #### Nested Cross Validation

# %%
stump_summary = stumps.stump_cv(X = X_stumps, 
                                Y = Y_stumps, 
                                columns=cols, 
                                c_grid={'C': [0.03]}, 
                                seed = 816)
# Out:
# model_id, score_thresholds 0 {'rank_abs': [175]}
# get_disparity_predefined_group()
# model_id, score_thresholds 0 {'rank_abs': [161]}
# get_disparity_predefined_group()
# model_id, score_thresholds 0 {'rank_abs': [180]}
# get_disparity_predefined_group()
# model_id, score_thresholds 0 {'rank_abs': [157]}
# get_disparity_predefined_group()
# model_id, score_thresholds 0 {'rank_abs': [189]}
# get_disparity_predefined_group()

# %%
stump_summary['best_params'], np.mean(stump_summary['holdout_test_auc']), np.mean(stump_summary['auc_diffs'])
# Out:
# ([{'C': 0.03}, {'C': 0.03}, {'C': 0.03}, {'C': 0.03}, {'C': 0.03}],
#  0.7037541278059203,
#  0.041201733308695546)

# %% [markdown]
# ##### Best Stump Model
# - alpha = 0.05 (alpha = 0.1 gives better results, but too many features)

# %%
best_stump_model = stumps.stump_model(X_train_stumps, Y_train_stumps, 
                                      X_test_stumps, Y_test_stumps, 
                                      c=0.03, columns=cols, seed=816)

# %% [markdown]
# ##### Prediction Table

# %%
stumps.stump_table(best_stump_model['coefs'], 
                   best_stump_model['features'], 
                   best_stump_model['intercept'], 
                   best_stump_model['dictionary'])
# Out:
# +-----------------------------------+----------------+
# | Features                          | Score          |
# |====================================================|
# | p_current_age>=23                 | -37.9          |
# | p_current_age>=29                 | -13.7          |
# | p_current_age>=37                 | -19.4          |
# | prior_conviction_M>=1             | -3.9           |
# | p_drug>=1                         | 47.2           |
# | p_drug>=2                         | 24.4           |
# | p_drug>=4                         | 16.6           |
# | years_since_last_crime>=1         | -5.6           |
# | Intercept                         | 0.0            |
# |====================================================|
# | ADD POINTS FROM ROWS 1 TO 8      | Total Score    |
# +-----------------------------------+----------------+

# %% [markdown]
# ##### Stumps Visualization

# %%
stumps.stump_plots(best_stump_model['features'], best_stump_model['coefs'])

# %% [markdown]
# ## RiskSLIM

# %%
## load stumps data
data = pd.read_csv("~/Documents/Duke/Cynthia Research/KY-analysis-mytrials/broward/data/broward_stumps.csv")
x, y = data.loc[:,:'five_year>=1'], data['recid_drug2'].values
cols = x.columns[3:]

# %%
## train on best param chosen by Lasso Stumps from above
x_train = x.copy().drop(['race', 'person_id', 'screening_date'], axis=1)
lasso = LogisticRegression(class_weight='balanced', solver='liblinear', penalty='l1', C=0.05, random_state=816).fit(x_train,y)
selected_features = cols[lasso.coef_[0] != 0].tolist()
len(selected_features)
# Out:
# 21

# %%
### Subset features
if 'sex' in selected_features:
    selected_features = ['recid_drug2', 'person_id', 'screening_date', 'race'] + selected_features
    indicator = 1
else:
    selected_features = ['recid_drug2', 'person_id', 'screening_date', 'race', 'sex'] + selected_features
    indicator = 0

sub_data = data[selected_features]
sub_X, sub_Y = sub_data.iloc[:,1:], sub_data.iloc[:,0].values
sub_X.insert(0, '(Intercept)', 1)

# %%
riskslim_summary = slim.risk_cv(X=sub_X, 
                                Y=sub_Y, 
                                indicator = indicator,
                                y_label='recid_drug2', 
                                max_coef=20, 
                                max_coef_number=10, 
                                max_runtime=200, 
                                c=1e-6, 
                                seed=816)
# Out:
# setting c0 = 0.0 to ensure that intercept is not penalized
# 09/10/19 @ 10:01 AM | switching loss computation from lookup to weighted
# 09/10/19 @ 10:01 AM | ------------------------------------------------------------
# 09/10/19 @ 10:01 AM | runnning initialization procedure
# 09/10/19 @ 10:01 AM | ------------------------------------------------------------
# 09/10/19 @ 10:01 AM | CPA produced 2 cuts
# 09/10/19 @ 10:01 AM | running naive rounding on 76 solutions
# 09/10/19 @ 10:01 AM | best objective value: 0.2781
# 09/10/19 @ 10:01 AM | rounding produced 2 integer solutions
# 09/10/19 @ 10:01 AM | best objective value is 0.2867
# 09/10/19 @ 10:01 AM | running sequential rounding on 76 solutions
# 09/10/19 @ 10:01 AM | best objective value: 0.2781
# 09/10/19 @ 10:01 AM | sequential rounding produced 1 integer solutions
# 09/10/19 @ 10:01 AM | best objective value: 0.2867
# 09/10/19 @ 10:01 AM | polishing 3 solutions
# 09/10/19 @ 10:01 AM | best objective value: 0.2867
# 09/10/19 @ 10:01 AM | polishing produced 2 integer solutions
# 09/10/19 @ 10:01 AM | initialization produced 2 feasible solutions
# 09/10/19 @ 10:01 AM | best objective value: 0.2867
# 09/10/19 @ 10:01 AM | ------------------------------------------------------------
# 09/10/19 @ 10:01 AM | completed initialization procedure
# 09/10/19 @ 10:01 AM | ------------------------------------------------------------
# 09/10/19 @ 10:01 AM | switching loss computation from lookup to weighted
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.27809161524915355
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.28670225630548768
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 09/10/19 @ 10:01 AM | adding 75 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.2867.
# Tried aggregator 1 time.
# Reduced MIP has 23 rows, 46 columns, and 87 nonzeros.
# Reduced MIP has 21 binaries, 23 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.05 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.2867        0.2781             3.01%
#       0     0        0.2781     1        0.2867        0.2781        1    3.00%
#       0     0        0.2781     1        0.2867      Fract: 1        2    3.00%
#       0     2        0.2781     5        0.2867        0.2781        2    3.00%                        0             0
# Elapsed time = 0.06 sec. (1.08 ticks, tree = 0.01 MB, solutions = 1)
#    6574  2151        0.2815     6        0.2867        0.2781    20141    3.00%          rho_15 D   6574   6573     55
#   11682  3610        0.2849     1        0.2867        0.2781    36122    3.00%           rho_0 U  11682  11681     52
#   16445  5172        0.2781     1        0.2867        0.2781    50292    3.00%           rho_8 U  16445  16443     79
#   20862  6531        0.2807     5        0.2867        0.2781    63882    3.00%          rho_16 D  20862  20492     62
#   25327  7939        0.2807     5        0.2867        0.2781    77178    3.00%          rho_16 D  25327  24092     56
#   29393  9219        0.2832     6        0.2867        0.2781    89324    3.00%          rho_11 D  29393  29390     72
#   33640 10721        0.2781     1        0.2867        0.2781   101909    3.00%           rho_8 U  33640  33638     75
#   37374 11858        0.2829     5        0.2867        0.2781   113619    3.00%          rho_15 D  37374  37373     75
#   41143 13048        0.2821     4        0.2867        0.2781   125131    3.00%          rho_16 D  41143  41142     90
#   57346 18081        0.2849     3        0.2867        0.2781   174511    3.00%           rho_0 U  57346  56094     40
# Elapsed time = 4.03 sec. (3101.04 ticks, tree = 4.97 MB, solutions = 1)
#   73866 23320        0.2781     1        0.2867        0.2781   224638    3.00%           rho_0 D  73866  73805     33
#  1545718 271995        0.2808     1        0.2825        0.2786  5197830    1.40%          rho_16 D 1545718 1005746     70
#  1565111 267715        cutoff              0.2825        0.2789  5249629    1.27%          rho_18 U 1565111 1565110     37
#  1584230 268205        cutoff              0.2825        0.2789  5303352    1.27%          rho_18 U 1584230 1584229     89
#  1603736 269038        0.2811     4        0.2825        0.2789  5357442    1.27%          rho_12 D 1603736 1603734     80
#  1625000 276000        0.2806     4        0.2825        0.2789  5397089    1.27%           rho_8 D 1625000 1624998     82
#  1708556 297224        0.2792     8        0.2825        0.2790  5566972    1.26%          rho_19 U 1708556 1561964     40
# Elapsed time = 95.42 sec. (91579.19 ticks, tree = 76.26 MB, solutions = 7)
#  1780133 284866        0.2799     5        0.2825        0.2790  5809177    1.23%          rho_15 D 1780133 1780132     37
#  1846716 251985        0.2793     1        0.2825        0.2793  6017978    1.15%           rho_8 U 1846716 1846715     73
#  1904251 246223        0.2802     3        0.2825        0.2793  6114614    1.15%           rho_1 N 1904251 1904250     31
#  1968940 221098        0.2802     5        0.2825        0.2796  6331087    1.04%          rho_11 N 1968940 1181649     67
#  2035594 184425        cutoff              0.2825        0.2798  6525402    0.97%          rho_12 U 2035594 524954     50
#  2127378 147607        cutoff              0.2825        0.2802  6700716    0.83%          rho_19 U 2127378 1709744     56
#  2211559 129928        cutoff              0.2825        0.2805  6899949    0.73%          rho_11 U 2211559 996727     56
#  2282865 103686        0.2806     5        0.2825        0.2806  7050391    0.68%           rho_0 D 2282865 2282863     81
#  2351488 46337        cutoff              0.2825        0.2814  7235418    0.39%          rho_16 D 2351488 1308157     54
#  2430343  3397        0.2820     5        0.2825        0.2820  7377248    0.18%           rho_0 D 2430343 2430342     60
# Elapsed time = 128.88 sec. (129726.40 ticks, tree = 18.31 MB, solutions = 7)
#
# Gomory fractional cuts applied:  1
# User cuts applied:  53
#
# Root node processing (before b&c):
#   Real time             =    0.05 sec. (1.09 ticks)
# Sequential b&c:
#   Real time             =  130.06 sec. (131248.76 ticks)
#                           ------------
# Total (root+branch&cut) =  130.11 sec. (131249.85 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_age_first_offense<=21                      |         1 points |   + ..... |
# | p_drug>=1                                    |         1 points |   + ..... |
# | p_drug>=4                                    |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# model_id, score_thresholds 0 {'rank_abs': [0]}
# get_disparity_predefined_group()
# setting c0 = 0.0 to ensure that intercept is not penalized
# 09/10/19 @ 10:03 AM | switching loss computation from lookup to weighted
# 09/10/19 @ 10:03 AM | ------------------------------------------------------------
# 09/10/19 @ 10:03 AM | runnning initialization procedure
# 09/10/19 @ 10:03 AM | ------------------------------------------------------------
# 09/10/19 @ 10:03 AM | CPA produced 2 cuts
# 09/10/19 @ 10:03 AM | running naive rounding on 87 solutions
# 09/10/19 @ 10:03 AM | best objective value: 0.2859
# 09/10/19 @ 10:03 AM | rounding produced 1 integer solutions
# 09/10/19 @ 10:03 AM | best objective value is 0.2958
# 09/10/19 @ 10:03 AM | running sequential rounding on 87 solutions
# 09/10/19 @ 10:03 AM | best objective value: 0.2859
# 09/10/19 @ 10:03 AM | sequential rounding produced 1 integer solutions
# 09/10/19 @ 10:03 AM | best objective value: 0.2934
# 09/10/19 @ 10:03 AM | polishing 2 solutions
# 09/10/19 @ 10:03 AM | best objective value: 0.2934
# 09/10/19 @ 10:03 AM | polishing produced 2 integer solutions
# 09/10/19 @ 10:03 AM | initialization produced 2 feasible solutions
# 09/10/19 @ 10:03 AM | best objective value: 0.2934
# 09/10/19 @ 10:03 AM | ------------------------------------------------------------
# 09/10/19 @ 10:03 AM | completed initialization procedure
# 09/10/19 @ 10:03 AM | ------------------------------------------------------------
# 09/10/19 @ 10:03 AM | switching loss computation from lookup to weighted
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.28592452147533381
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.29341632147554542
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 09/10/19 @ 10:03 AM | adding 86 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.2934.
# Tried aggregator 1 time.
# Reduced MIP has 23 rows, 46 columns, and 87 nonzeros.
# Reduced MIP has 21 binaries, 23 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.05 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.2934        0.2859             2.56%
#       0     0        0.2859     1        0.2934        0.2859        1    2.55%
#       0     2        0.2859     2        0.2934        0.2859        1    2.55%                        0             0
# Elapsed time = 0.05 sec. (0.87 ticks, tree = 0.01 MB, solutions = 1)
# *   390+  108                            0.2919        0.2859             2.04%
#    6164   232        0.2895     1        0.2919        0.2859    18248    2.04%           rho_8 U   6164   6162     35
# *  8000+  240                            0.2919        0.2859             2.04%
#   11230   347        0.2897     3        0.2919        0.2859    33013    2.04%          rho_21 D  11230  11229     58
#   15950   473        0.2859     1        0.2919        0.2859    47317    2.04%           rho_8 U  15950  15949    110
#   20252   427        0.2895     4        0.2919        0.2859    60154    2.04%           rho_8 N  20252  20159     94
#   24578   413        0.2897     3        0.2919        0.2859    72460    2.04%          rho_21 D  24578  24577     98
#   28634   401        0.2859     1        0.2919        0.2859    84153    2.04%           rho_8 U  28634  28631     71
#   32579   405        0.2897     5        0.2919        0.2859    96068    2.04%          rho_21 D  32579  32578     54
# * 35000+  425                            0.2919        0.2859             2.04%
# * 36000+  401                            0.2919        0.2859             2.04%
#   36703   487        0.2859     1        0.2919        0.2859   107725    2.04%           rho_0 D  36703  36702    102
# * 40000+  546                            0.2919        0.2859             2.04%
#   41227   539        0.2859     1        0.2919        0.2859   120843    2.04%           rho_8 U  41227  41220     77
# * 53423   445      integral     0        0.2890        0.2859   155784    1.07%          rho_13 D  53423  53422     10
# Elapsed time = 3.73 sec. (2741.72 ticks, tree = 0.12 MB, solutions = 7)
#   71036  1279        cutoff              0.2890        0.2859   206759    1.07%          rho_16 D  71036  71035     84
#   87742  2430        0.2871     5        0.2890        0.2859   257855    1.07%           rho_0 D  87742  87741    100
#  113379  4834        cutoff              0.2890        0.2859   331245    1.07%           rho_8 D 113379 113377    105
#  138541  6596        0.2866     5        0.2890        0.2859   412265    1.07%           rho_8 D 138541 138540     91
#  156984  7166        0.2859     1        0.2890        0.2859   489751    1.07%           rho_8 U 156984 156980     47
#  176010  7042        0.2859     4        0.2890        0.2859   568731    1.07%           rho_0 D 176010 176009     89
#  198490  7086        0.2859     5        0.2890        0.2859   657776    1.07%           rho_0 D 198490 198489     60
#  217867  7310        0.2890     4        0.2890        0.2859   743644    1.07%           rho_2 D 217867 217865     56
#  811640 26531        0.2874     6        0.2890        0.2874  2489669    0.56%           rho_0 D 811640 811638     34
#  828704 26965        0.2874     6        0.2890        0.2874  2517992    0.56%           rho_0 D 828704 828702     84
#  848559 20379        0.2877     4        0.2890        0.2877  2552613    0.45%           rho_8 U 848559 848558     78
# *863000+20532                            0.2890        0.2877             0.45%
#  877563 15404        cutoff              0.2890        0.2877  2619111    0.44%          rho_16 U 877563 561140     92
# Elapsed time = 43.31 sec. (40889.98 ticks, tree = 4.35 MB, solutions = 10)
#  895321 13074        0.2878     5        0.2890        0.2878  2655450    0.42%           rho_0 D 895321 895319     62
#  911082 13647        cutoff              0.2890        0.2878  2676114    0.42%           rho_0 U 911082 911081     72
#  941230 13985        0.2878     4        0.2890        0.2878  2709256    0.42%          rho_15 D 941230 941229     93
#  973126 13658        0.2885     3        0.2890        0.2879  2752810    0.38%           rho_8 D 973126 973125     85
#  1001721 12754        cutoff              0.2890        0.2879  2798974    0.38%          rho_21 U 1001721 130789     71
#  1025458 12205        0.2879     4        0.2890        0.2879  2838102    0.38%           rho_8 U 1025458 1025455     47
#  1053306 11893        0.2881     2        0.2890        0.2881  2879751    0.33%           rho_8 U 1053306 1053304     96
#  1080163 11947        cutoff              0.2890        0.2881  2913849    0.32%           rho_0 U 1080163 1080162     71
#  1094705 12599        cutoff              0.2890        0.2881  2939522    0.32%           rho_8 D 1094705 1094704     76
#  1114155 13013        0.2881     1        0.2890        0.2881  2967107    0.32%           rho_8 U 1114155 1114154    101
# Elapsed time = 58.08 sec. (50427.02 ticks, tree = 3.89 MB, solutions = 10)
# *1116000+12990                            0.2890        0.2881             0.32%
#  1145402 13068        0.2881     4        0.2890        0.2881  3022787    0.30%           rho_8 U 1145402 1145400     94
#  1188793 12877        0.2883     4        0.2890        0.2883  3079061    0.26%           rho_8 U 1188793 1188792     72
#  1218900  1309        0.2888     1        0.2890        0.2888  3120167    0.08%           rho_0 D 1218900 1218899     42
#
# User cuts applied:  45
#
# Root node processing (before b&c):
#   Real time             =    0.05 sec. (0.87 ticks)
# Sequential b&c:
#   Real time             =   61.58 sec. (53488.31 ticks)
#                           ------------
# Total (root+branch&cut) =   61.63 sec. (53489.18 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_age_first_offense<=21                      |         1 points |   + ..... |
# | p_drug>=1                                    |         1 points |   + ..... |
# | p_drug>=4                                    |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# model_id, score_thresholds 0 {'rank_abs': [0]}
# get_disparity_predefined_group()
# setting c0 = 0.0 to ensure that intercept is not penalized
# 09/10/19 @ 10:04 AM | 941 rows in lookup table
# 09/10/19 @ 10:04 AM | ------------------------------------------------------------
# 09/10/19 @ 10:04 AM | runnning initialization procedure
# 09/10/19 @ 10:04 AM | ------------------------------------------------------------
# 09/10/19 @ 10:04 AM | CPA produced 2 cuts
# 09/10/19 @ 10:04 AM | running naive rounding on 76 solutions
# 09/10/19 @ 10:04 AM | best objective value: 0.2776
# 09/10/19 @ 10:04 AM | rounding produced 2 integer solutions
# 09/10/19 @ 10:04 AM | best objective value is 0.2817
# 09/10/19 @ 10:04 AM | running sequential rounding on 76 solutions
# 09/10/19 @ 10:04 AM | best objective value: 0.2776
# 09/10/19 @ 10:04 AM | sequential rounding produced 1 integer solutions
# 09/10/19 @ 10:04 AM | best objective value: 0.2817
# 09/10/19 @ 10:04 AM | polishing 3 solutions
# 09/10/19 @ 10:04 AM | best objective value: 0.2817
# 09/10/19 @ 10:04 AM | polishing produced 2 integer solutions
# 09/10/19 @ 10:04 AM | initialization produced 2 feasible solutions
# 09/10/19 @ 10:04 AM | best objective value: 0.2817
# 09/10/19 @ 10:04 AM | ------------------------------------------------------------
# 09/10/19 @ 10:04 AM | completed initialization procedure
# 09/10/19 @ 10:04 AM | ------------------------------------------------------------
# 09/10/19 @ 10:04 AM | 941 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.27754996981013486
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.28168360385281593
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 09/10/19 @ 10:04 AM | adding 75 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.2817.
# Tried aggregator 1 time.
# Reduced MIP has 23 rows, 46 columns, and 87 nonzeros.
# Reduced MIP has 21 binaries, 23 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.05 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.2817        0.2775             1.47%
#       0     0        0.2775     1        0.2817        0.2775        1    1.47%
#       0     2        0.2775     2        0.2817        0.2775        1    1.47%                        0             0
# Elapsed time = 0.03 sec. (0.82 ticks, tree = 0.01 MB, solutions = 1)
#    6359  1616        0.2791     2        0.2817        0.2775    19154    1.47%          rho_19 U   6359   6320     49
#   11619  2669        cutoff              0.2817        0.2775    35764    1.47%          rho_19 U  11619  11618     78
#   16566  3851        0.2790     7        0.2817        0.2775    51326    1.47%           rho_6 D  16566  15766     47
#   21422  5000        0.2778     5        0.2817        0.2775    66123    1.47%          rho_16 U  21422  21420     97
#   26431  6139        0.2777     8        0.2817        0.2775    81576    1.47%          rho_11 D  26431  26430     38
#   31830  7373        0.2775     1        0.2817        0.2775    98229    1.47%          rho_18 D  31830  31829    100
#   37313  8605        0.2775     1        0.2817        0.2775   114957    1.47%           rho_8 D  37313  18571     74
#   42958  9854        cutoff              0.2817        0.2775   132455    1.47%           rho_6 U  42958  42913     55
#   48618 11169        0.2775     1        0.2817        0.2775   149820    1.47%          rho_15 U  48618  48548     72
#   71886 16138        cutoff              0.2817        0.2775   221737    1.47%           rho_6 U  71886  71885     71
# Elapsed time = 5.28 sec. (3100.55 ticks, tree = 3.56 MB, solutions = 1)
#   94471 21150        0.2775     3        0.2817        0.2775   291533    1.47%          rho_16 D  94471  94470     38
#  116069 24318        cutoff              0.2817        0.2775   364180    1.47%          rho_21 U 116069 116067     63
#  138310 28475        0.2781     5        0.2817        0.2775   434729    1.47%          rho_12 D 138310 138309     45
#  159078 31647        0.2775     1        0.2817        0.2775   501069    1.47%          rho_15 D 159078 159077    104
#  179727 36313        cutoff              0.2817        0.2775   565905    1.47%           rho_6 D 179727 179726     60
#  201062 40598        cutoff              0.2817        0.2775   633408    1.47%           rho_6 D 201062 201060     78
#  222132 43552        0.2775     1        0.2817        0.2775   700960    1.47%          rho_19 N 222132 222120     95
#  243105 47566        cutoff              0.2817        0.2775   767846    1.47%          rho_15 U 243105 242989     55
#  263361 51440        0.2776     8        0.2817        0.2775   832823    1.47%          rho_17 N 263361 263278     47
#  1642400 139752        0.2888     2        0.2907        0.2871  5935909    1.23%          rho_15 D 1642400 1642288     95
#  1662350 137222        cutoff              0.2907        0.2871  6010120    1.23%           rho_8 U 1662350 883295     83
#  1677225 126276        0.2871     2        0.2907        0.2871  6071128    1.23%           rho_0 U 1677225 632587     98
#  1693999 122145        0.2871     3        0.2907        0.2871  6140184    1.23%           rho_0 D 1693999 1693990     67
#  1711840 123792        0.2875     7        0.2907        0.2871  6206515    1.23%          rho_19 D 1711840 1711839     50
#  1729363 125356        cutoff              0.2907        0.2871  6271992    1.23%           rho_8 U 1729363 1729362     78
#  1747053 127420        0.2873     5        0.2907        0.2871  6337670    1.23%           rho_0 U 1747053 1747052     84
# Elapsed time = 107.56 sec. (79048.61 ticks, tree = 32.71 MB, solutions = 3)
#  1765766 129847        0.2907     3        0.2907        0.2871  6402956    1.23%          rho_15 N 1765766 1765765     88
#  1782870 134415        0.2871     5        0.2907        0.2871  6458914    1.23%           rho_8 U 1782870 1782869     42
#  1798305 139935        0.2871     4        0.2907        0.2871  6508819    1.23%           rho_8 U 1798305 1798303     69
#  1814892 142491        0.2898     2        0.2907        0.2871  6564238    1.23%           rho_8 D 1814892 1814891     55
#  1832447 144492        cutoff              0.2907        0.2871  6630697    1.23%          rho_14 U 1832447  53004     73
#  1850533 140941        cutoff              0.2907        0.2872  6703805    1.20%           rho_0 U 1850533 1850532     80
#  1879851 151865        0.2872     5        0.2907        0.2872  6751187    1.20%           rho_8 U 1879851 1879847     81
#  1904270 153596        0.2884     2        0.2907        0.2878  6814665    1.01%          rho_16 D 1904270 1904269     32
#  1928243 155844        0.2884     2        0.2907        0.2878  6875456    1.01%          rho_18 D 1928243 1928242     53
#  2026374 143859        cutoff              0.2907        0.2882  7102765    0.85%           rho_6 D 2026374 2026373     59
# Elapsed time = 122.27 sec. (91446.80 ticks, tree = 36.10 MB, solutions = 3)
#  2108677 144687        0.2884     7        0.2907        0.2884  7222666    0.78%           rho_0 D 2108677 2108675     58
#  2194809 95123        cutoff              0.2907        0.2892  7467246    0.53%          rho_19 D 2194809 2194807     79
#  2283663 37944        cutoff              0.2907        0.2897  7675904    0.35%          rho_14 U 2283663 817156     58
#
# User cuts applied:  34
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (0.84 ticks)
# Sequential b&c:
#   Real time             =  138.72 sec. (104802.57 ticks)
#                           ------------
# Total (root+branch&cut) =  138.78 sec. (104803.41 ticks)
# +-----------------------------------------------+-------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-21 + score))   |                   |           |
# | ============================================= | ================= | ========= |
# | p_current_age>=18                             |         17 points |   + ..... |
# | p_age_first_offense<=21                       |          1 points |   + ..... |
# | p_drug>=1                                     |          1 points |   + ..... |
# | p_drug>=4                                     |          1 points |   + ..... |
# | ============================================= | ================= | ========= |
# | ADD POINTS FROM ROWS 1 to 4                   |             SCORE |   = ..... |
# +-----------------------------------------------+-------------------+-----------+
# model_id, score_thresholds 0 {'rank_abs': [0]}
# get_disparity_predefined_group()

# %%
np.mean(riskslim_summary['train_auc']), np.mean(riskslim_summary['test_auc'])
# Out:
# (0.7014111146722716, 0.6933522269968744)

# %% [markdown]
# ## Arnold PSA

# %%
### load data
data = pd.read_csv("~/Documents/Duke/Cynthia Research/KY-analysis-mytrials/broward/data/broward_arnold.csv")
X_arnold_raw = data['arnold_nca_raw'].values
X_arnold_calc = data['arnold_nca'].values
Y_arnold = data['recid_drug2'].values

# %%
## set up cross validation
cv = KFold(n_splits=5,shuffle=True,random_state=816)
raw_auc = []
calc_auc = []

## raw score
i = 1
for train, test in cv.split(X_arnold_raw, Y_arnold):
    y_pred_raw, y_pred_calc, y_test = X_arnold_raw[test], X_arnold_calc[test], Y_arnold[test]
    raw_auc.append(roc_auc_score(y_test, y_pred_raw))
    calc_auc.append(roc_auc_score(y_test, y_pred_calc))
    i+=1

# %% [markdown]
# ### Results

# %%
#### save results
summary_drug2_broward_interpret = {"CART": cart_summary,
                                   "EBM": ebm_summary, 
                                   'Lasso Stumps': stump_summary, 
                                   'RiskSLIM': riskslim_summary, 
                                   'Arnold PSA Raw': raw_auc, 
                                   'Arnold PSA': calc_auc}
# %store summary_drug2_broward_interpret
# Out:
# Stored 'summary_drug2_broward_interpret' (dict)

# %%
results = [["CART", np.mean(cart_summary['holdout_test_auc']), np.mean(cart_summary['auc_diffs'])],
           ["EBM", np.mean(ebm_summary['holdout_test_auc']), np.mean(ebm_summary['auc_diffs'])], 
           ["Lasso Stumps", np.mean(stump_summary['holdout_test_auc']), np.mean(stump_summary['auc_diffs'])],
           ['RiskSLIM', np.mean(riskslim_summary['test_auc'])],
           ['Arnold PSA Raw', round(np.mean(raw_auc), 3)], 
           ['Arnold PSA', round(np.mean(calc_auc), 3)]]
results
# Out:
# [['CART', 0.6362388977391955, 0.03216264372495723],
#  ['EBM', 0.6669158292052909, 0.07706052267336123],
#  ['Lasso Stumps', 0.7037541278059203, 0.041201733308695546],
#  ['RiskSLIM', 0.6933522269968744],
#  ['Arnold PSA Raw', 0.558],
#  ['Arnold PSA', 0.546]]

# %%
auc = [np.mean(cart_summary['holdout_test_auc']), 
       np.mean(ebm_summary['holdout_test_auc']), 
       np.mean(stump_summary['holdout_test_auc']), 
       np.mean(riskslim_summary['test_auc'])]

# %%
path = "C:/Users/binha/Documents/Duke/Cynthia Research/KY-analysis-mytrials/broward/broward models/model results/Advanced Models/Two Year/"
results = [["Drug", np.str((round(np.mean(cart_summary['holdout_test_auc']), 3))) + " (" + np.str(round(np.std(cart_summary['holdout_test_auc']), 3)) + ")", 
            np.str(round(np.mean(ebm_summary['holdout_test_auc']),3)) + " (" + np.str(round(np.std(ebm_summary['holdout_test_auc']), 3)) + ")", 
            np.str(round(np.mean(stump_summary['holdout_test_auc']),3)) + " (" + np.str(round(np.std(stump_summary['holdout_test_auc']), 3)) + ")",             
            np.str(round(np.mean(riskslim_summary['test_auc']),3)) + " (" + np.str(round(np.std(riskslim_summary['test_auc']), 3)) + ")", 
            round(np.max(auc) - np.min(auc), 3),
            np.str(round(np.mean(raw_auc), 3)) + " (" + np.str(round(np.std(raw_auc),3)) + ")", 
            np.str(round(np.mean(calc_auc), 3)) + " (" + np.str(round(np.std(calc_auc),3)) + ")"]]
with open(path + 'Advanced Models Summary.csv', 'a') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(results)
