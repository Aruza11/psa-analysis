# %%
import numpy as np
import pandas as pd
import RiskSLIM as risk
import csv

from riskslim.helper_functions import load_data_from_csv, print_model
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.utils import shuffle

# %% [markdown]
# ### Lasso Feature Selection

# %%
## load stumps data
data = pd.read_csv("~/Documents/Duke/Cynthia Research/KY-analysis-mytrials/broward/data/broward_stumps.csv")
X, Y = data.loc[:,:'five_year>=1'], data['recid_violent2'].values
cols = X.columns

# %%
## lasso
lasso = Lasso(random_state=816, alpha=0.02).fit(X, Y)
selected_features = cols[lasso.coef_ != 0].tolist()
len(selected_features), roc_auc_score(Y, lasso.predict(X))
# Out:
# (16, 0.7000584481233413)

# %% [markdown]
# #### subset features

# %%
### Subset features
selected_features.insert(0, 'recid_violent2')
sub_data = data[selected_features]
sub_X, sub_Y = sub_data.iloc[:,1:], sub_data.iloc[:,0].values
sub_X.insert(0, '(Intercept)', 1)

# %% [markdown]
# ### Cross Validation

# %%
SLIM_X, SLIM_Y = sub_X.values, sub_Y.reshape(-1,1)
variable_names = sub_X.columns.tolist()
outcome_name = 'recid_violent2'
sample_weights = np.repeat(1, len(sub_Y))

# %%
#cv = KFold(n_splits=5, random_state=816, shuffle=True)
cv = KFold(n_splits=5, random_state=816, shuffle=True)
train_auc, test_auc = [], []

i = 0
for train, test in cv.split(SLIM_X, SLIM_Y):
    
    ## subset train data & store test data
    X_train, Y_train = SLIM_X[train], SLIM_Y[train]
    X_test, Y_test = SLIM_X[test], SLIM_Y[test]
    sample_weights_train, sample_weights_test = sample_weights[train], sample_weights[test]

    ## create new data dictionary
    new_train_data = {
        'X': X_train,
        'Y': Y_train,
        'variable_names': variable_names,
        'outcome_name': outcome_name,
        'sample_weights': sample_weights_train
    }
        
    ## fit the model
    model_info, mip_info, lcpa_info = risk.risk_slim(new_train_data, max_coefficient=20, max_L0_value=10, 
                                                c0_value=1e-6, max_runtime=200)
    print_model(model_info['solution'], new_train_data)
    
    ## change data format
    X_train, X_test = X_train[:,1:], X_test[:,1:] ## remove the first column, which is "intercept"
    Y_train[Y_train == -1] = 0 ## change -1 to 0
    Y_test[Y_test == -1] = 0
    
    ## probability & accuracy
    train_prob = risk.riskslim_prediction(X_train, cols, model_info).reshape(-1,1)
    test_prob = risk.riskslim_prediction(X_test, cols, model_info).reshape(-1,1)
    
    ## AUC
    train_auc.append(roc_auc_score(Y_train, train_prob))
    test_auc.append(roc_auc_score(Y_test, test_prob))
# Out:
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:57 PM | 741 rows in lookup table
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | runnning initialization procedure
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | CPA produced 2 cuts
# 08/17/19 @ 04:57 PM | running naive rounding on 100 solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4736
# 08/17/19 @ 04:57 PM | rounding produced 2 integer solutions
# 08/17/19 @ 04:57 PM | best objective value is 0.4937
# 08/17/19 @ 04:57 PM | running sequential rounding on 100 solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4736
# 08/17/19 @ 04:57 PM | sequential rounding produced 4 integer solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4937
# 08/17/19 @ 04:57 PM | polishing 6 solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4937
# 08/17/19 @ 04:57 PM | polishing produced 4 integer solutions
# 08/17/19 @ 04:57 PM | initialization produced 7 feasible solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4932
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | completed initialization procedure
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | 741 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.47351680181166222
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.49316768145600737
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:57 PM | adding 136 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.4932.
# Tried aggregator 1 time.
# Reduced MIP has 18 rows, 36 columns, and 67 nonzeros.
# Reduced MIP has 16 binaries, 18 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.03 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.4932        0.4735             3.99%
#       0     0        0.4735     1        0.4932        0.4735        1    3.98%
#       0     0        0.4735     1        0.4932      Fract: 2        2    3.98%
#       0     0        0.4735     2        0.4932      Fract: 1        4    3.98%
#       0     2        0.4735     6        0.4932        0.4735        4    3.98%                        0             0
# Elapsed time = 0.06 sec. (1.29 ticks, tree = 0.01 MB, solutions = 1)
# *   280+   85                            0.4864        0.4735             2.64%
#
# Gomory fractional cuts applied:  1
# User cuts applied:  120
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (1.30 ticks)
# Sequential b&c:
#   Real time             =    0.17 sec. (111.84 ticks)
#                           ------------
# Total (root+branch&cut) =    0.23 sec. (113.14 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-3 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_age_first_offense<=19                      |         1 points |   + ..... |
# | current_violent>=1                           |         1 points |   + ..... |
# | prior_conviction_M>=7                        |         1 points |   + ..... |
# | violent_conviction>=4                        |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 4                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:57 PM | 741 rows in lookup table
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | runnning initialization procedure
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | CPA produced 2 cuts
# 08/17/19 @ 04:57 PM | running naive rounding on 115 solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4757
# 08/17/19 @ 04:57 PM | rounding produced 1 integer solutions
# 08/17/19 @ 04:57 PM | best objective value is 0.5109
# 08/17/19 @ 04:57 PM | running sequential rounding on 115 solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4757
# 08/17/19 @ 04:57 PM | sequential rounding produced 1 integer solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4965
# 08/17/19 @ 04:57 PM | polishing 2 solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4965
# 08/17/19 @ 04:57 PM | polishing produced 2 integer solutions
# 08/17/19 @ 04:57 PM | initialization produced 3 feasible solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4965
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | completed initialization procedure
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | 741 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.47568465095778745
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.49648698364664257
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:57 PM | adding 138 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.4965.
# Tried aggregator 1 time.
# Reduced MIP has 18 rows, 36 columns, and 67 nonzeros.
# Reduced MIP has 16 binaries, 18 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (0.03 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.4965        0.4757             4.19%
#       0     0        0.4757     1        0.4965        0.4757        1    4.19%
#       0     0        0.4757     1        0.4965      Fract: 2        2    4.19%
#       0     0        0.4757     2        0.4965      Fract: 1        4    4.19%
#       0     2        0.4757     6        0.4965        0.4757        4    4.19%                        0             0
# Elapsed time = 0.06 sec. (1.29 ticks, tree = 0.01 MB, solutions = 1)
# *   130+   35                            0.4929        0.4757             3.50%
# *   140+   39                            0.4914        0.4757             3.19%
# *   726   166      integral     0        0.4902        0.4757     2917    2.97%
# *  1114    25      integral     0        0.4899        0.4883     4388    0.33%          rho_13 D   1114   1113     24
#
# Implied bound cuts applied:  1
# Gomory fractional cuts applied:  1
# User cuts applied:  146
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (1.30 ticks)
# Sequential b&c:
#   Real time             =    0.20 sec. (111.88 ticks)
#                           ------------
# Total (root+branch&cut) =    0.27 sec. (113.18 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-3 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_age_first_offense<=19                      |         1 points |   + ..... |
# | current_violent>=1                           |         1 points |   + ..... |
# | prior_conviction_M>=7                        |         1 points |   + ..... |
# | violent_conviction>=4                        |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 4                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:57 PM | 741 rows in lookup table
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | runnning initialization procedure
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | CPA produced 2 cuts
# 08/17/19 @ 04:57 PM | running naive rounding on 105 solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4776
# 08/17/19 @ 04:57 PM | rounding produced 1 integer solutions
# 08/17/19 @ 04:57 PM | best objective value is 0.4919
# 08/17/19 @ 04:57 PM | running sequential rounding on 105 solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4776
# 08/17/19 @ 04:57 PM | sequential rounding produced 2 integer solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4919
# 08/17/19 @ 04:57 PM | polishing 3 solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4919
# 08/17/19 @ 04:57 PM | polishing produced 2 integer solutions
# 08/17/19 @ 04:57 PM | initialization produced 2 feasible solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4919
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | completed initialization procedure
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | 741 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.47751547709303177
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.4918903869220651
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:57 PM | adding 104 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.4919.
# Tried aggregator 1 time.
# Reduced MIP has 18 rows, 36 columns, and 67 nonzeros.
# Reduced MIP has 16 binaries, 18 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.03 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.4919        0.4775             2.92%
#       0     0        0.4775     1        0.4919        0.4775        1    2.92%
#       0     0        0.4775     1        0.4919      Fract: 1        2    2.92%
#       0     0        0.4775     5        0.4919      Fract: 1        5    2.92%
#       0     2        0.4775     5        0.4919        0.4775        5    2.92%                        0             0
# Elapsed time = 0.06 sec. (1.01 ticks, tree = 0.01 MB, solutions = 1)
#
# Gomory fractional cuts applied:  2
# User cuts applied:  116
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (1.01 ticks)
# Sequential b&c:
#   Real time             =    0.16 sec. (86.22 ticks)
#                           ------------
# Total (root+branch&cut) =    0.22 sec. (87.23 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-2 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | current_violent>=1                           |         1 points |   + ..... |
# | violent_conviction>=5                        |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:57 PM | 741 rows in lookup table
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | runnning initialization procedure
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | CPA produced 2 cuts
# 08/17/19 @ 04:57 PM | running naive rounding on 117 solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4739
# 08/17/19 @ 04:57 PM | rounding produced 2 integer solutions
# 08/17/19 @ 04:57 PM | best objective value is 0.5110
# 08/17/19 @ 04:57 PM | running sequential rounding on 117 solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4739
# 08/17/19 @ 04:57 PM | sequential rounding produced 2 integer solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4942
# 08/17/19 @ 04:57 PM | polishing 4 solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4942
# 08/17/19 @ 04:57 PM | polishing produced 4 integer solutions
# 08/17/19 @ 04:57 PM | initialization produced 7 feasible solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4891
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | completed initialization procedure
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | 741 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.47388050947347204
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.48909702309302999
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:57 PM | adding 116 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.4891.
# Tried aggregator 1 time.
# Reduced MIP has 18 rows, 36 columns, and 67 nonzeros.
# Reduced MIP has 16 binaries, 18 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.03 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.4891        0.4739             3.11%
#       0     0        0.4739     1        0.4891        0.4739        1    3.11%
#       0     0        0.4739     1        0.4891      Fract: 2        2    3.11%
#       0     2        0.4739     4        0.4891        0.4739        2    3.11%                        0             0
# Elapsed time = 0.05 sec. (0.94 ticks, tree = 0.01 MB, solutions = 1)
# *   458   139      integral     0        0.4886        0.4739     1522    3.01%
# *   460+  122                            0.4860        0.4739             2.49%
#
# Gomory fractional cuts applied:  1
# User cuts applied:  110
#
# Root node processing (before b&c):
#   Real time             =    0.05 sec. (0.95 ticks)
# Sequential b&c:
#   Real time             =    0.14 sec. (66.87 ticks)
#                           ------------
# Total (root+branch&cut) =    0.19 sec. (67.82 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-3 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_age_first_offense<=19                      |         1 points |   + ..... |
# | current_violent>=1                           |         1 points |   + ..... |
# | prior_conviction_M>=7                        |         1 points |   + ..... |
# | p_property>=5                                |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 4                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:57 PM | 741 rows in lookup table
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | runnning initialization procedure
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | CPA produced 2 cuts
# 08/17/19 @ 04:57 PM | running naive rounding on 128 solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4785
# 08/17/19 @ 04:57 PM | rounding produced 1 integer solutions
# 08/17/19 @ 04:57 PM | best objective value is 0.5122
# 08/17/19 @ 04:57 PM | running sequential rounding on 128 solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4785
# 08/17/19 @ 04:57 PM | sequential rounding produced 2 integer solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4965
# 08/17/19 @ 04:57 PM | polishing 3 solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4965
# 08/17/19 @ 04:57 PM | polishing produced 3 integer solutions
# 08/17/19 @ 04:57 PM | initialization produced 4 feasible solutions
# 08/17/19 @ 04:57 PM | best objective value: 0.4965
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | completed initialization procedure
# 08/17/19 @ 04:57 PM | ------------------------------------------------------------
# 08/17/19 @ 04:57 PM | 741 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.47849736707025542
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.49648506597261688
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:57 PM | adding 127 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.4965.
# Tried aggregator 1 time.
# Reduced MIP has 18 rows, 36 columns, and 67 nonzeros.
# Reduced MIP has 16 binaries, 18 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (0.03 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.4965        0.4785             3.63%
#       0     0        0.4785     1        0.4965        0.4785        1    3.62%
#       0     0        0.4785     1        0.4965      Fract: 2        2    3.62%
#       0     0        0.4785     2        0.4965      Fract: 1        4    3.62%
#       0     2        0.4785     6        0.4965        0.4785        4    3.62%                        0             0
# Elapsed time = 0.05 sec. (1.30 ticks, tree = 0.01 MB, solutions = 1)
# *   420+  114                            0.4934        0.4785             3.03%
# *  1088   161      integral     0        0.4934        0.4846     4153    1.79%
#
# Gomory fractional cuts applied:  1
# User cuts applied:  142
#
# Root node processing (before b&c):
#   Real time             =    0.05 sec. (1.30 ticks)
# Sequential b&c:
#   Real time             =    0.17 sec. (118.62 ticks)
#                           ------------
# Total (root+branch&cut) =    0.22 sec. (119.93 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-3 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_age_first_offense<=19                      |         1 points |   + ..... |
# | current_violent>=1                           |         1 points |   + ..... |
# | prior_conviction_M>=7                        |         1 points |   + ..... |
# | violent_conviction>=3                        |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 4                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+

# %%
np.mean(train_auc), np.mean(test_auc)
# Out:
# (0.6642312856721537, 0.6470576621662607)

# %% [markdown]
# ### Save Results

# %%
#log model results to the model performance folder, as per standards
path = "C:\\Users\\binha\\Documents\\Duke\\Cynthia Research\\KY-analysis-mytrials\\broward\\broward models\\model results\\Advanced Models\\Two Year\\"                   
results = [["Violence", np.mean(train_auc), np.std(train_auc), np.mean(test_auc), np.std(test_auc)]]
with open(path + 'Two Year RiskSLIM.csv', 'a') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(results)
