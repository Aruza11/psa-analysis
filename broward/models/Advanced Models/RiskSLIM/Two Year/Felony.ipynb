# %%
import numpy as np
import pandas as pd
import RiskSLIM as risk
import csv

from riskslim.helper_functions import load_data_from_csv, print_model
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.utils import shuffle

# %% [markdown]
# ### Lasso Feature Selection

# %%
## load stumps data
data = pd.read_csv("~/Documents/Duke/Cynthia Research/KY-analysis-mytrials/broward/data/broward_stumps.csv")
X, Y = data.loc[:,:'five_year>=1'], data['recid_F2'].values
cols = X.columns

# %%
## lasso
lasso = Lasso(random_state=816, alpha=0.02).fit(X, Y)
selected_features = cols[lasso.coef_ != 0].tolist()
len(selected_features), roc_auc_score(Y, lasso.predict(X))
# Out:
# (14, 0.678079409215658)

# %% [markdown]
# #### subset features

# %%
### Subset features
selected_features.insert(0, 'recid_F2')
sub_data = data[selected_features]
sub_X, sub_Y = sub_data.iloc[:,1:], sub_data.iloc[:,0].values
sub_X.insert(0, '(Intercept)', 1)

# %% [markdown]
# ### Cross Validation

# %%
SLIM_X, SLIM_Y = sub_X.values, sub_Y.reshape(-1,1)
variable_names = sub_X.columns.tolist()
outcome_name = 'recid_F2'
sample_weights = np.repeat(1, len(sub_Y))

# %%
#cv = KFold(n_splits=5, random_state=816, shuffle=True)
cv = KFold(n_splits=5, random_state=816, shuffle=True)
train_auc, test_auc = [], []

i = 0
for train, test in cv.split(SLIM_X, SLIM_Y):
    
    ## subset train data & store test data
    X_train, Y_train = SLIM_X[train], SLIM_Y[train]
    X_test, Y_test = SLIM_X[test], SLIM_Y[test]
    sample_weights_train, sample_weights_test = sample_weights[train], sample_weights[test]

    ## create new data dictionary
    new_train_data = {
        'X': X_train,
        'Y': Y_train,
        'variable_names': variable_names,
        'outcome_name': outcome_name,
        'sample_weights': sample_weights_train
    }
        
    ## fit the model
    model_info, mip_info, lcpa_info = risk.risk_slim(new_train_data, max_coefficient=20, max_L0_value=10, 
                                                c0_value=1e-3, max_runtime=200)
    print_model(model_info['solution'], new_train_data)
    
    ## change data format
    X_train, X_test = X_train[:,1:], X_test[:,1:] ## remove the first column, which is "intercept"
    Y_train[Y_train == -1] = 0 ## change -1 to 0
    Y_test[Y_test == -1] = 0
    
    ## probability & accuracy
    train_prob = risk.riskslim_prediction(X_train, cols, model_info).reshape(-1,1)
    test_prob = risk.riskslim_prediction(X_test, cols, model_info).reshape(-1,1)
    
    ## AUC
    train_auc.append(roc_auc_score(Y_train, train_prob))
    test_auc.append(roc_auc_score(Y_test, test_prob))
# Out:
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:02 PM | 661 rows in lookup table
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | runnning initialization procedure
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | CPA produced 2 cuts
# 08/17/19 @ 05:02 PM | running naive rounding on 103 solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4325
# 08/17/19 @ 05:02 PM | rounding produced 1 integer solutions
# 08/17/19 @ 05:02 PM | best objective value is 0.4513
# 08/17/19 @ 05:02 PM | running sequential rounding on 103 solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4325
# 08/17/19 @ 05:02 PM | sequential rounding produced 2 integer solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4416
# 08/17/19 @ 05:02 PM | polishing 3 solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4416
# 08/17/19 @ 05:02 PM | polishing produced 3 integer solutions
# 08/17/19 @ 05:02 PM | initialization produced 4 feasible solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4416
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | completed initialization procedure
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | 661 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.43247343076791211
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.44164977919084025
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:02 PM | adding 102 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.4416.
# Tried aggregator 1 time.
# Reduced MIP has 16 rows, 32 columns, and 59 nonzeros.
# Reduced MIP has 14 binaries, 16 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (0.03 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.4416        0.4225             4.34%
#       0     0        0.4325     1        0.4416        0.4325        1    2.08%
#       0     0        0.4325     1        0.4416       Cuts: 4        3    2.08%
#       0     0        0.4325     1        0.4416    MIRcuts: 1        4    2.08%
#       0     0        0.4325     2        0.4416    MIRcuts: 1        8    2.08%
#       0     2        0.4325     2        0.4416        0.4325        8    2.08%                        0             0
# Elapsed time = 0.08 sec. (1.00 ticks, tree = 0.01 MB, solutions = 1)
#
# Mixed integer rounding cuts applied:  2
# Gomory fractional cuts applied:  1
# User cuts applied:  62
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (1.00 ticks)
# Sequential b&c:
#   Real time             =    0.11 sec. (30.14 ticks)
#                           ------------
# Total (root+branch&cut) =    0.17 sec. (31.14 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-2 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_felprop_violarrest>=3                      |         1 points |   + ..... |
# | prior_conviction_M>=7                        |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:02 PM | 661 rows in lookup table
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | runnning initialization procedure
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | CPA produced 2 cuts
# 08/17/19 @ 05:02 PM | running naive rounding on 121 solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4355
# 08/17/19 @ 05:02 PM | rounding produced 2 integer solutions
# 08/17/19 @ 05:02 PM | best objective value is 0.5091
# 08/17/19 @ 05:02 PM | running sequential rounding on 121 solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4355
# 08/17/19 @ 05:02 PM | sequential rounding produced 2 integer solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4463
# 08/17/19 @ 05:02 PM | polishing 4 solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4463
# 08/17/19 @ 05:02 PM | polishing produced 3 integer solutions
# 08/17/19 @ 05:02 PM | initialization produced 5 feasible solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4463
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | completed initialization procedure
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | 661 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.43544766747053798
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.44627742530333253
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:02 PM | adding 120 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.4463.
# Tried aggregator 1 time.
# Reduced MIP has 16 rows, 32 columns, and 59 nonzeros.
# Reduced MIP has 14 binaries, 16 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.03 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.4463        0.4254             4.67%
#       0     0        0.4354     1        0.4463        0.4354        1    2.43%
#       0     0        0.4354     2        0.4463       Cuts: 3        4    2.43%
#       0     0        0.4354     1        0.4463       Cuts: 2        5    2.43%
#       0     2        0.4354     7        0.4463        0.4354        5    2.43%                        0             0
# Elapsed time = 0.08 sec. (1.38 ticks, tree = 0.01 MB, solutions = 1)
#
# Implied bound cuts applied:  7
# Mixed integer rounding cuts applied:  1
# Gomory fractional cuts applied:  1
# User cuts applied:  79
#
# Root node processing (before b&c):
#   Real time             =    0.08 sec. (1.38 ticks)
# Sequential b&c:
#   Real time             =    0.17 sec. (74.47 ticks)
#                           ------------
# Total (root+branch&cut) =    0.25 sec. (75.85 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-2 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_felprop_violarrest>=3                      |         1 points |   + ..... |
# | prior_conviction_M>=7                        |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:02 PM | 661 rows in lookup table
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | runnning initialization procedure
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | CPA produced 2 cuts
# 08/17/19 @ 05:02 PM | running naive rounding on 97 solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4464
# 08/17/19 @ 05:02 PM | rounding produced 1 integer solutions
# 08/17/19 @ 05:02 PM | best objective value is 0.4674
# 08/17/19 @ 05:02 PM | running sequential rounding on 97 solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4464
# 08/17/19 @ 05:02 PM | sequential rounding produced 1 integer solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4569
# 08/17/19 @ 05:02 PM | polishing 2 solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4569
# 08/17/19 @ 05:02 PM | polishing produced 2 integer solutions
# 08/17/19 @ 05:02 PM | initialization produced 2 feasible solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4569
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | completed initialization procedure
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | 661 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.4463886255383317
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.45687832895873554
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:02 PM | adding 96 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.4569.
# Tried aggregator 1 time.
# Reduced MIP has 16 rows, 32 columns, and 59 nonzeros.
# Reduced MIP has 14 binaries, 16 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.03 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.4569        0.4364             4.48%
#       0     0        0.4464     1        0.4569        0.4464        1    2.30%
#       0     0        0.4464     1        0.4569       Cuts: 2        2    2.30%
#       0     0        0.4464     1        0.4569      Fract: 1        5    2.30%
#       0     2        0.4464     4        0.4569        0.4464        5    2.30%                        0             0
# Elapsed time = 0.06 sec. (0.92 ticks, tree = 0.01 MB, solutions = 1)
#
# Gomory fractional cuts applied:  1
# User cuts applied:  60
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (0.92 ticks)
# Sequential b&c:
#   Real time             =    0.11 sec. (38.65 ticks)
#                           ------------
# Total (root+branch&cut) =    0.17 sec. (39.57 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-2 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_felprop_violarrest>=3                      |         1 points |   + ..... |
# | prior_conviction_M>=7                        |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:02 PM | 661 rows in lookup table
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | runnning initialization procedure
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | CPA produced 2 cuts
# 08/17/19 @ 05:02 PM | running naive rounding on 135 solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4288
# 08/17/19 @ 05:02 PM | rounding produced 1 integer solutions
# 08/17/19 @ 05:02 PM | best objective value is 0.5309
# 08/17/19 @ 05:02 PM | running sequential rounding on 135 solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4288
# 08/17/19 @ 05:02 PM | sequential rounding produced 3 integer solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4397
# 08/17/19 @ 05:02 PM | polishing 4 solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4397
# 08/17/19 @ 05:02 PM | polishing produced 4 integer solutions
# 08/17/19 @ 05:02 PM | initialization produced 6 feasible solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4397
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | completed initialization procedure
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | 661 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.4287658685449518
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.43969678763199699
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:02 PM | adding 134 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.4397.
# Tried aggregator 1 time.
# Reduced MIP has 16 rows, 32 columns, and 59 nonzeros.
# Reduced MIP has 14 binaries, 16 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.03 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.4397        0.4188             4.76%
#       0     0        0.4288     1        0.4397        0.4288        1    2.49%
#       0     0        0.4288     2        0.4397       Cuts: 3        4    2.49%
#       0     0        0.4288     2        0.4397       Cuts: 2        7    2.49%
#       0     2        0.4288     7        0.4397        0.4288        7    2.49%                        0             0
# Elapsed time = 0.06 sec. (1.22 ticks, tree = 0.01 MB, solutions = 1)
#
# Implied bound cuts applied:  4
# Gomory fractional cuts applied:  1
# User cuts applied:  93
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (1.22 ticks)
# Sequential b&c:
#   Real time             =    0.17 sec. (80.47 ticks)
#                           ------------
# Total (root+branch&cut) =    0.23 sec. (81.69 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-2 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_charge>=11                                 |         1 points |   + ..... |
# | p_felprop_violarrest>=3                      |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:02 PM | 661 rows in lookup table
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | runnning initialization procedure
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | CPA produced 2 cuts
# 08/17/19 @ 05:02 PM | running naive rounding on 111 solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4459
# 08/17/19 @ 05:02 PM | rounding produced 1 integer solutions
# 08/17/19 @ 05:02 PM | best objective value is 0.4707
# 08/17/19 @ 05:02 PM | running sequential rounding on 111 solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4459
# 08/17/19 @ 05:02 PM | sequential rounding produced 1 integer solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4567
# 08/17/19 @ 05:02 PM | polishing 2 solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4567
# 08/17/19 @ 05:02 PM | polishing produced 2 integer solutions
# 08/17/19 @ 05:02 PM | initialization produced 3 feasible solutions
# 08/17/19 @ 05:02 PM | best objective value: 0.4567
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | completed initialization procedure
# 08/17/19 @ 05:02 PM | ------------------------------------------------------------
# 08/17/19 @ 05:02 PM | 661 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.44582061245649851
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.45671694752638192
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:02 PM | adding 110 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.4567.
# Tried aggregator 1 time.
# Reduced MIP has 16 rows, 32 columns, and 59 nonzeros.
# Reduced MIP has 14 binaries, 16 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.03 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.4567        0.4358             4.58%
#       0     0        0.4458     1        0.4567        0.4458        1    2.39%
#       0     0        0.4458     1        0.4567       Cuts: 2        2    2.39%
#       0     2        0.4458     6        0.4567        0.4458        2    2.39%                        0             0
# Elapsed time = 0.05 sec. (1.06 ticks, tree = 0.01 MB, solutions = 1)
# *   246    76      integral     0        0.4559        0.4458      841    2.22%
#
# User cuts applied:  71
#
# Root node processing (before b&c):
#   Real time             =    0.05 sec. (1.07 ticks)
# Sequential b&c:
#   Real time             =    0.11 sec. (45.16 ticks)
#                           ------------
# Total (root+branch&cut) =    0.16 sec. (46.23 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-2 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_charge>=11                                 |         1 points |   + ..... |
# | p_felprop_violarrest>=3                      |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+

# %%
np.mean(train_auc), np.mean(test_auc)
# Out:
# (0.621619775228824, 0.6118490182102331)

# %% [markdown]
# ### Save Results

# %%
#log model results to the model performance folder, as per standards
path = "C:\\Users\\binha\\Documents\\Duke\\Cynthia Research\\KY-analysis-mytrials\\broward\\broward models\\model results\\Advanced Models\\Two Year\\"                   
results = [["Felony", np.mean(train_auc), np.std(train_auc), np.mean(test_auc), np.std(test_auc)]]
with open(path + 'Two Year RiskSLIM.csv', 'a') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(results)
