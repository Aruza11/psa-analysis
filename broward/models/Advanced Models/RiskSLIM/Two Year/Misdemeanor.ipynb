# %%
import numpy as np
import pandas as pd
import RiskSLIM as risk
import csv

from riskslim.helper_functions import load_data_from_csv, print_model
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.utils import shuffle

# %% [markdown]
# ### Lasso Feature Selection

# %%
## load stumps data
data = pd.read_csv("~/Documents/Duke/Cynthia Research/KY-analysis-mytrials/broward/data/broward_stumps.csv")
X, Y = data.loc[:,:'five_year>=1'], data['recid_M2'].values
cols = X.columns

# %%
## lasso
lasso = Lasso(random_state=816, alpha=0.02).fit(X, Y)
selected_features = cols[lasso.coef_ != 0].tolist()
len(selected_features), roc_auc_score(Y, lasso.predict(X))
# Out:
# (19, 0.6487830864080031)

# %% [markdown]
# #### subset features

# %%
### Subset features
selected_features.insert(0, 'recid_M2')
sub_data = data[selected_features]
sub_X, sub_Y = sub_data.iloc[:,1:], sub_data.iloc[:,0].values
sub_X.insert(0, '(Intercept)', 1)

# %% [markdown]
# ### Cross Validation

# %%
SLIM_X, SLIM_Y = sub_X.values, sub_Y.reshape(-1,1)
variable_names = sub_X.columns.tolist()
outcome_name = 'recid_M2'
sample_weights = np.repeat(1, len(sub_Y))

# %%
#cv = KFold(n_splits=5, random_state=816, shuffle=True)
cv = KFold(n_splits=5, random_state=816, shuffle=True)
train_auc, test_auc = [], []

i = 0
for train, test in cv.split(SLIM_X, SLIM_Y):
    
    ## subset train data & store test data
    X_train, Y_train = SLIM_X[train], SLIM_Y[train]
    X_test, Y_test = SLIM_X[test], SLIM_Y[test]
    sample_weights_train, sample_weights_test = sample_weights[train], sample_weights[test]

    ## create new data dictionary
    new_train_data = {
        'X': X_train,
        'Y': Y_train,
        'variable_names': variable_names,
        'outcome_name': outcome_name,
        'sample_weights': sample_weights_train
    }
        
    ## fit the model
    model_info, mip_info, lcpa_info = risk.risk_slim(new_train_data, max_coefficient=20, max_L0_value=10, 
                                                c0_value=1e-4, max_runtime=200)
    print_model(model_info['solution'], new_train_data)
    
    ## change data format
    X_train, X_test = X_train[:,1:], X_test[:,1:] ## remove the first column, which is "intercept"
    Y_train[Y_train == -1] = 0 ## change -1 to 0
    Y_test[Y_test == -1] = 0
    
    ## probability & accuracy
    train_prob = risk.riskslim_prediction(X_train, cols, model_info).reshape(-1,1)
    test_prob = risk.riskslim_prediction(X_test, cols, model_info).reshape(-1,1)
    
    ## AUC
    train_auc.append(roc_auc_score(Y_train, train_prob))
    test_auc.append(roc_auc_score(Y_test, test_prob))
# Out:
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:03 PM | 861 rows in lookup table
# 08/17/19 @ 05:03 PM | ------------------------------------------------------------
# 08/17/19 @ 05:03 PM | runnning initialization procedure
# 08/17/19 @ 05:03 PM | ------------------------------------------------------------
# 08/17/19 @ 05:03 PM | CPA produced 2 cuts
# 08/17/19 @ 05:03 PM | running naive rounding on 132 solutions
# 08/17/19 @ 05:03 PM | best objective value: 0.5551
# 08/17/19 @ 05:03 PM | rounding produced 2 integer solutions
# 08/17/19 @ 05:03 PM | best objective value is 0.5683
# 08/17/19 @ 05:03 PM | running sequential rounding on 132 solutions
# 08/17/19 @ 05:03 PM | best objective value: 0.5551
# 08/17/19 @ 05:03 PM | sequential rounding produced 2 integer solutions
# 08/17/19 @ 05:03 PM | best objective value: 0.5683
# 08/17/19 @ 05:03 PM | polishing 4 solutions
# 08/17/19 @ 05:03 PM | best objective value: 0.5683
# 08/17/19 @ 05:03 PM | polishing produced 1 integer solutions
# 08/17/19 @ 05:03 PM | initialization produced 2 feasible solutions
# 08/17/19 @ 05:03 PM | best objective value: 0.5683
# 08/17/19 @ 05:03 PM | ------------------------------------------------------------
# 08/17/19 @ 05:03 PM | completed initialization procedure
# 08/17/19 @ 05:03 PM | ------------------------------------------------------------
# 08/17/19 @ 05:03 PM | 861 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.55509180513719436
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.56826933202714702
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:03 PM | adding 131 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.5683.
# Tried aggregator 1 time.
# Reduced MIP has 21 rows, 42 columns, and 79 nonzeros.
# Reduced MIP has 19 binaries, 21 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.5683        0.5541             2.49%
#       0     0        0.5551     1        0.5683        0.5551        1    2.32%
#       0     0        0.5551     1        0.5683      Fract: 1        2    2.32%
#       0     0        0.5551     6        0.5683       Cuts: 2        5    2.32%
#       0     2        0.5551     6        0.5683        0.5551        5    2.32%                        0             0
# Elapsed time = 0.06 sec. (1.41 ticks, tree = 0.01 MB, solutions = 1)
#    3384   788        cutoff              0.5683        0.5551    14978    2.32%           rho_0 U   3384   3383     43
#    6316  1557        0.5551     3        0.5683        0.5551    28186    2.32%           rho_9 U   6316   4627     21
#    8990  2090        cutoff              0.5683        0.5551    40566    2.32%           rho_6 U   8990   8989     20
#   11531  2763        0.5582     4        0.5683        0.5551    53102    2.32%           rho_5 D  11531  11529     16
#   14020  3457        0.5552     8        0.5683        0.5551    64921    2.32%          rho_10 U  14020  14019     51
#   16419  4005        0.5558    10        0.5683        0.5553    75056    2.27%          rho_15 D  16419  16418     13
#   19334  4322        0.5639     9        0.5683        0.5569    83630    1.99%          rho_14 D  19334  19333     11
#   22513  3997        cutoff              0.5683        0.5590    93149    1.64%           rho_0 U  22513  13085     35
#   25568  3398        0.5657     8        0.5683        0.5612   102048    1.25%           rho_0 D  25568   4059     24
#
# Mixed integer rounding cuts applied:  1
# Gomory fractional cuts applied:  2
# User cuts applied:  92
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (1.41 ticks)
# Sequential b&c:
#   Real time             =    3.52 sec. (2654.48 ticks)
#                           ------------
# Total (root+branch&cut) =    3.58 sec. (2655.90 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-2 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_age_first_offense<=30                      |         1 points |   + ..... |
# | fail_appear_two_yr>=1                        |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:03 PM | 861 rows in lookup table
# 08/17/19 @ 05:03 PM | ------------------------------------------------------------
# 08/17/19 @ 05:03 PM | runnning initialization procedure
# 08/17/19 @ 05:03 PM | ------------------------------------------------------------
# 08/17/19 @ 05:03 PM | CPA produced 2 cuts
# 08/17/19 @ 05:03 PM | running naive rounding on 139 solutions
# 08/17/19 @ 05:03 PM | best objective value: 0.5565
# 08/17/19 @ 05:03 PM | rounding produced 1 integer solutions
# 08/17/19 @ 05:03 PM | best objective value is 0.5672
# 08/17/19 @ 05:03 PM | running sequential rounding on 139 solutions
# 08/17/19 @ 05:03 PM | best objective value: 0.5565
# 08/17/19 @ 05:03 PM | sequential rounding produced 1 integer solutions
# 08/17/19 @ 05:03 PM | best objective value: 0.5672
# 08/17/19 @ 05:03 PM | polishing 2 solutions
# 08/17/19 @ 05:03 PM | best objective value: 0.5672
# 08/17/19 @ 05:03 PM | polishing produced 1 integer solutions
# 08/17/19 @ 05:03 PM | initialization produced 1 feasible solutions
# 08/17/19 @ 05:03 PM | best objective value: 0.5672
# 08/17/19 @ 05:03 PM | ------------------------------------------------------------
# 08/17/19 @ 05:03 PM | completed initialization procedure
# 08/17/19 @ 05:03 PM | ------------------------------------------------------------
# 08/17/19 @ 05:03 PM | 861 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.55646948923213579
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.56719639339101302
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:03 PM | adding 138 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.5672.
# Tried aggregator 1 time.
# Reduced MIP has 21 rows, 42 columns, and 79 nonzeros.
# Reduced MIP has 19 binaries, 21 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.5672        0.5555             2.07%
#       0     0        0.5565     1        0.5672        0.5565        1    1.89%
#       0     0        0.5565     1        0.5672      Fract: 1        2    1.89%
#       0     0        0.5565     2        0.5672      Fract: 1        4    1.89%
#       0     2        0.5565     5        0.5672        0.5565        4    1.89%                        0             0
# Elapsed time = 0.06 sec. (1.34 ticks, tree = 0.01 MB, solutions = 1)
#    4458  1042        0.5599     5        0.5672        0.5565    17412    1.89%           rho_0 U   4458   4456      2
#    7865  1851        0.5565     2        0.5672        0.5565    32434    1.89%           rho_0 D   7865   7863     37
#   10980  2469        0.5565     5        0.5672        0.5565    46198    1.89%          rho_15 D  10980  10979     65
#   13980  3063        0.5565     6        0.5672        0.5565    58989    1.89%           rho_6 D  13980  13979     67
#   16890  3522        0.5565     6        0.5672        0.5565    71609    1.89%           rho_9 N  16890   7492     32
#   19908  3964        0.5565     6        0.5672        0.5565    85037    1.89%           rho_9 N  19908  19907     49
#   23075  4308        cutoff              0.5672        0.5565    97918    1.89%           rho_0 U  23075  23074     27
#   26496  4790        0.5581     8        0.5672        0.5565   112663    1.89%           rho_0 D  26496   6374     23
#   29925  5464        0.5571     8        0.5672        0.5565   128124    1.89%          rho_14 D  29925  29924     42
#   45814   157        cutoff              0.5672        0.5669   174697    0.06%          rho_14 U  45814  31148     17
# Elapsed time = 4.03 sec. (3101.56 ticks, tree = 0.35 MB, solutions = 1)
#
# Gomory fractional cuts applied:  1
# User cuts applied:  70
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (1.34 ticks)
# Sequential b&c:
#   Real time             =    3.99 sec. (3112.81 ticks)
#                           ------------
# Total (root+branch&cut) =    4.05 sec. (3114.16 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-2 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_age_first_offense<=30                      |         1 points |   + ..... |
# | fail_appear_two_yr>=1                        |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:04 PM | 861 rows in lookup table
# 08/17/19 @ 05:04 PM | ------------------------------------------------------------
# 08/17/19 @ 05:04 PM | runnning initialization procedure
# 08/17/19 @ 05:04 PM | ------------------------------------------------------------
# 08/17/19 @ 05:04 PM | CPA produced 2 cuts
# 08/17/19 @ 05:04 PM | running naive rounding on 121 solutions
# 08/17/19 @ 05:04 PM | best objective value: 0.5627
# 08/17/19 @ 05:04 PM | rounding produced 1 integer solutions
# 08/17/19 @ 05:04 PM | best objective value is 0.6440
# 08/17/19 @ 05:04 PM | running sequential rounding on 121 solutions
# 08/17/19 @ 05:04 PM | best objective value: 0.5627
# 08/17/19 @ 05:04 PM | sequential rounding produced 2 integer solutions
# 08/17/19 @ 05:04 PM | best objective value: 0.5724
# 08/17/19 @ 05:04 PM | polishing 3 solutions
# 08/17/19 @ 05:04 PM | best objective value: 0.5724
# 08/17/19 @ 05:04 PM | polishing produced 2 integer solutions
# 08/17/19 @ 05:04 PM | initialization produced 4 feasible solutions
# 08/17/19 @ 05:04 PM | best objective value: 0.5724
# 08/17/19 @ 05:04 PM | ------------------------------------------------------------
# 08/17/19 @ 05:04 PM | completed initialization procedure
# 08/17/19 @ 05:04 PM | ------------------------------------------------------------
# 08/17/19 @ 05:04 PM | 861 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.56269082668158099
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.57243882904647947
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:04 PM | adding 120 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.5724.
# Tried aggregator 1 time.
# Reduced MIP has 21 rows, 42 columns, and 79 nonzeros.
# Reduced MIP has 19 binaries, 21 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.5724        0.5617             1.88%
#       0     0        0.5627     1        0.5724        0.5627        1    1.70%
#       0     0        0.5627     1        0.5724      Fract: 1        2    1.70%
#       0     2        0.5627     2        0.5724        0.5627        2    1.70%                        0             0
# Elapsed time = 0.06 sec. (0.98 ticks, tree = 0.01 MB, solutions = 1)
#    4397   659        cutoff              0.5724        0.5627    18814    1.70%          rho_11 U   4397   4388     61
#    7703  1009        0.5629     6        0.5724        0.5627    35952    1.70%           rho_0 U   7703   7702     17
#   11060   596        0.5707     3        0.5724        0.5688    49144    0.63%           rho_5 D  11060  11058     33
#
# Implied bound cuts applied:  1
# Gomory fractional cuts applied:  1
# User cuts applied:  59
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (0.98 ticks)
# Sequential b&c:
#   Real time             =    1.05 sec. (765.96 ticks)
#                           ------------
# Total (root+branch&cut) =    1.11 sec. (766.93 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-2 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_age_first_offense<=30                      |         1 points |   + ..... |
# | fail_appear_two_yr>=1                        |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:04 PM | 861 rows in lookup table
# 08/17/19 @ 05:04 PM | ------------------------------------------------------------
# 08/17/19 @ 05:04 PM | runnning initialization procedure
# 08/17/19 @ 05:04 PM | ------------------------------------------------------------
# 08/17/19 @ 05:04 PM | CPA produced 2 cuts
# 08/17/19 @ 05:04 PM | running naive rounding on 119 solutions
# 08/17/19 @ 05:04 PM | best objective value: 0.5780
# 08/17/19 @ 05:04 PM | rounding produced 2 integer solutions
# 08/17/19 @ 05:04 PM | best objective value is 0.5908
# 08/17/19 @ 05:04 PM | running sequential rounding on 119 solutions
# 08/17/19 @ 05:04 PM | best objective value: 0.5780
# 08/17/19 @ 05:04 PM | sequential rounding produced 1 integer solutions
# 08/17/19 @ 05:04 PM | best objective value: 0.5908
# 08/17/19 @ 05:04 PM | polishing 3 solutions
# 08/17/19 @ 05:04 PM | best objective value: 0.5908
# 08/17/19 @ 05:04 PM | polishing produced 2 integer solutions
# 08/17/19 @ 05:04 PM | initialization produced 3 feasible solutions
# 08/17/19 @ 05:04 PM | best objective value: 0.5908
# 08/17/19 @ 05:04 PM | ------------------------------------------------------------
# 08/17/19 @ 05:04 PM | completed initialization procedure
# 08/17/19 @ 05:04 PM | ------------------------------------------------------------
# 08/17/19 @ 05:04 PM | 861 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.57790821603703102
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.59083433623334081
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:04 PM | adding 118 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.5908.
# Tried aggregator 1 time.
# Reduced MIP has 21 rows, 42 columns, and 79 nonzeros.
# Reduced MIP has 19 binaries, 21 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.5908        0.5769             2.36%
#       0     0        0.5779     1        0.5908        0.5779        1    2.19%
#       0     2        0.5779     3        0.5908        0.5779        1    2.19%                        0             0
# Elapsed time = 0.05 sec. (0.91 ticks, tree = 0.01 MB, solutions = 1)
#    3925  1185        0.5779     4        0.5908        0.5779    16380    2.19%          rho_15 D   3925   3924     34
#    7096  1731        0.5894     3        0.5908        0.5779    31096    2.19%           rho_0 U   7096   7095     26
#    9983  2224        0.5846     6        0.5908        0.5779    45024    2.19%           rho_6 U   9983   9981     24
#   12685  2612        0.5791     3        0.5908        0.5779    56997    2.19%           rho_5 D  12685  12684     28
#   15171  3052        0.5779     4        0.5908        0.5779    68919    2.19%           rho_6 N  15171  15161     28
#   17905  3018        0.5867     3        0.5908        0.5808    79519    1.70%           rho_0 U  17905  17903     35
#   20865  2624        cutoff              0.5908        0.5835    88382    1.25%          rho_14 U  20865   4295     22
#   23979   958        cutoff              0.5908        0.5878    97114    0.51%          rho_13 U  23979   3104     19
#
# User cuts applied:  81
#
# Root node processing (before b&c):
#   Real time             =    0.05 sec. (0.91 ticks)
# Sequential b&c:
#   Real time             =    3.73 sec. (1988.46 ticks)
#                           ------------
# Total (root+branch&cut) =    3.78 sec. (1989.37 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-2 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_age_first_offense<=30                      |         1 points |   + ..... |
# | fail_appear_two_yr>=1                        |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:04 PM | 861 rows in lookup table
# 08/17/19 @ 05:04 PM | ------------------------------------------------------------
# 08/17/19 @ 05:04 PM | runnning initialization procedure
# 08/17/19 @ 05:04 PM | ------------------------------------------------------------
# 08/17/19 @ 05:04 PM | CPA produced 2 cuts
# 08/17/19 @ 05:04 PM | running naive rounding on 131 solutions
# 08/17/19 @ 05:04 PM | best objective value: 0.5626
# 08/17/19 @ 05:04 PM | rounding produced 1 integer solutions
# 08/17/19 @ 05:04 PM | best objective value is 0.6432
# 08/17/19 @ 05:04 PM | running sequential rounding on 131 solutions
# 08/17/19 @ 05:04 PM | best objective value: 0.5626
# 08/17/19 @ 05:04 PM | sequential rounding produced 1 integer solutions
# 08/17/19 @ 05:04 PM | best objective value: 0.5717
# 08/17/19 @ 05:04 PM | polishing 2 solutions
# 08/17/19 @ 05:04 PM | best objective value: 0.5717
# 08/17/19 @ 05:04 PM | polishing produced 2 integer solutions
# 08/17/19 @ 05:04 PM | initialization produced 3 feasible solutions
# 08/17/19 @ 05:04 PM | best objective value: 0.5717
# 08/17/19 @ 05:04 PM | ------------------------------------------------------------
# 08/17/19 @ 05:04 PM | completed initialization procedure
# 08/17/19 @ 05:04 PM | ------------------------------------------------------------
# 08/17/19 @ 05:04 PM | 861 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.56251557548183428
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.57165423100473611
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:04 PM | adding 130 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.5717.
# Tried aggregator 1 time.
# Reduced MIP has 21 rows, 42 columns, and 79 nonzeros.
# Reduced MIP has 19 binaries, 21 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.5717        0.5615             1.77%
#       0     0        0.5625     1        0.5717        0.5625        1    1.60%
#       0     0        0.5625     1        0.5717       Cuts: 2        2    1.60%
#       0     2        0.5625     6        0.5717        0.5625        2    1.60%                        0             0
# Elapsed time = 0.06 sec. (1.42 ticks, tree = 0.01 MB, solutions = 1)
#    4150   913        0.5648     5        0.5717        0.5625    18768    1.60%           rho_9 U   4150   4149     21
#    7728  1443        cutoff              0.5717        0.5625    36314    1.60%           rho_0 D   7728   7726     40
#   10942  1806        cutoff              0.5717        0.5625    52705    1.60%           rho_0 U  10942  10941     34
#   14000  2144        0.5661     6        0.5717        0.5625    66816    1.60%           rho_5 N  14000  13998     29
#   16895  2104        0.5661     5        0.5717        0.5642    80054    1.31%          rho_11 D  16895  16894     59
#
# Gomory fractional cuts applied:  1
# User cuts applied:  63
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (1.42 ticks)
# Sequential b&c:
#   Real time             =    2.06 sec. (1414.10 ticks)
#                           ------------
# Total (root+branch&cut) =    2.13 sec. (1415.52 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-2 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_age_first_offense<=30                      |         1 points |   + ..... |
# | fail_appear_two_yr>=1                        |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+

# %%
np.mean(train_auc), np.mean(test_auc)
# Out:
# (0.578452367408726, 0.5791816788036774)

# %% [markdown]
# ### Save Results

# %%
#log model results to the model performance folder, as per standards
path = "C:\\Users\\binha\\Documents\\Duke\\Cynthia Research\\KY-analysis-mytrials\\broward\\broward models\\model results\\Advanced Models\\Two Year\\"                   
results = [["Misdemeanor", np.mean(train_auc), np.std(train_auc), np.mean(test_auc), np.std(test_auc)]]
with open(path + 'Two Year RiskSLIM.csv', 'a') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(results)
