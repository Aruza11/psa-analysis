# %%
import numpy as np
import pandas as pd
import RiskSLIM as risk
import csv

from riskslim.helper_functions import load_data_from_csv, print_model
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.utils import shuffle

# %% [markdown]
# ### Lasso Feature Selection

# %%
## load stumps data
data = pd.read_csv("~/Documents/Duke/Cynthia Research/KY-analysis-mytrials/broward/data/broward_stumps.csv")
X, Y = data.loc[:,:'five_year>=1'], data['recid_M6'].values
cols = X.columns

# %%
## lasso
lasso = Lasso(random_state=816, alpha=0.007).fit(X, Y)
selected_features = cols[lasso.coef_ != 0].tolist()
len(selected_features), roc_auc_score(Y, lasso.predict(X))
# Out:
# (20, 0.6616734932709186)

# %% [markdown]
# #### subset features

# %%
### Subset features
selected_features.insert(0, 'recid_M6')
sub_data = data[selected_features]
sub_X, sub_Y = sub_data.iloc[:,1:], sub_data.iloc[:,0].values
sub_X.insert(0, '(Intercept)', 1)

# %% [markdown]
# ### Cross Validation

# %%
SLIM_X, SLIM_Y = sub_X.values, sub_Y.reshape(-1,1)
variable_names = sub_X.columns.tolist()
outcome_name = 'recid_M6'
sample_weights = np.repeat(1, len(sub_Y))

# %%
#cv = KFold(n_splits=5, random_state=816, shuffle=True)
cv = KFold(n_splits=5, random_state=816, shuffle=True)
train_auc, test_auc = [], []

i = 0
for train, test in cv.split(SLIM_X, SLIM_Y):
    
    ## subset train data & store test data
    X_train, Y_train = SLIM_X[train], SLIM_Y[train]
    X_test, Y_test = SLIM_X[test], SLIM_Y[test]
    sample_weights_train, sample_weights_test = sample_weights[train], sample_weights[test]

    ## create new data dictionary
    new_train_data = {
        'X': X_train,
        'Y': Y_train,
        'variable_names': variable_names,
        'outcome_name': outcome_name,
        'sample_weights': sample_weights_train
    }
        
    ## fit the model
    model_info, mip_info, lcpa_info = risk.risk_slim(new_train_data, max_coefficient=20, max_L0_value=6, 
                                                c0_value=5e-4, max_runtime=200)
    print_model(model_info['solution'], new_train_data)
    
    ## change data format
    X_train, X_test = X_train[:,1:], X_test[:,1:] ## remove the first column, which is "intercept"
    Y_train[Y_train == -1] = 0 ## change -1 to 0
    Y_test[Y_test == -1] = 0
    
    ## probability & accuracy
    train_prob = risk.riskslim_prediction(X_train, cols, model_info).reshape(-1,1)
    test_prob = risk.riskslim_prediction(X_test, cols, model_info).reshape(-1,1)
    
    ## AUC
    train_auc.append(roc_auc_score(Y_train, train_prob))
    test_auc.append(roc_auc_score(Y_test, test_prob))
# Out:
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 06:04 PM | 901 rows in lookup table
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | runnning initialization procedure
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | CPA produced 2 cuts
# 08/17/19 @ 06:04 PM | running naive rounding on 78 solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3695
# 08/17/19 @ 06:04 PM | rounding produced 1 integer solutions
# 08/17/19 @ 06:04 PM | best objective value is 0.3986
# 08/17/19 @ 06:04 PM | running sequential rounding on 78 solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3695
# 08/17/19 @ 06:04 PM | sequential rounding produced 2 integer solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3802
# 08/17/19 @ 06:04 PM | polishing 3 solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3802
# 08/17/19 @ 06:04 PM | polishing produced 3 integer solutions
# 08/17/19 @ 06:04 PM | initialization produced 4 feasible solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3802
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | completed initialization procedure
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | 901 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.36944640647631299
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.3802355975075033
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 06:04 PM | adding 91 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.3802.
# Tried aggregator 1 time.
# Reduced MIP has 22 rows, 44 columns, and 83 nonzeros.
# Reduced MIP has 20 binaries, 22 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.3802        0.3664             3.63%
#       0     0        0.3694     1        0.3802        0.3694        1    2.84%
#       0     0        0.3694     1        0.3802       Cuts: 2        2    2.84%
#       0     2        0.3694     1        0.3802        0.3694        2    2.84%                        0             0
# Elapsed time = 0.06 sec. (0.98 ticks, tree = 0.01 MB, solutions = 1)
#    3630   932        0.3777    13        0.3802        0.3699    17794    2.73%          rho_11 D   3630   3629     24
#    7122   723        0.3781     6        0.3802        0.3753    31505    1.30%           rho_0 D   7122   7121     27
#
# Implied bound cuts applied:  1
# User cuts applied:  75
#
# Root node processing (before b&c):
#   Real time             =    0.05 sec. (0.98 ticks)
# Sequential b&c:
#   Real time             =    0.63 sec. (565.59 ticks)
#                           ------------
# Total (root+branch&cut) =    0.67 sec. (566.57 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-3 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_age_first_offense<=30                      |         1 points |   + ..... |
# | six_month>=1                                 |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 06:04 PM | 901 rows in lookup table
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | runnning initialization procedure
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | CPA produced 2 cuts
# 08/17/19 @ 06:04 PM | running naive rounding on 48 solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3594
# 08/17/19 @ 06:04 PM | rounding produced 4 integer solutions
# 08/17/19 @ 06:04 PM | best objective value is 0.3677
# 08/17/19 @ 06:04 PM | running sequential rounding on 48 solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3594
# 08/17/19 @ 06:04 PM | sequential rounding produced 5 integer solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3677
# 08/17/19 @ 06:04 PM | polishing 9 solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3677
# 08/17/19 @ 06:04 PM | polishing produced 4 integer solutions
# 08/17/19 @ 06:04 PM | initialization produced 8 feasible solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3677
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | completed initialization procedure
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | 901 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.35887774749325274
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.36771501183213712
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 06:04 PM | adding 106 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.3677.
# Tried aggregator 1 time.
# Reduced MIP has 22 rows, 44 columns, and 83 nonzeros.
# Reduced MIP has 20 binaries, 22 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.3677        0.3559             3.22%
#       0     0        0.3589     1        0.3677        0.3589        1    2.40%
#       0     2        0.3589     5        0.3677        0.3589        1    2.40%                        0             0
# Elapsed time = 0.05 sec. (0.94 ticks, tree = 0.01 MB, solutions = 1)
#    4238  1489        cutoff              0.3677        0.3589    17232    2.40%          rho_11 U   4238   4237     30
#    8144  1682        0.3662     7        0.3677        0.3624    31764    1.44%           rho_0 U   8144   8143     20
#
# User cuts applied:  62
#
# Root node processing (before b&c):
#   Real time             =    0.05 sec. (0.95 ticks)
# Sequential b&c:
#   Real time             =    0.80 sec. (669.56 ticks)
#                           ------------
# Total (root+branch&cut) =    0.84 sec. (670.50 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-3 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_age_first_offense<=30                      |         1 points |   + ..... |
# | fail_appear_two_yr>=1                        |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 06:04 PM | 901 rows in lookup table
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | runnning initialization procedure
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | CPA produced 2 cuts
# 08/17/19 @ 06:04 PM | running naive rounding on 69 solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3631
# 08/17/19 @ 06:04 PM | rounding produced 3 integer solutions
# 08/17/19 @ 06:04 PM | best objective value is 0.3733
# 08/17/19 @ 06:04 PM | running sequential rounding on 69 solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3631
# 08/17/19 @ 06:04 PM | sequential rounding produced 2 integer solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3710
# 08/17/19 @ 06:04 PM | polishing 5 solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3710
# 08/17/19 @ 06:04 PM | polishing produced 3 integer solutions
# 08/17/19 @ 06:04 PM | initialization produced 5 feasible solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3710
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | completed initialization procedure
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | 901 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.36304006613326206
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.37098245321263029
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 06:04 PM | adding 68 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.3710.
# Tried aggregator 1 time.
# Reduced MIP has 22 rows, 44 columns, and 83 nonzeros.
# Reduced MIP has 20 binaries, 22 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.3710        0.3600             2.95%
#       0     0        0.3630     1        0.3710        0.3630        1    2.14%
#       0     2        0.3630     4        0.3710        0.3630        1    2.14%                        0             0
# Elapsed time = 0.05 sec. (0.71 ticks, tree = 0.01 MB, solutions = 1)
#    4362   769        0.3678     7        0.3710        0.3651    20596    1.60%          rho_12 D   4362   4360     59
#
# User cuts applied:  49
#
# Root node processing (before b&c):
#   Real time             =    0.05 sec. (0.71 ticks)
# Sequential b&c:
#   Real time             =    0.48 sec. (348.29 ticks)
#                           ------------
# Total (root+branch&cut) =    0.53 sec. (349.00 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-3 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_age_first_offense<=30                      |         1 points |   + ..... |
# | fail_appear_two_yr>=1                        |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 06:04 PM | 901 rows in lookup table
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | runnning initialization procedure
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | CPA produced 2 cuts
# 08/17/19 @ 06:04 PM | running naive rounding on 53 solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3807
# 08/17/19 @ 06:04 PM | rounding produced 5 integer solutions
# 08/17/19 @ 06:04 PM | best objective value is 0.3904
# 08/17/19 @ 06:04 PM | running sequential rounding on 53 solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3807
# 08/17/19 @ 06:04 PM | sequential rounding produced 6 integer solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3881
# 08/17/19 @ 06:04 PM | polishing 11 solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3881
# 08/17/19 @ 06:04 PM | polishing produced 5 integer solutions
# 08/17/19 @ 06:04 PM | initialization produced 11 feasible solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3881
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | completed initialization procedure
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | 901 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.38002237745126322
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.3880596702460925
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 06:04 PM | adding 103 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.3881.
# Tried aggregator 1 time.
# Reduced MIP has 22 rows, 44 columns, and 83 nonzeros.
# Reduced MIP has 20 binaries, 22 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.3881        0.3770             2.84%
#       0     0        0.3800     1        0.3881        0.3800        1    2.07%
#       0     0        0.3800     1        0.3881       Cuts: 2        2    2.07%
#       0     0        0.3800     3        0.3881    MIRcuts: 1        5    2.07%
#       0     2        0.3800     5        0.3881        0.3800        5    2.07%                        0             0
# Elapsed time = 0.06 sec. (1.61 ticks, tree = 0.01 MB, solutions = 1)
#    5219   978        0.3868    14        0.3881        0.3829    18449    1.32%           rho_4 U   5219   3382     41
#
# Mixed integer rounding cuts applied:  1
# User cuts applied:  45
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (1.61 ticks)
# Sequential b&c:
#   Real time             =    0.41 sec. (328.32 ticks)
#                           ------------
# Total (root+branch&cut) =    0.47 sec. (329.93 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-3 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_age_first_offense<=30                      |         1 points |   + ..... |
# | prior_conviction_M>=7                        |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 06:04 PM | 901 rows in lookup table
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | runnning initialization procedure
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | CPA produced 2 cuts
# 08/17/19 @ 06:04 PM | running naive rounding on 49 solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3646
# 08/17/19 @ 06:04 PM | rounding produced 3 integer solutions
# 08/17/19 @ 06:04 PM | best objective value is 0.3725
# 08/17/19 @ 06:04 PM | running sequential rounding on 49 solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3646
# 08/17/19 @ 06:04 PM | sequential rounding produced 5 integer solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3719
# 08/17/19 @ 06:04 PM | polishing 8 solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3719
# 08/17/19 @ 06:04 PM | polishing produced 5 integer solutions
# 08/17/19 @ 06:04 PM | initialization produced 8 feasible solutions
# 08/17/19 @ 06:04 PM | best objective value: 0.3719
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | completed initialization procedure
# 08/17/19 @ 06:04 PM | ------------------------------------------------------------
# 08/17/19 @ 06:04 PM | 901 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.36423026069582565
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.37192086224429777
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 06:04 PM | adding 104 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.3719.
# Tried aggregator 1 time.
# Reduced MIP has 22 rows, 44 columns, and 83 nonzeros.
# Reduced MIP has 20 binaries, 22 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.3719        0.3612             2.87%
#       0     0        0.3642     1        0.3719        0.3642        1    2.07%
#       0     2        0.3642     4        0.3719        0.3642        1    2.07%                        0             0
# Elapsed time = 0.08 sec. (0.84 ticks, tree = 0.01 MB, solutions = 1)
#    5033  1154        0.3669     7        0.3719        0.3642    19748    2.07%          rho_14 D   5033   5032     18
#
# Implied bound cuts applied:  1
# User cuts applied:  45
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (0.84 ticks)
# Sequential b&c:
#   Real time             =    0.50 sec. (405.45 ticks)
#                           ------------
# Total (root+branch&cut) =    0.56 sec. (406.29 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-3 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_age_first_offense<=30                      |         1 points |   + ..... |
# | prior_conviction_M>=7                        |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+

# %%
np.mean(train_auc), np.mean(test_auc)
# Out:
# (0.5739227249170695, 0.5509074533550342)

# %% [markdown]
# ### Save Results

# %%
#log model results to the model performance folder, as per standards
path = "C:\\Users\\binha\\Documents\\Duke\\Cynthia Research\\KY-analysis-mytrials\\broward\\broward models\\model results\\Advanced Models\\Six Month\\"
results = [["Misdemeanor", np.mean(train_auc), np.std(train_auc), np.mean(test_auc), np.std(test_auc)]]
with open(path + 'Six Month RiskSLIM.csv', 'a') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(results)
