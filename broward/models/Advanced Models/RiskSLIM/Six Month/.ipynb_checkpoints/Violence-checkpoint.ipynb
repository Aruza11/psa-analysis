# %%
import numpy as np
import pandas as pd
import RiskSLIM as risk
import csv

from riskslim.helper_functions import load_data_from_csv, print_model
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.utils import shuffle

# %% [markdown]
# ### Lasso Feature Selection

# %%
## load stumps data
data = pd.read_csv("~/Documents/Duke/Cynthia Research/KY-analysis-mytrials/broward/data/broward_stumps.csv")
X, Y = data.loc[:,:'five_year>=1'], data['recid_violent6'].values
cols = X.columns

# %%
## lasso
lasso = Lasso(random_state=816, alpha=0.01).fit(X, Y)
selected_features = cols[lasso.coef_ != 0].tolist()
len(selected_features), roc_auc_score(Y, lasso.predict(X))
# Out:
# (13, 0.7239409184071006)

# %% [markdown]
# #### subset features

# %%
### Subset features
selected_features.insert(0, 'recid_violent6')
sub_data = data[selected_features]
sub_X, sub_Y = sub_data.iloc[:,1:], sub_data.iloc[:,0].values
sub_X.insert(0, '(Intercept)', 1)

# %% [markdown]
# ### Cross Validation

# %%
SLIM_X, SLIM_Y = sub_X.values, sub_Y.reshape(-1,1)
variable_names = sub_X.columns.tolist()
outcome_name = 'recid_violent6'
sample_weights = np.repeat(1, len(sub_Y))

# %%
#cv = KFold(n_splits=5, random_state=816, shuffle=True)
cv = KFold(n_splits=5, random_state=816, shuffle=True)
train_auc, test_auc = [], []

i = 0
for train, test in cv.split(SLIM_X, SLIM_Y):
    
    ## subset train data & store test data
    X_train, Y_train = SLIM_X[train], SLIM_Y[train]
    X_test, Y_test = SLIM_X[test], SLIM_Y[test]
    sample_weights_train, sample_weights_test = sample_weights[train], sample_weights[test]

    ## create new data dictionary
    new_train_data = {
        'X': X_train,
        'Y': Y_train,
        'variable_names': variable_names,
        'outcome_name': outcome_name,
        'sample_weights': sample_weights_train
    }
        
    ## fit the model
    model_info, mip_info, lcpa_info = risk.risk_slim(new_train_data, max_coefficient=20, max_L0_value=10, 
                                                c0_value=1e-6, max_runtime=200)
    print_model(model_info['solution'], new_train_data)
    
    ## change data format
    X_train, X_test = X_train[:,1:], X_test[:,1:] ## remove the first column, which is "intercept"
    Y_train[Y_train == -1] = 0 ## change -1 to 0
    Y_test[Y_test == -1] = 0
    
    ## probability & accuracy
    train_prob = risk.riskslim_prediction(X_train, cols, model_info).reshape(-1,1)
    test_prob = risk.riskslim_prediction(X_test, cols, model_info).reshape(-1,1)
    
    ## AUC
    train_auc.append(roc_auc_score(Y_train, train_prob))
    test_auc.append(roc_auc_score(Y_test, test_prob))
# Out:
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:47 PM | 621 rows in lookup table
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | runnning initialization procedure
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | CPA produced 2 cuts
# 08/17/19 @ 05:47 PM | running naive rounding on 104 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2677
# 08/17/19 @ 05:47 PM | rounding produced 1 integer solutions
# 08/17/19 @ 05:47 PM | best objective value is 0.3057
# 08/17/19 @ 05:47 PM | running sequential rounding on 104 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2677
# 08/17/19 @ 05:47 PM | sequential rounding produced 2 integer solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2706
# 08/17/19 @ 05:47 PM | polishing 3 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2706
# 08/17/19 @ 05:47 PM | polishing produced 3 integer solutions
# 08/17/19 @ 05:47 PM | initialization produced 4 feasible solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2706
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | completed initialization procedure
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | 621 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.26771892919708407
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.2705899789292156
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:47 PM | adding 103 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.2706.
# Tried aggregator 1 time.
# Reduced MIP has 15 rows, 30 columns, and 55 nonzeros.
# Reduced MIP has 13 binaries, 15 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.03 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.2706        0.2677             1.06%
#       0     0        0.2677     1        0.2706        0.2677        1    1.06%
#       0     2        0.2677     5        0.2706        0.2677        1    1.06%                        0             0
# Elapsed time = 0.05 sec. (0.68 ticks, tree = 0.01 MB, solutions = 1)
#
# Implied bound cuts applied:  1
# User cuts applied:  40
#
# Root node processing (before b&c):
#   Real time             =    0.05 sec. (0.68 ticks)
# Sequential b&c:
#   Real time             =    0.08 sec. (13.71 ticks)
#                           ------------
# Total (root+branch&cut) =    0.13 sec. (14.38 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | current_violent>=1                           |         1 points |   + ..... |
# | violent_conviction>=1                        |         1 points |   + ..... |
# | p_property>=5                                |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:47 PM | 621 rows in lookup table
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | runnning initialization procedure
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | CPA produced 2 cuts
# 08/17/19 @ 05:47 PM | running naive rounding on 105 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2704
# 08/17/19 @ 05:47 PM | rounding produced 2 integer solutions
# 08/17/19 @ 05:47 PM | best objective value is 0.2935
# 08/17/19 @ 05:47 PM | running sequential rounding on 105 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2704
# 08/17/19 @ 05:47 PM | sequential rounding produced 3 integer solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2739
# 08/17/19 @ 05:47 PM | polishing 5 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2739
# 08/17/19 @ 05:47 PM | polishing produced 4 integer solutions
# 08/17/19 @ 05:47 PM | initialization produced 6 feasible solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2739
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | completed initialization procedure
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | 621 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.27039322243977942
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.27390716419672967
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:47 PM | adding 104 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.2739.
# Tried aggregator 1 time.
# Reduced MIP has 15 rows, 30 columns, and 55 nonzeros.
# Reduced MIP has 13 binaries, 15 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.03 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.2739        0.2704             1.29%
#       0     0        0.2704     1        0.2739        0.2704        1    1.28%
#       0     2        0.2704     2        0.2739        0.2704        1    1.28%                        0             0
# Elapsed time = 0.06 sec. (0.61 ticks, tree = 0.01 MB, solutions = 1)
#
# Implied bound cuts applied:  1
# User cuts applied:  51
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (0.61 ticks)
# Sequential b&c:
#   Real time             =    0.08 sec. (14.52 ticks)
#                           ------------
# Total (root+branch&cut) =    0.14 sec. (15.14 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | current_violent>=1                           |         1 points |   + ..... |
# | violent_conviction>=1                        |         1 points |   + ..... |
# | violent_conviction>=5                        |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:47 PM | 621 rows in lookup table
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | runnning initialization procedure
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | CPA produced 2 cuts
# 08/17/19 @ 05:47 PM | running naive rounding on 80 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2599
# 08/17/19 @ 05:47 PM | rounding produced 1 integer solutions
# 08/17/19 @ 05:47 PM | best objective value is 0.2785
# 08/17/19 @ 05:47 PM | running sequential rounding on 80 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2599
# 08/17/19 @ 05:47 PM | sequential rounding produced 2 integer solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2630
# 08/17/19 @ 05:47 PM | polishing 3 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2630
# 08/17/19 @ 05:47 PM | polishing produced 2 integer solutions
# 08/17/19 @ 05:47 PM | initialization produced 3 feasible solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2630
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | completed initialization procedure
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | 621 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.2598669618494216
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.26297032808628706
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:47 PM | adding 79 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.2630.
# Tried aggregator 1 time.
# Reduced MIP has 15 rows, 30 columns, and 55 nonzeros.
# Reduced MIP has 13 binaries, 15 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.03 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.2630        0.2599             1.18%
#       0     0        0.2599     1        0.2630        0.2599        1    1.18%
#       0     2        0.2599     5        0.2630        0.2599        1    1.18%                        0             0
# Elapsed time = 0.03 sec. (0.63 ticks, tree = 0.01 MB, solutions = 1)
#
# User cuts applied:  30
#
# Root node processing (before b&c):
#   Real time             =    0.03 sec. (0.63 ticks)
# Sequential b&c:
#   Real time             =    0.05 sec. (7.32 ticks)
#                           ------------
# Total (root+branch&cut) =    0.08 sec. (7.95 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | current_violent>=1                           |         1 points |   + ..... |
# | violent_conviction>=1                        |         1 points |   + ..... |
# | violent_conviction>=5                        |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:47 PM | 621 rows in lookup table
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | runnning initialization procedure
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | CPA produced 2 cuts
# 08/17/19 @ 05:47 PM | running naive rounding on 79 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2783
# 08/17/19 @ 05:47 PM | rounding produced 1 integer solutions
# 08/17/19 @ 05:47 PM | best objective value is 0.2897
# 08/17/19 @ 05:47 PM | running sequential rounding on 79 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2783
# 08/17/19 @ 05:47 PM | sequential rounding produced 1 integer solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2897
# 08/17/19 @ 05:47 PM | polishing 2 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2897
# 08/17/19 @ 05:47 PM | polishing produced 2 integer solutions
# 08/17/19 @ 05:47 PM | initialization produced 3 feasible solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2895
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | completed initialization procedure
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | 621 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.27825109767695982
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.28954632902177024
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:47 PM | adding 78 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.2895.
# Tried aggregator 1 time.
# Reduced MIP has 15 rows, 30 columns, and 55 nonzeros.
# Reduced MIP has 13 binaries, 15 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.03 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.2895        0.2782             3.90%
#       0     0        0.2783     1        0.2895        0.2783        1    3.90%
#       0     0        0.2783     1        0.2895      Fract: 2        3    3.90%
#       0     0        0.2783     5        0.2895    MIRcuts: 1        5    3.90%
#       0     2        0.2783     5        0.2895        0.2783        5    3.90%                        0             0
# Elapsed time = 0.05 sec. (0.83 ticks, tree = 0.01 MB, solutions = 1)
# *    12     8      integral     0        0.2846        0.2783       21    2.24%
# *   121    28      integral     0        0.2833        0.2783      303    1.78%           rho_3 U    121    120     13
#
# Mixed integer rounding cuts applied:  1
# Gomory fractional cuts applied:  1
# User cuts applied:  48
#
# Root node processing (before b&c):
#   Real time             =    0.05 sec. (0.83 ticks)
# Sequential b&c:
#   Real time             =    0.06 sec. (16.48 ticks)
#                           ------------
# Total (root+branch&cut) =    0.11 sec. (17.31 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | current_violent>=1                           |         1 points |   + ..... |
# | violent_conviction>=3                        |         1 points |   + ..... |
# | p_stealing>=1                                |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:47 PM | 621 rows in lookup table
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | runnning initialization procedure
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | CPA produced 2 cuts
# 08/17/19 @ 05:47 PM | running naive rounding on 114 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2656
# 08/17/19 @ 05:47 PM | rounding produced 1 integer solutions
# 08/17/19 @ 05:47 PM | best objective value is 0.3097
# 08/17/19 @ 05:47 PM | running sequential rounding on 114 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2656
# 08/17/19 @ 05:47 PM | sequential rounding produced 1 integer solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2686
# 08/17/19 @ 05:47 PM | polishing 2 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2686
# 08/17/19 @ 05:47 PM | polishing produced 2 integer solutions
# 08/17/19 @ 05:47 PM | initialization produced 3 feasible solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.2686
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | completed initialization procedure
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | 621 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.26560169519384341
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.26864268078320075
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:47 PM | adding 113 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.2686.
# Tried aggregator 1 time.
# Reduced MIP has 15 rows, 30 columns, and 55 nonzeros.
# Reduced MIP has 13 binaries, 15 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.03 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.2686        0.2656             1.14%
#       0     0        0.2656     1        0.2686        0.2656        1    1.13%
#       0     2        0.2656     5        0.2686        0.2656        1    1.13%                        0             0
# Elapsed time = 0.06 sec. (0.71 ticks, tree = 0.01 MB, solutions = 1)
#
# User cuts applied:  44
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (0.71 ticks)
# Sequential b&c:
#   Real time             =    0.08 sec. (25.09 ticks)
#                           ------------
# Total (root+branch&cut) =    0.14 sec. (25.80 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | current_violent>=1                           |         1 points |   + ..... |
# | violent_conviction>=1                        |         1 points |   + ..... |
# | p_stealing>=4                                |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+

# %%
np.mean(train_auc), np.mean(test_auc)
# Out:
# (0.6877171122405812, 0.6640677335416095)

# %% [markdown]
# ### Save Results

# %%
#log model results to the model performance folder, as per standards
path = "C:\\Users\\binha\\Documents\\Duke\\Cynthia Research\\KY-analysis-mytrials\\broward\\broward models\\model results\\Advanced Models\\Six Month\\"
results = [["Violence", np.mean(train_auc), np.std(train_auc), np.mean(test_auc), np.std(test_auc)]]
with open(path + 'Six Month RiskSLIM.csv', 'a') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(results)
