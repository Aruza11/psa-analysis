# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv

from sklearn.linear_model import Lasso

from pprint import pprint
from riskslim.helper_functions import load_data_from_csv, print_model
from riskslim.setup_functions import get_conservative_offset
from riskslim.coefficient_set import CoefficientSet
from riskslim.lattice_cpa import run_lattice_cpa
from riskslim.lattice_cpa import setup_lattice_cpa, finish_lattice_cpa

from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.utils import shuffle

# %% [markdown]
# ### Modeling -- RiskSLIM

# %%
def risk_slim(data, max_coefficient, max_L0_value, c0_value, max_runtime = 120, w_pos = 1, max_offset=50):
    
    
    """
    @parameters:
    
    max_coefficient:  value of largest/smallest coefficient
    max_L0_value:     maximum model size (set as float(inf))
    max_offset:       maximum value of offset parameter (optional)
    c0_value:         L0-penalty parameter such that c0_value > 0; larger values -> 
                      sparser models; we set to a small value (1e-6) so that we get a model with max_L0_value terms
    max_runtime:      max algorithm running time
    w_pos:            relative weight on examples with y = +1; w_neg = 1.00 (optional)
    
    """
    
    # create coefficient set and set the value of the offset parameter
    coef_set = CoefficientSet(variable_names = data['variable_names'], lb = 0, ub = max_coefficient, sign = 0)
    conservative_offset = get_conservative_offset(data, coef_set, max_L0_value)
    max_offset = min(max_offset, conservative_offset)
    coef_set['(Intercept)'].ub = max_offset
    coef_set['(Intercept)'].lb = -max_offset

    constraints = {
        'L0_min': 0,
        'L0_max': max_L0_value,
        'coef_set':coef_set,
    }
    
    # Set parameters
    settings = {
        # Problem Parameters
        'c0_value': c0_value,
        'w_pos': w_pos,

        # LCPA Settings
        'max_runtime': max_runtime,                         # max runtime for LCPA
        'max_tolerance': np.finfo('float').eps,             # tolerance to stop LCPA (set to 0 to return provably optimal solution)
        'display_cplex_progress': True,                     # print CPLEX progress on screen
        'loss_computation': 'lookup',                       # how to compute the loss function ('normal','fast','lookup')
        
        # LCPA Improvements
        'round_flag': False,                                # round continuous solutions with SeqRd
        'polish_flag': False,                               # polish integer feasible solutions with DCD
        'chained_updates_flag': False,                      # use chained updates
        'add_cuts_at_heuristic_solutions': True,            # add cuts at integer feasible solutions found using polishing/rounding
        
        # Initialization
        'initialization_flag': True,                        # use initialization procedure
        'init_max_runtime': 300.0,                          # max time to run CPA in initialization procedure
        'init_max_coefficient_gap': 0.49,

        # CPLEX Solver Parameters
        'cplex_randomseed': 0,                              # random seed
        'cplex_mipemphasis': 0,                             # cplex MIP strategy
    }
    

    # train model using lattice_cpa
    model_info, mip_info, lcpa_info = run_lattice_cpa(data, constraints, settings)
        
    return model_info, mip_info, lcpa_info

# %%
def riskslim_prediction(X, feature_name, model_info):
    
    """
    @parameters
    
    X: test input features (np.array)
    feature_name: feature names
    model_info: output from RiskSLIM model
    
    """
    
    ## initialize parameters
    dictionary = {}
    prob = np.zeros(len(X))
    scores = np.zeros(len(X))
    
    ## prepare statistics
    subtraction_score = model_info['solution'][0]
    coefs = model_info['solution'][1:]
    index = np.where(coefs != 0)[0]
    
    nonzero_coefs = coefs[index]
    features = feature_name[index]
    X_sub = X[:,index]
    
    ## build dictionaries
    for i in range(len(features)):
        single_feature = features[i]
        coef = nonzero_coefs[i]
        dictionary.update({single_feature: coef})
        
    ## calculate probability
    for i in range(len(X_sub)):
        summation = 0
        for j in range(len(features)):
            a = X_sub[i,j]
            summation += dictionary[features[j]] * a
        scores[i] = summation
    
    prob = 1/(1+np.exp(-(scores + subtraction_score)))
    
    return prob

# %%
def riskslim_accuracy(X, Y, feature_name, model_info, threshold=0.5):
    
    prob = riskslim_prediction(X, feature_name, model_info)
    pred = np.mean((prob > threshold) == Y)
    
    return pred

# %% [markdown]
# ### Lasso Feature Selection

# %%
## load stumps data
data = pd.read_csv("~/Documents/Duke/Cynthia Research/KY-analysis-mytrials/broward/data/broward_stumps.csv")
X, Y = data.loc[:,:'five_year>=1'], data['recid_six_month'].values
cols = X.columns

# %%
## lasso
lasso = Lasso(random_state=816, alpha=0.02).fit(X, Y)
selected_features = cols[lasso.coef_ != 0].tolist()
len(selected_features), roc_auc_score(Y, lasso.predict(X))
# Out:
# (11, 0.6471696225906974)

# %% [markdown]
# #### subset features

# %%
### Subset features
selected_features.insert(0, 'recid_six_month')
sub_data = data[selected_features]
sub_X, sub_Y = sub_data.iloc[:,1:], sub_data.iloc[:,0].values
sub_X.insert(0, '(Intercept)', 1)

# %% [markdown]
# ### Cross Validation

# %%
SLIM_X, SLIM_Y = sub_X.values, sub_Y.reshape(-1,1)
variable_names = sub_X.columns.tolist()
outcome_name = 'recid_six_month'
sample_weights = np.repeat(1, len(sub_Y))

# %%
#cv = KFold(n_splits=5, random_state=816, shuffle=True)
cv = KFold(n_splits=5, random_state=816, shuffle=True)
train_auc, test_auc = [], []

i = 0
for train, test in cv.split(SLIM_X, SLIM_Y):
    
    ## subset train data & store test data
    X_train, Y_train = SLIM_X[train], SLIM_Y[train]
    X_test, Y_test = SLIM_X[test], SLIM_Y[test]
    sample_weights_train, sample_weights_test = sample_weights[train], sample_weights[test]

    ## create new data dictionary
    new_train_data = {
        'X': X_train,
        'Y': Y_train,
        'variable_names': variable_names,
        'outcome_name': outcome_name,
        'sample_weights': sample_weights_train
    }
        
    ## fit the model
    model_info, mip_info, lcpa_info = risk_slim(new_train_data, max_coefficient=20, max_L0_value=10, 
                                                c0_value=1e-6, max_runtime=200)
    print_model(model_info['solution'], new_train_data)
    
    ## change data format
    X_train, X_test = X_train[:,1:], X_test[:,1:] ## remove the first column, which is "intercept"
    Y_train[Y_train == -1] = 0 ## change -1 to 0
    Y_test[Y_test == -1] = 0
    
    ## probability & accuracy
    train_prob = riskslim_prediction(X_train, cols, model_info).reshape(-1,1)
    test_prob = riskslim_prediction(X_test, cols, model_info).reshape(-1,1)
    
    ## AUC
    train_auc.append(roc_auc_score(Y_train, train_prob))
    test_auc.append(roc_auc_score(Y_test, test_prob))
# Out:
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:46 PM | 541 rows in lookup table
# 08/17/19 @ 05:46 PM | ------------------------------------------------------------
# 08/17/19 @ 05:46 PM | runnning initialization procedure
# 08/17/19 @ 05:46 PM | ------------------------------------------------------------
# 08/17/19 @ 05:46 PM | CPA produced 2 cuts
# 08/17/19 @ 05:46 PM | running naive rounding on 69 solutions
# 08/17/19 @ 05:46 PM | best objective value: 0.5045
# 08/17/19 @ 05:46 PM | rounding produced 1 integer solutions
# 08/17/19 @ 05:46 PM | best objective value is 0.5258
# 08/17/19 @ 05:46 PM | running sequential rounding on 69 solutions
# 08/17/19 @ 05:46 PM | best objective value: 0.5045
# 08/17/19 @ 05:46 PM | sequential rounding produced 1 integer solutions
# 08/17/19 @ 05:46 PM | best objective value: 0.5141
# 08/17/19 @ 05:46 PM | polishing 2 solutions
# 08/17/19 @ 05:46 PM | best objective value: 0.5141
# 08/17/19 @ 05:46 PM | polishing produced 2 integer solutions
# 08/17/19 @ 05:46 PM | initialization produced 2 feasible solutions
# 08/17/19 @ 05:46 PM | best objective value: 0.5141
# 08/17/19 @ 05:46 PM | ------------------------------------------------------------
# 08/17/19 @ 05:46 PM | completed initialization procedure
# 08/17/19 @ 05:46 PM | ------------------------------------------------------------
# 08/17/19 @ 05:46 PM | 541 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.50449805688726823
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.51409153057850943
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:46 PM | adding 68 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.5141.
# Tried aggregator 1 time.
# Reduced MIP has 13 rows, 26 columns, and 47 nonzeros.
# Reduced MIP has 11 binaries, 13 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (0.02 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.5141        0.5045             1.87%
#       0     0        0.5045     1        0.5141        0.5045        1    1.87%
#       0     0        0.5045     4        0.5141       Cuts: 2        3    1.87%
#       0     0        0.5045     5        0.5141    MIRcuts: 1        5    1.87%
#       0     2        0.5045     5        0.5141        0.5045        5    1.87%                        0             0
# Elapsed time = 0.05 sec. (0.79 ticks, tree = 0.01 MB, solutions = 1)
#
# Mixed integer rounding cuts applied:  1
# Gomory fractional cuts applied:  1
# User cuts applied:  28
#
# Root node processing (before b&c):
#   Real time             =    0.03 sec. (0.79 ticks)
# Sequential b&c:
#   Real time             =    0.27 sec. (151.48 ticks)
#                           ------------
# Total (root+branch&cut) =    0.30 sec. (152.27 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-2 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | prior_conviction_M>=7                        |         1 points |   + ..... |
# | six_month>=1                                 |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:47 PM | 541 rows in lookup table
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | runnning initialization procedure
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | CPA produced 2 cuts
# 08/17/19 @ 05:47 PM | running naive rounding on 83 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.4946
# 08/17/19 @ 05:47 PM | rounding produced 1 integer solutions
# 08/17/19 @ 05:47 PM | best objective value is 0.5173
# 08/17/19 @ 05:47 PM | running sequential rounding on 83 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.4946
# 08/17/19 @ 05:47 PM | sequential rounding produced 1 integer solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.5064
# 08/17/19 @ 05:47 PM | polishing 2 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.5064
# 08/17/19 @ 05:47 PM | polishing produced 2 integer solutions
# 08/17/19 @ 05:47 PM | initialization produced 2 feasible solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.5064
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | completed initialization procedure
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | 541 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.49455150252196628
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.50639089673304816
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:47 PM | adding 82 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.5064.
# Tried aggregator 1 time.
# Reduced MIP has 13 rows, 26 columns, and 47 nonzeros.
# Reduced MIP has 11 binaries, 13 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.02 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.5064        0.4945             2.34%
#       0     0        0.4946     1        0.5064        0.4946        1    2.34%
#       0     0        0.4946     4        0.5064       Cuts: 2        3    2.34%
#       0     0        0.4946     5        0.5064    MIRcuts: 2        7    2.34%
#       0     2        0.4946     5        0.5064        0.4946        7    2.34%                        0             0
# Elapsed time = 0.05 sec. (0.84 ticks, tree = 0.01 MB, solutions = 1)
#
# Mixed integer rounding cuts applied:  1
# Gomory fractional cuts applied:  1
# User cuts applied:  34
#
# Root node processing (before b&c):
#   Real time             =    0.05 sec. (0.84 ticks)
# Sequential b&c:
#   Real time             =    0.22 sec. (136.23 ticks)
#                           ------------
# Total (root+branch&cut) =    0.27 sec. (137.07 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-2 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | prior_conviction_M>=7                        |         1 points |   + ..... |
# | six_month>=1                                 |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:47 PM | 541 rows in lookup table
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | runnning initialization procedure
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | CPA produced 2 cuts
# 08/17/19 @ 05:47 PM | running naive rounding on 78 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.5054
# 08/17/19 @ 05:47 PM | rounding produced 2 integer solutions
# 08/17/19 @ 05:47 PM | best objective value is 0.5142
# 08/17/19 @ 05:47 PM | running sequential rounding on 78 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.5054
# 08/17/19 @ 05:47 PM | sequential rounding produced 1 integer solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.5142
# 08/17/19 @ 05:47 PM | polishing 3 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.5142
# 08/17/19 @ 05:47 PM | polishing produced 2 integer solutions
# 08/17/19 @ 05:47 PM | initialization produced 2 feasible solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.5142
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | completed initialization procedure
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | 541 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.50534671607195147
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.51424443995891844
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:47 PM | adding 77 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.5142.
# Tried aggregator 1 time.
# Reduced MIP has 13 rows, 26 columns, and 47 nonzeros.
# Reduced MIP has 11 binaries, 13 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.02 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.5142        0.5053             1.73%
#       0     0        0.5053     1        0.5142        0.5053        1    1.73%
#       0     0        0.5053     2        0.5142       Cuts: 3        3    1.73%
#       0     2        0.5053     2        0.5142        0.5053        3    1.73%                        0             0
# Elapsed time = 0.05 sec. (0.57 ticks, tree = 0.01 MB, solutions = 1)
#
# Mixed integer rounding cuts applied:  2
# Gomory fractional cuts applied:  1
# User cuts applied:  30
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (0.57 ticks)
# Sequential b&c:
#   Real time             =    0.14 sec. (79.77 ticks)
#                           ------------
# Total (root+branch&cut) =    0.20 sec. (80.34 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-2 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | prior_conviction_M>=7                        |         1 points |   + ..... |
# | six_month>=1                                 |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:47 PM | 541 rows in lookup table
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | runnning initialization procedure
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | CPA produced 2 cuts
# 08/17/19 @ 05:47 PM | running naive rounding on 68 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.5101
# 08/17/19 @ 05:47 PM | rounding produced 1 integer solutions
# 08/17/19 @ 05:47 PM | best objective value is 0.5329
# 08/17/19 @ 05:47 PM | running sequential rounding on 68 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.5101
# 08/17/19 @ 05:47 PM | sequential rounding produced 2 integer solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.5245
# 08/17/19 @ 05:47 PM | polishing 3 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.5245
# 08/17/19 @ 05:47 PM | polishing produced 3 integer solutions
# 08/17/19 @ 05:47 PM | initialization produced 3 feasible solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.5245
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | completed initialization procedure
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | 541 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.51002173234701198
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.52450425486644103
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:47 PM | adding 67 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.5245.
# Tried aggregator 1 time.
# Reduced MIP has 13 rows, 26 columns, and 47 nonzeros.
# Reduced MIP has 11 binaries, 13 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.02 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.5245        0.5100             2.76%
#       0     0        0.5100     1        0.5245        0.5100        1    2.76%
#       0     0        0.5100     3        0.5245      Fract: 1        2    2.76%
#       0     0        0.5100     5        0.5245    MIRcuts: 1        4    2.76%
#       0     2        0.5100     5        0.5245        0.5100        4    2.76%                        0             0
# Elapsed time = 0.03 sec. (0.78 ticks, tree = 0.01 MB, solutions = 1)
#
# Mixed integer rounding cuts applied:  1
# Gomory fractional cuts applied:  1
# User cuts applied:  39
#
# Root node processing (before b&c):
#   Real time             =    0.03 sec. (0.78 ticks)
# Sequential b&c:
#   Real time             =    0.31 sec. (221.27 ticks)
#                           ------------
# Total (root+branch&cut) =    0.34 sec. (222.05 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-2 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | prior_conviction_M>=7                        |         1 points |   + ..... |
# | six_month>=1                                 |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 05:47 PM | 541 rows in lookup table
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | runnning initialization procedure
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | CPA produced 2 cuts
# 08/17/19 @ 05:47 PM | running naive rounding on 74 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.5051
# 08/17/19 @ 05:47 PM | rounding produced 2 integer solutions
# 08/17/19 @ 05:47 PM | best objective value is 0.5411
# 08/17/19 @ 05:47 PM | running sequential rounding on 74 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.5051
# 08/17/19 @ 05:47 PM | sequential rounding produced 1 integer solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.5183
# 08/17/19 @ 05:47 PM | polishing 3 solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.5183
# 08/17/19 @ 05:47 PM | polishing produced 2 integer solutions
# 08/17/19 @ 05:47 PM | initialization produced 4 feasible solutions
# 08/17/19 @ 05:47 PM | best objective value: 0.5183
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | completed initialization procedure
# 08/17/19 @ 05:47 PM | ------------------------------------------------------------
# 08/17/19 @ 05:47 PM | 541 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.50509871816579477
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.5183441302494729
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 05:47 PM | adding 73 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.5183.
# Tried aggregator 1 time.
# Reduced MIP has 13 rows, 26 columns, and 47 nonzeros.
# Reduced MIP has 11 binaries, 13 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.02 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.5183        0.5051             2.56%
#       0     0        0.5051     1        0.5183        0.5051        1    2.56%
#       0     0        0.5051     4        0.5183       Cuts: 3        3    2.56%
#       0     0        0.5051     5        0.5183    MIRcuts: 1        5    2.56%
#       0     2        0.5051     5        0.5183        0.5051        5    2.56%                        0             0
# Elapsed time = 0.05 sec. (0.77 ticks, tree = 0.01 MB, solutions = 1)
#    7044   291        cutoff              0.5183        0.5136    17279    0.92%           rho_3 U   7044   1613     34
#
# Implied bound cuts applied:  1
# Mixed integer rounding cuts applied:  1
# Gomory fractional cuts applied:  1
# User cuts applied:  36
#
# Root node processing (before b&c):
#   Real time             =    0.05 sec. (0.78 ticks)
# Sequential b&c:
#   Real time             =    0.34 sec. (250.75 ticks)
#                           ------------
# Total (root+branch&cut) =    0.39 sec. (251.52 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-2 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | prior_conviction_M>=7                        |         1 points |   + ..... |
# | six_month>=1                                 |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+

# %%
np.mean(train_auc), np.mean(test_auc)
# Out:
# (0.600298041139269, 0.6006597522736927)

# %% [markdown]
# ### Save Results

# %%
#log model results to the model performance folder, as per standards
path = "C:\\Users\\binha\\Documents\\Duke\\Cynthia Research\\KY-analysis-mytrials\\broward\\broward models\\model results\\Advanced Models\\Six Month\\"
results = [["Model", "train_auc_mean", "train_auc_std","test_auc_mean", "test_auc_std"],
    ["Recidivism", np.mean(train_auc), np.std(train_auc), np.mean(test_auc), np.std(test_auc)]]
with open(path + 'Six Month RiskSLIM.csv', 'w') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(results)
