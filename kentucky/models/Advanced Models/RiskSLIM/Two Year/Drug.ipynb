# %%
import numpy as np
import pandas as pd
import RiskSLIM as risk
import csv

from riskslim.helper_functions import load_data_from_csv, print_model
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.utils import shuffle

# %% [markdown]
# ### Lasso Feature Selection

# %%
## load stumps data
data = pd.read_csv("C:/Users/binha/Documents/Duke/Cynthia Research/KY-analysis-mytrials/KY Recidivism/KY data/kentucky_stumps.csv")
X, Y = data.loc[:,:'current_violence>=1'], data['recid_drug_two_year'].values
cols = X.columns

# %%
## lasso
lasso = Lasso(random_state=816, alpha=0.001).fit(X, Y)
selected_features = cols[lasso.coef_ != 0].tolist()
len(selected_features), roc_auc_score(Y, lasso.predict(X))
# Out:
# (30, 0.6992766913304036)

# %% [markdown]
# #### subset features

# %%
### Subset features
selected_features.insert(0, 'recid_drug_two_year')
sub_data = data[selected_features]
sub_X, sub_Y = sub_data.iloc[:,1:], sub_data.iloc[:,0].values
sub_X.insert(0, '(Intercept)', 1)

# %% [markdown]
# ### Cross Validation

# %%
SLIM_X, SLIM_Y = sub_X.values, sub_Y.reshape(-1,1)
variable_names = sub_X.columns.tolist()
outcome_name = 'recid_drug_two_year'
sample_weights = np.repeat(1, len(sub_Y))

# %%
#cv = KFold(n_splits=5, random_state=816, shuffle=True)
cv = KFold(n_splits=5, random_state=816, shuffle=True)
train_auc, test_auc = [], []

i = 0
for train, test in cv.split(SLIM_X, SLIM_Y):
    
    ## subset train data & store test data
    X_train, Y_train = SLIM_X[train], SLIM_Y[train]
    X_test, Y_test = SLIM_X[test], SLIM_Y[test]
    sample_weights_train, sample_weights_test = sample_weights[train], sample_weights[test]

    ## create new data dictionary
    new_train_data = {
        'X': X_train,
        'Y': Y_train,
        'variable_names': variable_names,
        'outcome_name': outcome_name,
        'sample_weights': sample_weights_train
    }
        
    ## fit the model
    model_info, mip_info, lcpa_info = risk.risk_slim(new_train_data, max_coefficient=20, max_L0_value=10, 
                                                c0_value=1e-5, max_runtime=400)
    print_model(model_info['solution'], new_train_data)
    
    ## change data format
    X_train, X_test = X_train[:,1:], X_test[:,1:] ## remove the first column, which is "intercept"
    Y_train[Y_train == -1] = 0 ## change -1 to 0
    Y_test[Y_test == -1] = 0
    
    ## probability & accuracy
    train_prob = risk.riskslim_prediction(X_train, cols, model_info).reshape(-1,1)
    test_prob = risk.riskslim_prediction(X_test, cols, model_info).reshape(-1,1)
    
    ## AUC
    train_auc.append(roc_auc_score(Y_train, train_prob))
    test_auc.append(roc_auc_score(Y_test, test_prob))
# Out:
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/16/19 @ 09:53 AM | 1301 rows in lookup table
# 08/16/19 @ 09:53 AM | ------------------------------------------------------------
# 08/16/19 @ 09:53 AM | runnning initialization procedure
# 08/16/19 @ 09:53 AM | ------------------------------------------------------------
# 08/16/19 @ 09:53 AM | CPA produced 2 cuts
# 08/16/19 @ 09:53 AM | running naive rounding on 87 solutions
# 08/16/19 @ 09:53 AM | best objective value: 0.2807
# 08/16/19 @ 09:53 AM | rounding produced 4 integer solutions
# 08/16/19 @ 09:53 AM | best objective value is 0.2877
# 08/16/19 @ 09:53 AM | running sequential rounding on 87 solutions
# 08/16/19 @ 09:53 AM | best objective value: 0.2807
# 08/16/19 @ 09:54 AM | sequential rounding produced 3 integer solutions
# 08/16/19 @ 09:54 AM | best objective value: 0.2877
# 08/16/19 @ 09:54 AM | polishing 7 solutions
# 08/16/19 @ 09:54 AM | best objective value: 0.2877
# 08/16/19 @ 09:54 AM | polishing produced 5 integer solutions
# 08/16/19 @ 09:54 AM | initialization produced 8 feasible solutions
# 08/16/19 @ 09:54 AM | best objective value: 0.2877
# 08/16/19 @ 09:54 AM | ------------------------------------------------------------
# 08/16/19 @ 09:54 AM | completed initialization procedure
# 08/16/19 @ 09:54 AM | ------------------------------------------------------------
# 08/16/19 @ 09:54 AM | 1301 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               400
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.27962029645570474
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.28767029488137796
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/16/19 @ 09:54 AM | adding 249 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.2877.
# Tried aggregator 1 time.
# Reduced MIP has 32 rows, 64 columns, and 123 nonzeros.
# Reduced MIP has 30 binaries, 32 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.07 ticks)
# Probing time = 0.00 sec. (0.02 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.04 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.2877        0.2795             2.83%
#       0     0        0.2796     1        0.2877        0.2796        1    2.80%
#       0     0        0.2796     1        0.2877      Fract: 1        3    2.80%
#       0     2        0.2796     2        0.2877        0.2796        3    2.80%                        0             0
# Elapsed time = 0.11 sec. (1.93 ticks, tree = 0.01 MB, solutions = 1)
#    2088   728        0.2858     6        0.2877        0.2796     9158    2.80%          rho_29 D   2088   2087     31
#    3012  1101        0.2806    11        0.2877        0.2796    14790    2.80%           rho_0 D   3012   1492     14
# *  3230+ 1046                            0.2864        0.2796             2.38%
#    3770  1205        0.2839     9        0.2864        0.2796    19313    2.38%          rho_16 D   3770   3769     22
#    4434  1433        0.2817    19        0.2864        0.2796    24058    2.38%           rho_4 D   4434   4433     18
#    5095  1598        0.2828    11        0.2864        0.2796    28557    2.38%          rho_14 D   5095   5094     24
# *  5250+ 1576                            0.2861        0.2796             2.25%
#    5665  1712        0.2856    11        0.2861        0.2796    32613    2.25%          rho_11 D   5665   5663     23
#    6240  1893        cutoff              0.2861        0.2796    36699    2.25%           rho_4 U   6240   6239     17
#    6841  2038        0.2815    15        0.2861        0.2799    40473    2.16%           rho_0 D   6841   4475     13
#    7465  2150        cutoff              0.2861        0.2802    43901    2.05%          rho_20 D   7465   7464     29
#    9830  2227        cutoff              0.2861        0.2816    57380    1.56%           rho_2 U   9830   9829     20
# Elapsed time = 4.03 sec. (3103.98 ticks, tree = 0.71 MB, solutions = 3)
#   12214  2068        cutoff              0.2861        0.2828    70653    1.14%          rho_20 D  12214  12213     29
#   14496  1559        cutoff              0.2861        0.2839    82147    0.75%           rho_2 U  14496   6882     22
#   16787   404        cutoff              0.2861        0.2855    91726    0.21%          rho_12 D  16787  16785     29
#
# Gomory fractional cuts applied:  1
# User cuts applied:  524
#
# Root node processing (before b&c):
#   Real time             =    0.13 sec. (1.98 ticks)
# Sequential b&c:
#   Real time             =    6.38 sec. (6133.88 ticks)
#                           ------------
# Total (root+branch&cut) =    6.50 sec. (6135.86 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | age_at_current_charge<=52                    |         1 points |   + ..... |
# | p_arrest>=3                                  |         1 points |   + ..... |
# | p_drug>=1                                    |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/16/19 @ 09:54 AM | 1301 rows in lookup table
# 08/16/19 @ 09:54 AM | ------------------------------------------------------------
# 08/16/19 @ 09:54 AM | runnning initialization procedure
# 08/16/19 @ 09:54 AM | ------------------------------------------------------------
# 08/16/19 @ 09:54 AM | CPA produced 2 cuts
# 08/16/19 @ 09:54 AM | running naive rounding on 81 solutions
# 08/16/19 @ 09:54 AM | best objective value: 0.2801
# 08/16/19 @ 09:54 AM | rounding produced 4 integer solutions
# 08/16/19 @ 09:54 AM | best objective value is 0.2900
# 08/16/19 @ 09:54 AM | running sequential rounding on 81 solutions
# 08/16/19 @ 09:54 AM | best objective value: 0.2801
# 08/16/19 @ 09:54 AM | sequential rounding produced 5 integer solutions
# 08/16/19 @ 09:54 AM | best objective value: 0.2880
# 08/16/19 @ 09:54 AM | polishing 9 solutions
# 08/16/19 @ 09:54 AM | best objective value: 0.2880
# 08/16/19 @ 09:54 AM | polishing produced 5 integer solutions
# 08/16/19 @ 09:54 AM | initialization produced 11 feasible solutions
# 08/16/19 @ 09:54 AM | best objective value: 0.2880
# 08/16/19 @ 09:54 AM | ------------------------------------------------------------
# 08/16/19 @ 09:54 AM | completed initialization procedure
# 08/16/19 @ 09:54 AM | ------------------------------------------------------------
# 08/16/19 @ 09:54 AM | 1301 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               400
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.27851048469939155
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.2879721250663434
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/16/19 @ 09:54 AM | adding 249 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.2880.
# Tried aggregator 1 time.
# Reduced MIP has 32 rows, 64 columns, and 123 nonzeros.
# Reduced MIP has 30 binaries, 32 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.07 ticks)
# Probing time = 0.00 sec. (0.02 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.04 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.2880        0.2784             3.32%
#       0     0        0.2785     1        0.2880        0.2785        1    3.29%
#       0     0        0.2785     1        0.2880      Fract: 1        3    3.29%
#       0     2        0.2785     2        0.2880        0.2785        3    3.29%                        0             0
# Elapsed time = 0.11 sec. (1.93 ticks, tree = 0.01 MB, solutions = 1)
# *    80+   44                            0.2878        0.2785             3.24%
# *   150+   92                            0.2878        0.2785             3.21%
# *   718   361      integral     0        0.2872        0.2785     2472    3.02%
# *  1210+  490                            0.2857        0.2785             2.52%
# *  1219   494      integral     0        0.2856        0.2785     4509    2.50%
#    1816   665        cutoff              0.2856        0.2785     7479    2.50%           rho_0 U   1816   1814     23
#    2788  1000        0.2800     9        0.2856        0.2785    13365    2.50%           rho_0 D   2788   2786     21
# *  3110+ 1088                            0.2856        0.2785             2.49%
# *  3210+ 1097                            0.2856        0.2785             2.49%
#    3559  1237        0.2828     6        0.2856        0.2785    18260    2.49%          rho_14 D   3559   3557     30
#    4249  1490        cutoff              0.2856        0.2785    23214    2.49%          rho_20 U   4249   4248     17
#    4868  1745        cutoff              0.2856        0.2785    28440    2.49%          rho_20 U   4868   4867     29
#    5461  1918        0.2785    10        0.2856        0.2785    33111    2.49%           rho_0 D   5461   5457     15
#    6019  2132        0.2813    12        0.2856        0.2785    38111    2.49%          rho_16 U   6019   6017     21
#    6580  2289        0.2804    14        0.2856        0.2785    42537    2.49%           rho_1 D   6580   6579     20
#    7100  2446        0.2853     0        0.2856        0.2785    47143    2.49%           rho_8 D   7100   7099     28
#    8998  3097        cutoff              0.2856        0.2785    64619    2.49%           rho_7 U   8998   8997     23
# Elapsed time = 4.19 sec. (3105.72 ticks, tree = 0.92 MB, solutions = 8)
# *  9992  3282      integral     0        0.2853        0.2785    73779    2.37%
#   10881  3513        0.2833    13        0.2853        0.2785    81640    2.37%          rho_14 U  10881    480     23
#   12800  3933        0.2845     8        0.2853        0.2791    95877    2.18%          rho_20 U  12800  12799     30
#   14732  4128        0.2809    12        0.2853        0.2797   109530    1.94%           rho_3 D  14732   9879     21
#   16628  4232        cutoff              0.2853        0.2803   122353    1.74%           rho_0 U  16628  16626     23
#   18505  4287        0.2852     8        0.2853        0.2808   134493    1.57%           rho_1 U  18505   4358     18
#   20356  4266        0.2845     7        0.2853        0.2813   146197    1.40%           rho_2 U  20356  20355     20
#   22201  4145        0.2845    17        0.2853        0.2817   157435    1.24%          rho_18 D  22201  22200     20
#   24099  3802        cutoff              0.2853        0.2823   168191    1.06%           rho_4 U  24099  10525     25
#   25928  3426        0.2839     5        0.2853        0.2827   178648    0.90%           rho_8 U  25928  17440     26
#   27783  2897        cutoff              0.2853        0.2832   188497    0.72%          rho_16 U  27783  27781     20
# Elapsed time = 12.66 sec. (12647.00 ticks, tree = 1.08 MB, solutions = 9)
#   29713  2104        cutoff              0.2853        0.2839   198010    0.50%          rho_30 D  29713   1025     35
#   31804   871        cutoff              0.2853        0.2846   206633    0.24%           rho_8 U  31804  17787     19
#
# Gomory fractional cuts applied:  1
# User cuts applied:  612
#
# Root node processing (before b&c):
#   Real time             =    0.11 sec. (1.99 ticks)
# Sequential b&c:
#   Real time             =   14.38 sec. (15021.21 ticks)
#                           ------------
# Total (root+branch&cut) =   14.48 sec. (15023.20 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | age_at_current_charge<=52                    |         1 points |   + ..... |
# | p_arrest>=3                                  |         1 points |   + ..... |
# | p_drug>=1                                    |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/16/19 @ 09:54 AM | 1301 rows in lookup table
# 08/16/19 @ 09:54 AM | ------------------------------------------------------------
# 08/16/19 @ 09:54 AM | runnning initialization procedure
# 08/16/19 @ 09:54 AM | ------------------------------------------------------------
# 08/16/19 @ 09:54 AM | CPA produced 2 cuts
# 08/16/19 @ 09:54 AM | running naive rounding on 82 solutions
# 08/16/19 @ 09:54 AM | best objective value: 0.2800
# 08/16/19 @ 09:54 AM | rounding produced 5 integer solutions
# 08/16/19 @ 09:54 AM | best objective value is 0.2960
# 08/16/19 @ 09:54 AM | running sequential rounding on 82 solutions
# 08/16/19 @ 09:54 AM | best objective value: 0.2800
# 08/16/19 @ 09:54 AM | sequential rounding produced 5 integer solutions
# 08/16/19 @ 09:54 AM | best objective value: 0.2859
# 08/16/19 @ 09:54 AM | polishing 10 solutions
# 08/16/19 @ 09:54 AM | best objective value: 0.2859
# 08/16/19 @ 09:54 AM | polishing produced 5 integer solutions
# 08/16/19 @ 09:54 AM | initialization produced 12 feasible solutions
# 08/16/19 @ 09:54 AM | best objective value: 0.2859
# 08/16/19 @ 09:54 AM | ------------------------------------------------------------
# 08/16/19 @ 09:54 AM | completed initialization procedure
# 08/16/19 @ 09:54 AM | ------------------------------------------------------------
# 08/16/19 @ 09:54 AM | 1301 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               400
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.27917978756743272
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.285922797469708
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/16/19 @ 09:54 AM | adding 249 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.2859.
# Tried aggregator 1 time.
# Reduced MIP has 32 rows, 64 columns, and 123 nonzeros.
# Reduced MIP has 30 binaries, 32 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.07 ticks)
# Probing time = 0.00 sec. (0.02 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.04 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.2859        0.2791             2.39%
#       0     0        0.2792     1        0.2859        0.2792        1    2.36%
#       0     0        0.2792     1        0.2859      Fract: 1        3    2.36%
#       0     2        0.2792     2        0.2859        0.2792        3    2.36%                        0             0
# Elapsed time = 0.13 sec. (1.91 ticks, tree = 0.01 MB, solutions = 1)
#    1930   778        0.2836     7        0.2859        0.2792     8615    2.36%          rho_24 D   1930   1929     27
#    3050  1160        0.2853     0        0.2859        0.2792    15295    2.36%          rho_20 U   3050   3049     30
#    3943  1400        0.2799    16        0.2859        0.2792    21106    2.36%           rho_0 D   3943   3941     20
#    4677  1640        cutoff              0.2859        0.2792    26309    2.36%           rho_0 D   4677   4676     25
#    5331  1853        cutoff              0.2859        0.2792    31079    2.36%          rho_17 U   5331   5330     27
#    5981  2031        0.2845     6        0.2859        0.2792    35892    2.36%          rho_24 D   5981   5979     22
#    6583  2236        0.2843    16        0.2859        0.2792    40649    2.36%          rho_18 U   6583   6581     22
#    7170  2421        0.2857     0        0.2859        0.2792    45566    2.36%          rho_20 D   7170   7169     20
#    7780  2607        0.2816    17        0.2859        0.2792    50411    2.36%          rho_10 D   7780   7779     20
#    9965  3249        cutoff              0.2859        0.2792    68899    2.36%           rho_0 U   9965   9964     20
# Elapsed time = 4.16 sec. (3103.98 ticks, tree = 0.96 MB, solutions = 1)
#   12219  3770        cutoff              0.2859        0.2795    85933    2.24%          rho_22 D  12219  12218     23
#   14543  4100        0.2849     5        0.2859        0.2802   100009    2.00%           rho_0 D  14543  14542     22
#   16728  4359        0.2859     5        0.2859        0.2808   113694    1.79%          rho_20 D  16728  16726     26
#   18871  4551        cutoff              0.2859        0.2813   126418    1.63%          rho_14 U  18871  18868     22
#   21032  4710        0.2855    15        0.2859        0.2817   138837    1.48%          rho_13 U  21032  15602     26
#   23178  4782        cutoff              0.2859        0.2821   150717    1.34%           rho_3 U  23178  19177     23
#   25427  4837        0.2850     9        0.2859        0.2825   162332    1.21%          rho_12 D  25427  25425     29
#   27676  4822        cutoff              0.2859        0.2828   173621    1.09%          rho_13 U  27676   3045     26
#   29903  4745        0.2848     9        0.2859        0.2831   184245    0.99%          rho_25 D  29903  29901     30
#   32017  4517        cutoff              0.2859        0.2834   194705    0.88%           rho_0 U  32017  30937     18
# Elapsed time = 11.75 sec. (12642.97 ticks, tree = 1.51 MB, solutions = 1)
#   34135  4243        0.2855    19        0.2859        0.2837   204778    0.78%           rho_5 D  34135  15084     23
#   36270  3792        0.2851     9        0.2859        0.2840   214239    0.66%          rho_24 D  36270  36269     25
#   38426  3309        cutoff              0.2859        0.2843   223519    0.56%          rho_10 U  38426  38424     24
#   40672  2442        cutoff              0.2859        0.2847   232999    0.43%          rho_22 D  40672  11849     30
#   43074  1327        cutoff              0.2859        0.2852   241793    0.24%          rho_24 U  43074  23534     28
#
# Gomory fractional cuts applied:  1
# User cuts applied:  580
#
# Root node processing (before b&c):
#   Real time             =    0.13 sec. (1.96 ticks)
# Sequential b&c:
#   Real time             =   15.23 sec. (18119.67 ticks)
#                           ------------
# Total (root+branch&cut) =   15.36 sec. (18121.64 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | age_at_current_charge<=52                    |         1 points |   + ..... |
# | p_arrest>=3                                  |         1 points |   + ..... |
# | p_drug>=1                                    |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/16/19 @ 09:55 AM | 1301 rows in lookup table
# 08/16/19 @ 09:55 AM | ------------------------------------------------------------
# 08/16/19 @ 09:55 AM | runnning initialization procedure
# 08/16/19 @ 09:55 AM | ------------------------------------------------------------
# 08/16/19 @ 09:55 AM | CPA produced 2 cuts
# 08/16/19 @ 09:55 AM | running naive rounding on 77 solutions
# 08/16/19 @ 09:55 AM | best objective value: 0.2801
# 08/16/19 @ 09:55 AM | rounding produced 5 integer solutions
# 08/16/19 @ 09:55 AM | best objective value is 0.2945
# 08/16/19 @ 09:55 AM | running sequential rounding on 77 solutions
# 08/16/19 @ 09:55 AM | best objective value: 0.2801
# 08/16/19 @ 09:55 AM | sequential rounding produced 6 integer solutions
# 08/16/19 @ 09:55 AM | best objective value: 0.2876
# 08/16/19 @ 09:55 AM | polishing 11 solutions
# 08/16/19 @ 09:55 AM | best objective value: 0.2876
# 08/16/19 @ 09:55 AM | polishing produced 5 integer solutions
# 08/16/19 @ 09:55 AM | initialization produced 12 feasible solutions
# 08/16/19 @ 09:55 AM | best objective value: 0.2876
# 08/16/19 @ 09:55 AM | ------------------------------------------------------------
# 08/16/19 @ 09:55 AM | completed initialization procedure
# 08/16/19 @ 09:55 AM | ------------------------------------------------------------
# 08/16/19 @ 09:55 AM | 1301 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               400
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.27886653806447348
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.28756204821038528
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/16/19 @ 09:55 AM | adding 249 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.2876.
# Tried aggregator 1 time.
# Reduced MIP has 32 rows, 64 columns, and 123 nonzeros.
# Reduced MIP has 30 binaries, 32 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.07 ticks)
# Probing time = 0.00 sec. (0.02 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.04 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.2876        0.2788             3.06%
#       0     0        0.2789     1        0.2876        0.2789        1    3.02%
#       0     0        0.2789     1        0.2876      Fract: 1        3    3.02%
#       0     2        0.2789     2        0.2876        0.2789        3    3.02%                        0             0
# Elapsed time = 0.13 sec. (1.94 ticks, tree = 0.01 MB, solutions = 1)
# *   640+  284                            0.2872        0.2789             2.88%
#    1604   599        cutoff              0.2872        0.2789     7598    2.88%           rho_5 U   1604   1603     21
#    2593   949        cutoff              0.2872        0.2789    13559    2.88%          rho_13 U   2593   2592     31
# *  2915  1066      integral     0        0.2866        0.2789    15393    2.71%
#    3392  1223        0.2836     7        0.2866        0.2789    18246    2.71%           rho_1 U   3392   2351     16
#    4070  1399        0.2866     0        0.2866        0.2789    22927    2.71%          rho_20 D   4070   4069     22
# *  4180+ 1278                            0.2854        0.2789             2.30%
#    4667  1417        0.2849     3        0.2854        0.2789    26418    2.30%          rho_13 D   4667   4666     26
#    5171  1550        0.2831     9        0.2854        0.2789    30571    2.30%           rho_0 U   5171   5170     14
#    5709  1763        0.2853     7        0.2854        0.2789    34774    2.30%           rho_0 U   5709   5708     15
#    6236  1921        0.2849    11        0.2854        0.2789    38959    2.30%          rho_10 D   6236   6234     17
#    6733  2053        cutoff              0.2854        0.2789    43015    2.30%           rho_2 U   6733   6732     16
#    8728  2612        cutoff              0.2854        0.2791    58170    2.21%          rho_20 D   8728   8726     19
# Elapsed time = 3.81 sec. (3105.40 ticks, tree = 0.82 MB, solutions = 4)
#   10966  2958        0.2820    15        0.2854        0.2801    71342    1.88%           rho_0 D  10966  10965     16
#   13112  3168        0.2843    13        0.2854        0.2809    83377    1.59%          rho_14 D  13112  13111     22
#   15263  3290        0.2844     5        0.2854        0.2814    94894    1.40%          rho_27 D  15263  15262     19
#   17322  3171        cutoff              0.2854        0.2821   105875    1.15%           rho_1 D  17322  13172     20
#   19310  2915        cutoff              0.2854        0.2827   116230    0.95%          rho_27 D  19310  17849     19
#   21303  2464        cutoff              0.2854        0.2833   125989    0.74%           rho_9 U  21303  21302     20
# * 23050  1745      integral     0        0.2854        0.2839   133738    0.51%
#   23252  1660        0.2846    11        0.2854        0.2840   134575    0.49%           rho_3 D  23252  23251     19
#   25342   308        cutoff              0.2854        0.2850   142581    0.11%          rho_18 U  25342  12681     18
#
# Gomory fractional cuts applied:  1
# User cuts applied:  604
#
# Root node processing (before b&c):
#   Real time             =    0.11 sec. (1.99 ticks)
# Sequential b&c:
#   Real time             =    8.83 sec. (10871.73 ticks)
#                           ------------
# Total (root+branch&cut) =    8.94 sec. (10873.73 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | age_at_current_charge<=52                    |         1 points |   + ..... |
# | p_arrest>=3                                  |         1 points |   + ..... |
# | p_drug>=1                                    |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/16/19 @ 09:55 AM | 1301 rows in lookup table
# 08/16/19 @ 09:55 AM | ------------------------------------------------------------
# 08/16/19 @ 09:55 AM | runnning initialization procedure
# 08/16/19 @ 09:55 AM | ------------------------------------------------------------
# 08/16/19 @ 09:55 AM | CPA produced 2 cuts
# 08/16/19 @ 09:55 AM | running naive rounding on 85 solutions
# 08/16/19 @ 09:55 AM | best objective value: 0.2793
# 08/16/19 @ 09:55 AM | rounding produced 5 integer solutions
# 08/16/19 @ 09:55 AM | best objective value is 0.2869
# 08/16/19 @ 09:55 AM | running sequential rounding on 85 solutions
# 08/16/19 @ 09:55 AM | best objective value: 0.2793
# 08/16/19 @ 09:55 AM | sequential rounding produced 5 integer solutions
# 08/16/19 @ 09:55 AM | best objective value: 0.2869
# 08/16/19 @ 09:55 AM | polishing 10 solutions
# 08/16/19 @ 09:55 AM | best objective value: 0.2869
# 08/16/19 @ 09:55 AM | polishing produced 5 integer solutions
# 08/16/19 @ 09:55 AM | initialization produced 11 feasible solutions
# 08/16/19 @ 09:55 AM | best objective value: 0.2866
# 08/16/19 @ 09:55 AM | ------------------------------------------------------------
# 08/16/19 @ 09:55 AM | completed initialization procedure
# 08/16/19 @ 09:55 AM | ------------------------------------------------------------
# 08/16/19 @ 09:55 AM | 1301 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               400
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.27856254690971899
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.28655576846045699
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/16/19 @ 09:55 AM | adding 249 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.2866.
# Tried aggregator 1 time.
# Reduced MIP has 32 rows, 64 columns, and 123 nonzeros.
# Reduced MIP has 30 binaries, 32 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.07 ticks)
# Probing time = 0.00 sec. (0.02 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.04 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.2866        0.2785             2.82%
#       0     0        0.2786     1        0.2866        0.2786        1    2.79%
#       0     0        0.2786     1        0.2866      Fract: 1        3    2.79%
#       0     2        0.2786     2        0.2866        0.2786        3    2.79%                        0             0
# Elapsed time = 0.13 sec. (1.92 ticks, tree = 0.01 MB, solutions = 1)
# *  1300+  582                            0.2862        0.2786             2.67%
# *  1680+  701                            0.2854        0.2786             2.38%
#    1707   712        cutoff              0.2854        0.2786     7261    2.38%          rho_12 U   1707   1704     19
# *  1928   782      integral     0        0.2853        0.2786     8552    2.36%
#    2647  1002        0.2814     7        0.2853        0.2786    12728    2.36%           rho_6 D   2647   2645     18
# *  2830+ 1040                            0.2851        0.2786             2.30%
#    3358  1194        0.2843    10        0.2851        0.2786    17461    2.30%          rho_11 D   3358    105      9
#    4024  1378        0.2818    14        0.2851        0.2786    22443    2.30%           rho_4 U   4024   4023     16
#    4690  1595        0.2827     0        0.2851        0.2786    27284    2.30%           rho_8 D   4690   4688     24
#    5323  1773        cutoff              0.2851        0.2786    32195    2.30%           rho_7 U   5323   5321     19
#    5907  1942        0.2836     8        0.2851        0.2786    37053    2.30%           rho_3 D   5907   5905     20
#    6459  2074        cutoff              0.2851        0.2786    41881    2.30%          rho_19 U   6459   6458     23
#    7017  2264        0.2842    15        0.2851        0.2786    46404    2.30%          rho_14 D   7017   7016     20
#    9102  2866        cutoff              0.2851        0.2786    64091    2.30%          rho_17 U   9102   9101     27
# Elapsed time = 3.78 sec. (3104.96 ticks, tree = 0.87 MB, solutions = 5)
#   11460  3188        0.2834     5        0.2851        0.2797    79986    1.92%           rho_3 U  11460  11459     17
#   13859  3430        0.2829    15        0.2851        0.2804    94200    1.66%           rho_0 D  13859   4583     16
#   16228  3555        0.2842    11        0.2851        0.2811   108143    1.43%          rho_24 D  16228  16226     23
#   18569  3595        0.2829    15        0.2851        0.2817   120995    1.22%           rho_8 D  18569  10112     24
#   20849  3358        0.2833    14        0.2851        0.2822   133310    1.01%          rho_14 D  20849  17114     21
#   23144  2939        0.2832    13        0.2851        0.2828   145160    0.80%          rho_17 D  23144  17037     24
#   25428  2342        cutoff              0.2851        0.2834   156163    0.61%           rho_2 U  25428  23075     22
#   27872  1435        0.2841     7        0.2851        0.2841   166433    0.36%           rho_4 D  27872  14502     20
#
# Gomory fractional cuts applied:  1
# User cuts applied:  500
#
# Root node processing (before b&c):
#   Real time             =    0.13 sec. (1.97 ticks)
# Sequential b&c:
#   Real time             =    9.38 sec. (11525.05 ticks)
#                           ------------
# Total (root+branch&cut) =    9.50 sec. (11527.02 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | age_at_current_charge<=52                    |         1 points |   + ..... |
# | p_arrest>=3                                  |         1 points |   + ..... |
# | p_drug>=1                                    |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+

# %%
np.mean(train_auc), np.mean(test_auc)
# Out:
# (0.6540901243468472, 0.6540355956586899)

# %% [markdown]
# ### Save Results

# %%
#log model results to the model performance folder, as per standards
path = "C:\\Users\\binha\\Documents\\Duke\\Cynthia Research\\KY-analysis-mytrials\\KY Recidivism\\KY Results\\Models\\Two Year\\"                   
results = [["Drug", np.mean(train_auc), np.std(train_auc), np.mean(test_auc), np.std(test_auc)]]

with open(path + 'Two Year RiskSLIM.csv', 'a') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(results)
