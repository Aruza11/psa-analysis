# %%
import numpy as np
import pandas as pd
import RiskSLIM as risk
import csv

from riskslim.helper_functions import load_data_from_csv, print_model
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.utils import shuffle

# %% [markdown]
# ### Lasso Feature Selection

# %%
## load stumps data
data = pd.read_csv("C:/Users/binha/Documents/Duke/Cynthia Research/KY-analysis-mytrials/KY Recidivism/KY data/kentucky_stumps.csv")
X, Y = data.loc[:,:'current_violence>=1'], data['recid_property_two_year'].values
cols = X.columns

# %%
## lasso
lasso = Lasso(random_state=816, alpha=0.001).fit(X, Y)
selected_features = cols[lasso.coef_ != 0].tolist()
len(selected_features), roc_auc_score(Y, lasso.predict(X))
# Out:
# (20, 0.7853299368345621)

# %% [markdown]
# #### subset features

# %%
### Subset features
selected_features.insert(0, 'recid_property_two_year')
sub_data = data[selected_features]
sub_X, sub_Y = sub_data.iloc[:,1:], sub_data.iloc[:,0].values
sub_X.insert(0, '(Intercept)', 1)

# %% [markdown]
# ### Cross Validation

# %%
SLIM_X, SLIM_Y = sub_X.values, sub_Y.reshape(-1,1)
variable_names = sub_X.columns.tolist()
outcome_name = 'recid_property_two_year'
sample_weights = np.repeat(1, len(sub_Y))

# %%
#cv = KFold(n_splits=5, random_state=816, shuffle=True)
cv = KFold(n_splits=5, random_state=816, shuffle=True)
train_auc, test_auc = [], []

i = 0
for train, test in cv.split(SLIM_X, SLIM_Y):
    
    ## subset train data & store test data
    X_train, Y_train = SLIM_X[train], SLIM_Y[train]
    X_test, Y_test = SLIM_X[test], SLIM_Y[test]
    sample_weights_train, sample_weights_test = sample_weights[train], sample_weights[test]

    ## create new data dictionary
    new_train_data = {
        'X': X_train,
        'Y': Y_train,
        'variable_names': variable_names,
        'outcome_name': outcome_name,
        'sample_weights': sample_weights_train
    }
        
    ## fit the model
    model_info, mip_info, lcpa_info = risk.risk_slim(new_train_data, max_coefficient=20, max_L0_value=10, 
                                                c0_value=1e-5, max_runtime=400)
    print_model(model_info['solution'], new_train_data)
    
    ## change data format
    X_train, X_test = X_train[:,1:], X_test[:,1:] ## remove the first column, which is "intercept"
    Y_train[Y_train == -1] = 0 ## change -1 to 0
    Y_test[Y_test == -1] = 0
    
    ## probability & accuracy
    train_prob = risk.riskslim_prediction(X_train, cols, model_info).reshape(-1,1)
    test_prob = risk.riskslim_prediction(X_test, cols, model_info).reshape(-1,1)
    
    ## AUC
    train_auc.append(roc_auc_score(Y_train, train_prob))
    test_auc.append(roc_auc_score(Y_test, test_prob))
# Out:
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/16/19 @ 09:58 AM | 901 rows in lookup table
# 08/16/19 @ 09:58 AM | ------------------------------------------------------------
# 08/16/19 @ 09:58 AM | runnning initialization procedure
# 08/16/19 @ 09:58 AM | ------------------------------------------------------------
# 08/16/19 @ 09:58 AM | CPA produced 2 cuts
# 08/16/19 @ 09:58 AM | running naive rounding on 97 solutions
# 08/16/19 @ 09:58 AM | best objective value: 0.0801
# 08/16/19 @ 09:58 AM | rounding produced 5 integer solutions
# 08/16/19 @ 09:58 AM | best objective value is 0.0827
# 08/16/19 @ 09:58 AM | running sequential rounding on 97 solutions
# 08/16/19 @ 09:58 AM | best objective value: 0.0801
# 08/16/19 @ 09:58 AM | sequential rounding produced 6 integer solutions
# 08/16/19 @ 09:58 AM | best objective value: 0.0819
# 08/16/19 @ 09:58 AM | polishing 11 solutions
# 08/16/19 @ 09:58 AM | best objective value: 0.0819
# 08/16/19 @ 09:58 AM | polishing produced 4 integer solutions
# 08/16/19 @ 09:58 AM | initialization produced 10 feasible solutions
# 08/16/19 @ 09:58 AM | best objective value: 0.0817
# 08/16/19 @ 09:58 AM | ------------------------------------------------------------
# 08/16/19 @ 09:58 AM | completed initialization procedure
# 08/16/19 @ 09:58 AM | ------------------------------------------------------------
# 08/16/19 @ 09:58 AM | 901 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               400
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.079520449422787798
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.081746627476422432
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/16/19 @ 09:58 AM | adding 254 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.0817.
# Tried aggregator 1 time.
# Reduced MIP has 22 rows, 44 columns, and 83 nonzeros.
# Reduced MIP has 20 binaries, 22 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.0817        0.0794             2.85%
#       0     0        0.0795     1        0.0817        0.0795        1    2.72%
#       0     0        0.0795     1        0.0817      Fract: 1        2    2.72%
#       0     2        0.0795     2        0.0817        0.0795        2    2.72%                        0             0
# Elapsed time = 0.11 sec. (1.30 ticks, tree = 0.01 MB, solutions = 1)
#    1858   758        0.0810     3        0.0817        0.0795     7878    2.72%           rho_6 U   1858   1857     16
#    2755  1039        cutoff              0.0817        0.0795    12609    2.72%          rho_11 D   2755   2754     23
#    3504  1290        0.0803     6        0.0817        0.0795    16526    2.72%           rho_6 D   3504   3473     18
#    4150  1499        0.0811     3        0.0817        0.0795    20280    2.72%           rho_0 U   4150   4149     21
# *  4170+ 1451                            0.0816        0.0795             2.55%
#    4663  1611        0.0807    15        0.0816        0.0795    23580    2.55%           rho_3 D   4663    665     13
#    5190  1815        0.0798     7        0.0816        0.0795    26745    2.55%           rho_5 D   5190   5189     18
#    5703  2022        cutoff              0.0816        0.0795    29748    2.55%           rho_6 U   5703   5702     18
#    6180  2230        0.0797     9        0.0816        0.0795    32822    2.55%           rho_0 U   6180   6179     17
#    6654  2425        cutoff              0.0816        0.0795    35770    2.55%           rho_6 U   6654   6652     27
#    8544  3238        0.0800    11        0.0816        0.0795    46839    2.55%           rho_0 D   8544   8542     19
# Elapsed time = 3.92 sec. (3104.72 ticks, tree = 0.96 MB, solutions = 2)
#   10340  3985        0.0814     7        0.0816        0.0796    58065    2.47%           rho_0 U  10340  10339     18
#   12276  4483        0.0804    12        0.0816        0.0798    66391    2.26%           rho_1 D  12276   8396     13
#   14083  4897        0.0810     7        0.0816        0.0799    74304    2.11%           rho_5 N  14083  14081     18
#   15905  5226        0.0805    13        0.0816        0.0800    81874    1.99%           rho_0 D  15905  15904     17
#   17626  5474        cutoff              0.0816        0.0801    89445    1.87%          rho_12 U  17626  17624     21
#   19353  5644        cutoff              0.0816        0.0802    96799    1.73%           rho_3 U  19353   5084     21
#   21060  5847        0.0809     7        0.0816        0.0803   103985    1.62%          rho_11 D  21060   8337     25
#   22670  5905        0.0811     5        0.0816        0.0804   111055    1.50%           rho_5 D  22670  22669     23
#   24270  6004        0.0808     3        0.0816        0.0804   117800    1.42%           rho_7 N  24270  24268     15
#   25865  5968        0.0816     5        0.0816        0.0805   124296    1.32%          rho_11 D  25865  25863     23
# Elapsed time = 11.02 sec. (12645.68 ticks, tree = 1.97 MB, solutions = 2)
#   27408  5893        0.0811     8        0.0816        0.0806   130601    1.23%          rho_12 D  27408  27407     23
#   28948  5795        0.0809     7        0.0816        0.0807   137177    1.15%          rho_10 D  28948  12038     22
#   30467  5616        cutoff              0.0816        0.0807   143463    1.06%          rho_18 U  30467  30465     15
#   31955  5401        0.0812     7        0.0816        0.0808   149735    0.98%           rho_5 D  31955  31953     21
# * 33087  4852      integral     0        0.0815        0.0809   154455    0.82%
#   33431  4779        0.0812    10        0.0815        0.0809   155824    0.80%          rho_12 D  33431  33430     22
#   34880  4307        cutoff              0.0815        0.0810   161532    0.70%           rho_3 U  34880  28239     13
#   36372  3727        cutoff              0.0815        0.0810   167236    0.60%           rho_5 D  36372  36371     17
#   37967  2973        cutoff              0.0815        0.0811   173137    0.47%           rho_5 U  37967    604     19
#   39477  2054        cutoff              0.0815        0.0813   178579    0.33%           rho_4 U  39477  19211     18
#   40964   923        cutoff              0.0815        0.0814   183231    0.17%           rho_5 U  40964  20096     24
# Elapsed time = 17.42 sec. (22185.35 ticks, tree = 0.58 MB, solutions = 3)
#
# Gomory fractional cuts applied:  1
# User cuts applied:  972
#
# Root node processing (before b&c):
#   Real time             =    0.12 sec. (1.37 ticks)
# Sequential b&c:
#   Real time             =   17.69 sec. (22815.77 ticks)
#                           ------------
# Total (root+branch&cut) =   17.81 sec. (22817.14 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-6 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | age_at_current_charge<=20                    |         1 points |   + ..... |
# | age_at_current_charge<=46                    |         1 points |   + ..... |
# | p_arrest>=2                                  |         1 points |   + ..... |
# | p_arrest>=4                                  |         1 points |   + ..... |
# | p_property>=1                                |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 5                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/16/19 @ 09:58 AM | 901 rows in lookup table
# 08/16/19 @ 09:58 AM | ------------------------------------------------------------
# 08/16/19 @ 09:58 AM | runnning initialization procedure
# 08/16/19 @ 09:58 AM | ------------------------------------------------------------
# 08/16/19 @ 09:58 AM | CPA produced 2 cuts
# 08/16/19 @ 09:58 AM | running naive rounding on 105 solutions
# 08/16/19 @ 09:58 AM | best objective value: 0.0818
# 08/16/19 @ 09:58 AM | rounding produced 5 integer solutions
# 08/16/19 @ 09:58 AM | best objective value is 0.0835
# 08/16/19 @ 09:58 AM | running sequential rounding on 105 solutions
# 08/16/19 @ 09:58 AM | best objective value: 0.0818
# 08/16/19 @ 09:58 AM | sequential rounding produced 5 integer solutions
# 08/16/19 @ 09:58 AM | best objective value: 0.0835
# 08/16/19 @ 09:58 AM | polishing 10 solutions
# 08/16/19 @ 09:58 AM | best objective value: 0.0835
# 08/16/19 @ 09:58 AM | polishing produced 5 integer solutions
# 08/16/19 @ 09:58 AM | initialization produced 13 feasible solutions
# 08/16/19 @ 09:58 AM | best objective value: 0.0834
# 08/16/19 @ 09:58 AM | ------------------------------------------------------------
# 08/16/19 @ 09:58 AM | completed initialization procedure
# 08/16/19 @ 09:58 AM | ------------------------------------------------------------
# 08/16/19 @ 09:58 AM | 901 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               400
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.08133221962269728
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.083432371720463527
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/16/19 @ 09:58 AM | adding 249 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.0834.
# Tried aggregator 1 time.
# Reduced MIP has 22 rows, 44 columns, and 83 nonzeros.
# Reduced MIP has 20 binaries, 22 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.0834        0.0812             2.64%
#       0     0        0.0813     1        0.0834        0.0813        1    2.52%
#       0     2        0.0813     2        0.0834        0.0813        1    2.52%                        0             0
# Elapsed time = 0.09 sec. (1.07 ticks, tree = 0.01 MB, solutions = 1)
#    2000   732        0.0822     0        0.0834        0.0813     9196    2.52%           rho_4 D   2000   1999     21
#    3000  1067        0.0827     4        0.0834        0.0813    14423    2.52%          rho_13 D   3000   2998     25
#    3736  1298        0.0813     6        0.0834        0.0813    19137    2.52%           rho_4 U   3736   3723     16
#    4431  1519        cutoff              0.0834        0.0813    22895    2.52%          rho_10 U   4431   4430     26
#    5021  1726        0.0818     8        0.0834        0.0813    26647    2.52%           rho_5 U   5021   4994     21
#    5582  1933        0.0813    12        0.0834        0.0813    29932    2.52%           rho_1 U   5582   3722     15
#    6080  2129        0.0813    14        0.0834        0.0813    33355    2.52%           rho_6 D   6080   6079     16
#    6583  2339        0.0814    16        0.0834        0.0813    36898    2.52%          rho_18 U   6583   4477     15
#    7090  2544        0.0813     7        0.0834        0.0813    39776    2.52%           rho_7 U   7090   6864     20
#    8931  3310        0.0831     9        0.0834        0.0813    52489    2.52%          rho_12 D   8931   8929     23
# Elapsed time = 3.91 sec. (3104.17 ticks, tree = 0.98 MB, solutions = 1)
#   11052  3863        0.0822    11        0.0834        0.0816    61998    2.21%           rho_3 D  11052   4672     20
#   13000  4259        0.0828     6        0.0834        0.0817    70768    2.02%          rho_20 D  13000  12999     22
# * 13990  4376      integral     0        0.0834        0.0818    75028    1.90%           rho_9 D  13990  13989     30
#   15767  4618        0.0831     9        0.0834        0.0820    83041    1.73%           rho_6 U  15767   7232     20
#   17549  4742        cutoff              0.0834        0.0821    91151    1.59%          rho_12 U  17549  17546     23
#   19310  4773        0.0831     5        0.0834        0.0822    98929    1.43%          rho_12 D  19310  19308     24
# * 19496  4757      integral     0        0.0834        0.0822    99861    1.41%
#   21014  4696        0.0827     7        0.0834        0.0823   106560    1.29%          rho_12 D  21014  13090     26
#   22632  4542        0.0834     8        0.0834        0.0824   113938    1.15%          rho_20 N  22632  10488     23
#   24232  4338        cutoff              0.0834        0.0825   121173    1.02%           rho_7 U  24232  16786     22
#   25824  4020        cutoff              0.0834        0.0826   128165    0.90%           rho_7 U  25824   3728     21
# Elapsed time = 10.44 sec. (12195.96 ticks, tree = 1.44 MB, solutions = 3)
#   27368  3565        0.0829    10        0.0834        0.0827   134759    0.77%           rho_6 U  27368  16554     21
#   28888  3018        cutoff              0.0834        0.0828   140939    0.65%           rho_1 U  28888  15250     26
#   30540  2166        cutoff              0.0834        0.0830   147681    0.47%           rho_8 U  30540  30538     19
#   32143  1043        cutoff              0.0834        0.0832   153518    0.26%           rho_4 U  32143  23767     16
#
# User cuts applied:  903
#
# Root node processing (before b&c):
#   Real time             =    0.09 sec. (1.13 ticks)
# Sequential b&c:
#   Real time             =   13.36 sec. (16689.65 ticks)
#                           ------------
# Total (root+branch&cut) =   13.45 sec. (16690.79 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-6 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | age_at_current_charge<=20                    |         1 points |   + ..... |
# | age_at_current_charge<=46                    |         1 points |   + ..... |
# | p_arrest>=2                                  |         1 points |   + ..... |
# | p_arrest>=4                                  |         1 points |   + ..... |
# | p_property>=1                                |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 5                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/16/19 @ 09:59 AM | 901 rows in lookup table
# 08/16/19 @ 09:59 AM | ------------------------------------------------------------
# 08/16/19 @ 09:59 AM | runnning initialization procedure
# 08/16/19 @ 09:59 AM | ------------------------------------------------------------
# 08/16/19 @ 09:59 AM | CPA produced 2 cuts
# 08/16/19 @ 09:59 AM | running naive rounding on 108 solutions
# 08/16/19 @ 09:59 AM | best objective value: 0.0808
# 08/16/19 @ 09:59 AM | rounding produced 5 integer solutions
# 08/16/19 @ 09:59 AM | best objective value is 0.0838
# 08/16/19 @ 09:59 AM | running sequential rounding on 108 solutions
# 08/16/19 @ 09:59 AM | best objective value: 0.0808
# 08/16/19 @ 09:59 AM | sequential rounding produced 6 integer solutions
# 08/16/19 @ 09:59 AM | best objective value: 0.0823
# 08/16/19 @ 09:59 AM | polishing 11 solutions
# 08/16/19 @ 09:59 AM | best objective value: 0.0823
# 08/16/19 @ 09:59 AM | polishing produced 5 integer solutions
# 08/16/19 @ 09:59 AM | initialization produced 14 feasible solutions
# 08/16/19 @ 09:59 AM | best objective value: 0.0823
# 08/16/19 @ 09:59 AM | ------------------------------------------------------------
# 08/16/19 @ 09:59 AM | completed initialization procedure
# 08/16/19 @ 09:59 AM | ------------------------------------------------------------
# 08/16/19 @ 09:59 AM | 901 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               400
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.080078524709058518
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.08228798364498309
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/16/19 @ 09:59 AM | adding 253 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.0823.
# Tried aggregator 1 time.
# Reduced MIP has 22 rows, 44 columns, and 83 nonzeros.
# Reduced MIP has 20 binaries, 22 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.0823        0.0800             2.81%
#       0     0        0.0801     1        0.0823        0.0801        1    2.69%
#       0     0        0.0801     1        0.0823      Fract: 1        2    2.69%
#       0     2        0.0801     1        0.0823        0.0801        2    2.69%                        0             0
# Elapsed time = 0.09 sec. (1.34 ticks, tree = 0.01 MB, solutions = 1)
#    2139   782        cutoff              0.0823        0.0801    10546    2.69%           rho_7 U   2139   2138     23
# *  2770+  949                            0.0821        0.0801             2.41%
#    3150  1057        0.0816     5        0.0821        0.0801    15017    2.41%           rho_0 U   3150   3148     23
#    3882  1295        0.0820     3        0.0821        0.0801    19908    2.41%          rho_11 D   3882   3881     23
#    4595  1529        0.0801     8        0.0821        0.0801    23800    2.41%           rho_0 D   4595   4593     18
#    5226  1767        cutoff              0.0821        0.0801    27264    2.41%          rho_11 D   5226   5225     29
#    5830  2006        0.0801     9        0.0821        0.0801    30708    2.41%           rho_7 D   5830   5819     20
#    6386  2183        0.0807     7        0.0821        0.0801    33963    2.41%          rho_10 U   6386   6385     23
#    6877  2351        cutoff              0.0821        0.0801    37156    2.41%          rho_13 D   6877   6876     28
#    7382  2553        0.0809     7        0.0821        0.0801    40171    2.41%           rho_4 D   7382   7381     20
#    9436  3210        0.0809    13        0.0821        0.0803    51264    2.20%           rho_3 U   9436   9434     18
# Elapsed time = 3.84 sec. (3105.85 ticks, tree = 0.94 MB, solutions = 2)
#   11568  3551        cutoff              0.0821        0.0805    60592    1.95%          rho_12 U  11568  11567     29
#   13535  3797        0.0808    13        0.0821        0.0806    69068    1.75%           rho_7 D  13535  13534     20
#   15383  3869        0.0810     7        0.0821        0.0808    77294    1.54%           rho_0 U  15383  10920     23
#   17152  3871        0.0820    11        0.0821        0.0809    84906    1.39%           rho_0 U  17152   8246     19
#   18907  3745        cutoff              0.0821        0.0810    92398    1.24%          rho_13 D  18907  18906     31
#   20579  3498        0.0818     5        0.0821        0.0812    99696    1.07%          rho_10 D  20579   3216     25
#   22245  3163        0.0814    10        0.0821        0.0813   106822    0.91%           rho_5 D  22245  11478     21
#   23853  2660        cutoff              0.0821        0.0814   113536    0.74%           rho_9 U  23853  23851     23
#   25471  1927        0.0820     1        0.0821        0.0816   119695    0.55%          rho_11 D  25471   5909     27
#   27097   831        cutoff              0.0821        0.0818   125567    0.28%           rho_0 D  27097  27096     28
# Elapsed time = 10.48 sec. (12644.83 ticks, tree = 0.40 MB, solutions = 2)
#
# Implied bound cuts applied:  1
# Gomory fractional cuts applied:  1
# User cuts applied:  900
#
# Root node processing (before b&c):
#   Real time             =    0.09 sec. (1.40 ticks)
# Sequential b&c:
#   Real time             =   10.72 sec. (13191.29 ticks)
#                           ------------
# Total (root+branch&cut) =   10.81 sec. (13192.69 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-6 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | age_at_current_charge<=20                    |         1 points |   + ..... |
# | age_at_current_charge<=46                    |         1 points |   + ..... |
# | p_arrest>=2                                  |         1 points |   + ..... |
# | p_arrest>=4                                  |         1 points |   + ..... |
# | p_property>=1                                |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 5                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/16/19 @ 09:59 AM | 901 rows in lookup table
# 08/16/19 @ 09:59 AM | ------------------------------------------------------------
# 08/16/19 @ 09:59 AM | runnning initialization procedure
# 08/16/19 @ 09:59 AM | ------------------------------------------------------------
# 08/16/19 @ 09:59 AM | CPA produced 2 cuts
# 08/16/19 @ 09:59 AM | running naive rounding on 107 solutions
# 08/16/19 @ 09:59 AM | best objective value: 0.0793
# 08/16/19 @ 09:59 AM | rounding produced 5 integer solutions
# 08/16/19 @ 09:59 AM | best objective value is 0.0827
# 08/16/19 @ 09:59 AM | running sequential rounding on 107 solutions
# 08/16/19 @ 09:59 AM | best objective value: 0.0793
# 08/16/19 @ 09:59 AM | sequential rounding produced 6 integer solutions
# 08/16/19 @ 09:59 AM | best objective value: 0.0809
# 08/16/19 @ 09:59 AM | polishing 11 solutions
# 08/16/19 @ 09:59 AM | best objective value: 0.0809
# 08/16/19 @ 09:59 AM | polishing produced 5 integer solutions
# 08/16/19 @ 09:59 AM | initialization produced 14 feasible solutions
# 08/16/19 @ 09:59 AM | best objective value: 0.0809
# 08/16/19 @ 09:59 AM | ------------------------------------------------------------
# 08/16/19 @ 09:59 AM | completed initialization procedure
# 08/16/19 @ 09:59 AM | ------------------------------------------------------------
# 08/16/19 @ 09:59 AM | 901 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               400
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.078791524973928176
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.08092932460845928
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/16/19 @ 09:59 AM | adding 257 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.0809.
# Tried aggregator 1 time.
# Reduced MIP has 22 rows, 44 columns, and 83 nonzeros.
# Reduced MIP has 20 binaries, 22 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.0809        0.0787             2.77%
#       0     0        0.0788     1        0.0809        0.0788        1    2.64%
#       0     0        0.0788     1        0.0809      Fract: 1        2    2.64%
#       0     2        0.0788     5        0.0809        0.0788        2    2.64%                        0             0
# Elapsed time = 0.13 sec. (1.34 ticks, tree = 0.01 MB, solutions = 1)
#    1926   673        0.0790     9        0.0809        0.0788     8481    2.64%           rho_0 D   1926   1923     17
# *  2208   777      integral     0        0.0809        0.0788     9901    2.60%
#    2853   979        cutoff              0.0809        0.0788    13514    2.60%           rho_4 U   2853   2852     22
#    3629  1239        0.0792    11        0.0809        0.0788    18122    2.60%           rho_0 U   3629   3628     16
#    4294  1503        cutoff              0.0809        0.0788    22357    2.60%           rho_7 U   4294   4293     20
#    4898  1746        cutoff              0.0809        0.0788    25900    2.60%           rho_7 U   4898   4897     24
#    5467  1989        0.0792    14        0.0809        0.0788    29288    2.60%           rho_2 U   5467   1640     15
#    6029  2212        0.0806     9        0.0809        0.0788    32528    2.60%           rho_4 D   6029   6026     27
#    6498  2421        0.0798    10        0.0809        0.0788    36092    2.60%           rho_5 D   6498   6497     12
#    6956  2623        0.0788    10        0.0809        0.0788    39121    2.60%           rho_0 D   6956   3898     11
#    8896  3379        0.0791     9        0.0809        0.0789    50973    2.48%           rho_5 D   8896   8895     20
# Elapsed time = 5.61 sec. (3103.19 ticks, tree = 0.99 MB, solutions = 2)
#   10981  3901        0.0803     9        0.0809        0.0791    60415    2.25%          rho_12 D  10981  10979     24
#   12937  4313        0.0807     7        0.0809        0.0792    69507    2.05%          rho_18 U  12937  12936     23
# * 14751  4539      integral     0        0.0809        0.0794    77349    1.86%
#   14823  4553        0.0806     4        0.0809        0.0794    77664    1.85%           rho_7 N  14823  14822     20
#   16599  4691        0.0808     5        0.0809        0.0795    85481    1.70%          rho_12 D  16599  16598     16
#   18400  4835        0.0799     7        0.0809        0.0796    93462    1.55%           rho_5 U  18400  13880     16
# * 18455  4641      integral     0        0.0808        0.0796    93666    1.43%
#   20147  4532        cutoff              0.0808        0.0797   101136    1.27%          rho_12 U  20147   9161     18
#   21858  4335        cutoff              0.0808        0.0799   108472    1.12%           rho_3 U  21858  16817     10
#   23519  4060        cutoff              0.0808        0.0800   115571    0.97%           rho_4 U  23519  19412     22
#   25133  3697        0.0805     9        0.0808        0.0801   122369    0.83%          rho_10 U  25133  25132     17
#   26696  3198        cutoff              0.0808        0.0802   128775    0.70%          rho_18 U  26696   9325     23
# Elapsed time = 17.33 sec. (12642.77 ticks, tree = 1.20 MB, solutions = 4)
#   28360  2485        cutoff              0.0808        0.0803   135254    0.54%          rho_18 U  28360   5034     19
#   30079  1532        cutoff              0.0808        0.0805   141443    0.35%           rho_2 U  30079  14403     18
#   31707   210        cutoff              0.0808        0.0807   146468    0.06%           rho_9 D  31707  16471     22
#
# Gomory fractional cuts applied:  1
# User cuts applied:  897
#
# Root node processing (before b&c):
#   Real time             =    0.13 sec. (1.40 ticks)
# Sequential b&c:
#   Real time             =   21.05 sec. (15612.23 ticks)
#                           ------------
# Total (root+branch&cut) =   21.17 sec. (15613.63 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-7 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_property>=1                                |         2 points |   + ..... |
# | Gender>=1                                    |         1 points |   + ..... |
# | age_at_current_charge<=46                    |         1 points |   + ..... |
# | p_arrest>=2                                  |         1 points |   + ..... |
# | p_pending_charge>=1                          |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 5                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/16/19 @ 09:59 AM | 901 rows in lookup table
# 08/16/19 @ 09:59 AM | ------------------------------------------------------------
# 08/16/19 @ 09:59 AM | runnning initialization procedure
# 08/16/19 @ 09:59 AM | ------------------------------------------------------------
# 08/16/19 @ 09:59 AM | CPA produced 2 cuts
# 08/16/19 @ 09:59 AM | running naive rounding on 110 solutions
# 08/16/19 @ 09:59 AM | best objective value: 0.0811
# 08/16/19 @ 09:59 AM | rounding produced 5 integer solutions
# 08/16/19 @ 09:59 AM | best objective value is 0.0830
# 08/16/19 @ 09:59 AM | running sequential rounding on 110 solutions
# 08/16/19 @ 09:59 AM | best objective value: 0.0811
# 08/16/19 @ 09:59 AM | sequential rounding produced 6 integer solutions
# 08/16/19 @ 09:59 AM | best objective value: 0.0829
# 08/16/19 @ 09:59 AM | polishing 11 solutions
# 08/16/19 @ 09:59 AM | best objective value: 0.0829
# 08/16/19 @ 09:59 AM | polishing produced 4 integer solutions
# 08/16/19 @ 09:59 AM | initialization produced 14 feasible solutions
# 08/16/19 @ 09:59 AM | best objective value: 0.0825
# 08/16/19 @ 09:59 AM | ------------------------------------------------------------
# 08/16/19 @ 09:59 AM | completed initialization procedure
# 08/16/19 @ 09:59 AM | ------------------------------------------------------------
# 08/16/19 @ 09:59 AM | 901 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               400
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.080372791784908082
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.08254551789478029
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/16/19 @ 09:59 AM | adding 249 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.0825.
# Tried aggregator 1 time.
# Reduced MIP has 22 rows, 44 columns, and 83 nonzeros.
# Reduced MIP has 20 binaries, 22 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.0825        0.0803             2.75%
#       0     0        0.0804     1        0.0825        0.0804        1    2.63%
#       0     2        0.0804     2        0.0825        0.0804        1    2.63%                        0             0
# Elapsed time = 0.08 sec. (1.07 ticks, tree = 0.01 MB, solutions = 1)
#    1820   676        0.0824     3        0.0825        0.0804     8973    2.63%          rho_15 D   1820   1818     30
#    2816  1012        cutoff              0.0825        0.0804    13855    2.63%           rho_3 U   2816   2815     30
#    3552  1264        0.0820     1        0.0825        0.0804    18262    2.63%          rho_11 D   3552   1238     29
#    4198  1495        0.0817    13        0.0825        0.0804    22088    2.63%           rho_1 U   4198    646     11
#    4790  1728        0.0818     5        0.0825        0.0804    25791    2.63%          rho_13 D   4790   4789     26
#    5358  1958        cutoff              0.0825        0.0804    29090    2.63%          rho_18 U   5358   5343     23
#    5860  2148        0.0825     0        0.0825        0.0804    32322    2.63%          rho_11 D   5860   5859     25
#    6336  2343        0.0807    10        0.0825        0.0804    35737    2.63%           rho_5 U   6336   3634     21
#    6804  2522        0.0806     9        0.0825        0.0804    38772    2.63%          rho_12 U   6804   5829     17
# *  8064  2936      integral     0        0.0825        0.0804    47368    2.56%           rho_7 U   8064   8063     19
# Elapsed time = 4.81 sec. (2828.26 ticks, tree = 0.88 MB, solutions = 2)
#    9874  3607        0.0807    15        0.0825        0.0805    58756    2.45%           rho_5 D   9874   9873     21
#   11715  4053        0.0812    16        0.0825        0.0806    67305    2.28%          rho_18 D  11715  11714     14
#   13474  4388        0.0825     3        0.0825        0.0807    75398    2.12%           rho_4 D  13474  13472     16
#   15158  4647        0.0811     9        0.0825        0.0808    83170    2.00%           rho_6 U  15158   6228     27
#   16788  4906        0.0821     7        0.0825        0.0809    90518    1.89%           rho_5 N  16788  16787     31
# * 18375  5050      integral     0        0.0825        0.0810    97774    1.78%           rho_8 U  18375  18374     33
# * 19048  5095      integral     0        0.0825        0.0811   100782    1.72%
#   19980  5162        0.0815     9        0.0825        0.0811   104943    1.65%           rho_5 D  19980  19979     17
#   21545  5271        cutoff              0.0825        0.0812   112150    1.54%           rho_3 U  21545  21543     33
#   23096  5280        cutoff              0.0825        0.0813   119097    1.43%           rho_1 U  23096  19184     16
#   24592  5236        cutoff              0.0825        0.0814   125936    1.32%           rho_7 U  24592   6647     22
# Elapsed time = 17.19 sec. (12344.44 ticks, tree = 1.79 MB, solutions = 4)
#   26077  5144        cutoff              0.0825        0.0815   132656    1.22%           rho_4 U  26077   8893     21
#   27572  4945        cutoff              0.0825        0.0815   139077    1.13%           rho_0 D  27572   1394     22
#   29058  4707        0.0823     9        0.0825        0.0816   145458    1.02%           rho_7 D  29058  29057     19
#   30528  4426        0.0822     5        0.0825        0.0817   151657    0.93%           rho_4 D  30528  30526     27
#   31980  4061        0.0821     8        0.0825        0.0818   157648    0.83%           rho_6 D  31980  31979     27
#   33419  3620        cutoff              0.0825        0.0819   163364    0.71%           rho_1 U  33419  20784     29
#   34952  3023        cutoff              0.0825        0.0820   169454    0.59%           rho_5 D  34952   7919     14
#   36486  2251        0.0822     9        0.0825        0.0821   175313    0.45%          rho_14 D  36486  15501     21
#   37971  1259        cutoff              0.0825        0.0822   180554    0.28%          rho_12 D  37971  20581     28
#
# User cuts applied:  995
#
# Root node processing (before b&c):
#   Real time             =    0.08 sec. (1.13 ticks)
# Sequential b&c:
#   Real time             =   28.73 sec. (21861.89 ticks)
#                           ------------
# Total (root+branch&cut) =   28.81 sec. (21863.03 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-6 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | age_at_current_charge<=20                    |         1 points |   + ..... |
# | age_at_current_charge<=46                    |         1 points |   + ..... |
# | p_arrest>=2                                  |         1 points |   + ..... |
# | p_arrest>=4                                  |         1 points |   + ..... |
# | p_property>=1                                |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 5                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+

# %%
np.mean(train_auc), np.mean(test_auc)
# Out:
# (0.7547309547841883, 0.7513205514896761)

# %% [markdown]
# ### Save Results

# %%
#log model results to the model performance folder, as per standards
path = "C:\\Users\\binha\\Documents\\Duke\\Cynthia Research\\KY-analysis-mytrials\\KY Recidivism\\KY Results\\Models\\Two Year\\"                   
results = [["Property", np.mean(train_auc), np.std(train_auc), np.mean(test_auc), np.std(test_auc)]]

with open(path + 'Two Year RiskSLIM.csv', 'a') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(results)
