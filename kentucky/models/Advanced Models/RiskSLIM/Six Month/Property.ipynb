# %%
import numpy as np
import pandas as pd
import RiskSLIM as risk
import csv

from riskslim.helper_functions import load_data_from_csv, print_model
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.utils import shuffle

# %% [markdown]
# ### Lasso Feature Selection

# %%
## load stumps data
data = pd.read_csv("C:/Users/binha/Documents/Duke/Cynthia Research/KY-analysis-mytrials/KY Recidivism/KY data/kentucky_stumps.csv")
X, Y = data.loc[:,:'current_violence>=1'], data['recid_property_six_month'].values
cols = X.columns

# %%
## lasso
lasso = Lasso(random_state=816, alpha=0.001).fit(X, Y)
selected_features = cols[lasso.coef_ != 0].tolist()
len(selected_features), roc_auc_score(Y, lasso.predict(X))
# Out:
# (10, 0.8556386734476186)

# %% [markdown]
# #### subset features

# %%
### Subset features
selected_features.insert(0, 'recid_property_six_month')
sub_data = data[selected_features]
sub_X, sub_Y = sub_data.iloc[:,1:], sub_data.iloc[:,0].values
sub_X.insert(0, '(Intercept)', 1)

# %% [markdown]
# ### Cross Validation

# %%
SLIM_X, SLIM_Y = sub_X.values, sub_Y.reshape(-1,1)
variable_names = sub_X.columns.tolist()
outcome_name = 'recid_property_six_month'
sample_weights = np.repeat(1, len(sub_Y))

# %%
#cv = KFold(n_splits=5, random_state=816, shuffle=True)
cv = KFold(n_splits=5, random_state=816, shuffle=True)
train_auc, test_auc = [], []

i = 0
for train, test in cv.split(SLIM_X, SLIM_Y):
    
    ## subset train data & store test data
    X_train, Y_train = SLIM_X[train], SLIM_Y[train]
    X_test, Y_test = SLIM_X[test], SLIM_Y[test]
    sample_weights_train, sample_weights_test = sample_weights[train], sample_weights[test]

    ## create new data dictionary
    new_train_data = {
        'X': X_train,
        'Y': Y_train,
        'variable_names': variable_names,
        'outcome_name': outcome_name,
        'sample_weights': sample_weights_train
    }
        
    ## fit the model
    model_info, mip_info, lcpa_info = risk.risk_slim(new_train_data, max_coefficient=20, max_L0_value=10, 
                                                c0_value=1e-5, max_runtime=200)
    print_model(model_info['solution'], new_train_data)
    
    ## change data format
    X_train, X_test = X_train[:,1:], X_test[:,1:] ## remove the first column, which is "intercept"
    Y_train[Y_train == -1] = 0 ## change -1 to 0
    Y_test[Y_test == -1] = 0
    
    ## probability & accuracy
    train_prob = risk.riskslim_prediction(X_train, cols, model_info).reshape(-1,1)
    test_prob = risk.riskslim_prediction(X_test, cols, model_info).reshape(-1,1)
    
    ## AUC
    train_auc.append(roc_auc_score(Y_train, train_prob))
    test_auc.append(roc_auc_score(Y_test, test_prob))
# Out:
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:15 PM | 501 rows in lookup table
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | runnning initialization procedure
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | CPA produced 2 cuts
# 08/17/19 @ 04:15 PM | running naive rounding on 158 solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0250
# 08/17/19 @ 04:15 PM | rounding produced 2 integer solutions
# 08/17/19 @ 04:15 PM | best objective value is 0.0256
# 08/17/19 @ 04:15 PM | running sequential rounding on 158 solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0250
# 08/17/19 @ 04:15 PM | sequential rounding produced 2 integer solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0255
# 08/17/19 @ 04:15 PM | polishing 4 solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0255
# 08/17/19 @ 04:15 PM | polishing produced 3 integer solutions
# 08/17/19 @ 04:15 PM | initialization produced 4 feasible solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0255
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | completed initialization procedure
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | 501 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.024998355082038994
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.025476242767525491
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:15 PM | adding 157 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.0255.
# Tried aggregator 2 times.
# MIP Presolve eliminated 1 rows and 1 columns.
# Aggregator did 1 substitutions.
# Reduced MIP has 10 rows, 22 columns, and 20 nonzeros.
# Reduced MIP has 10 binaries, 11 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (0.02 ticks)
# Probing time = 0.00 sec. (0.00 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.01 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.0255        0.0250             1.88%
#       0     0        0.0250     1        0.0255        0.0250        0    1.88%
#       0     0        0.0250     1        0.0255      Fract: 1        1    1.88%
#       0     2        0.0250     2        0.0255        0.0250        1    1.88%                        0             0
# Elapsed time = 0.09 sec. (0.60 ticks, tree = 0.01 MB, solutions = 1)
# *  1379   237      integral     0        0.0255        0.0251     4603    1.28%
#
# Gomory fractional cuts applied:  1
# User cuts applied:  142
#
# Root node processing (before b&c):
#   Real time             =    0.08 sec. (0.61 ticks)
# Sequential b&c:
#   Real time             =    0.42 sec. (156.26 ticks)
#                           ------------
# Total (root+branch&cut) =    0.50 sec. (156.87 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-7 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_property>=1                                |         2 points |   + ..... |
# | p_arrest>=3                                  |         1 points |   + ..... |
# | p_felony>=1                                  |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:15 PM | 501 rows in lookup table
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | runnning initialization procedure
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | CPA produced 2 cuts
# 08/17/19 @ 04:15 PM | running naive rounding on 139 solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0252
# 08/17/19 @ 04:15 PM | rounding produced 1 integer solutions
# 08/17/19 @ 04:15 PM | best objective value is 0.0258
# 08/17/19 @ 04:15 PM | running sequential rounding on 139 solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0252
# 08/17/19 @ 04:15 PM | sequential rounding produced 3 integer solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0258
# 08/17/19 @ 04:15 PM | polishing 4 solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0258
# 08/17/19 @ 04:15 PM | polishing produced 3 integer solutions
# 08/17/19 @ 04:15 PM | initialization produced 3 feasible solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0258
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | completed initialization procedure
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | 501 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.025228219112999342
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.025786035059484465
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:15 PM | adding 138 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.0258.
# Tried aggregator 2 times.
# MIP Presolve eliminated 1 rows and 1 columns.
# Aggregator did 1 substitutions.
# Reduced MIP has 10 rows, 22 columns, and 20 nonzeros.
# Reduced MIP has 10 binaries, 11 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.02 ticks)
# Probing time = 0.00 sec. (0.00 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.01 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.0258        0.0252             2.16%
#       0     0        0.0252     1        0.0258        0.0252        0    2.16%
#       0     0        0.0252     1        0.0258      Fract: 1        1    2.16%
#       0     2        0.0252     2        0.0258        0.0252        1    2.16%                        0             0
# Elapsed time = 0.06 sec. (0.64 ticks, tree = 0.01 MB, solutions = 1)
# *   390+   85                            0.0258        0.0252             2.05%
# *   510+   93                            0.0257        0.0252             1.97%
#
# Implied bound cuts applied:  1
# Gomory fractional cuts applied:  1
# User cuts applied:  151
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (0.65 ticks)
# Sequential b&c:
#   Real time             =    0.41 sec. (158.37 ticks)
#                           ------------
# Total (root+branch&cut) =    0.47 sec. (159.02 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-7 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_property>=1                                |         2 points |   + ..... |
# | p_arrest>=5                                  |         1 points |   + ..... |
# | p_felony>=1                                  |         1 points |   + ..... |
# | p_pending_charge>=1                          |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 4                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:15 PM | 501 rows in lookup table
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | runnning initialization procedure
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | CPA produced 2 cuts
# 08/17/19 @ 04:15 PM | running naive rounding on 153 solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0249
# 08/17/19 @ 04:15 PM | rounding produced 2 integer solutions
# 08/17/19 @ 04:15 PM | best objective value is 0.0255
# 08/17/19 @ 04:15 PM | running sequential rounding on 153 solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0249
# 08/17/19 @ 04:15 PM | sequential rounding produced 1 integer solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0255
# 08/17/19 @ 04:15 PM | polishing 3 solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0255
# 08/17/19 @ 04:15 PM | polishing produced 2 integer solutions
# 08/17/19 @ 04:15 PM | initialization produced 3 feasible solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0255
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | completed initialization procedure
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | 501 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.024926502503594464
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.025496136045790454
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:15 PM | adding 152 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.0255.
# Tried aggregator 2 times.
# MIP Presolve eliminated 1 rows and 1 columns.
# Aggregator did 1 substitutions.
# Reduced MIP has 10 rows, 22 columns, and 20 nonzeros.
# Reduced MIP has 10 binaries, 11 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.02 ticks)
# Probing time = 0.00 sec. (0.00 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.01 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.0255        0.0249             2.23%
#       0     0        0.0249     1        0.0255        0.0249        0    2.23%
#       0     0        0.0249     1        0.0255      Fract: 1        1    2.23%
#       0     2        0.0249     2        0.0255        0.0249        1    2.23%                        0             0
# Elapsed time = 0.08 sec. (0.66 ticks, tree = 0.01 MB, solutions = 1)
# *   350+   75                            0.0255        0.0249             2.07%
# *   386    80      integral     0        0.0254        0.0249     1204    2.03%
# *   587   110      integral     0        0.0254        0.0249     2045    1.87%
#
# Gomory fractional cuts applied:  1
# User cuts applied:  152
#
# Root node processing (before b&c):
#   Real time             =    0.08 sec. (0.67 ticks)
# Sequential b&c:
#   Real time             =    0.50 sec. (187.18 ticks)
#                           ------------
# Total (root+branch&cut) =    0.58 sec. (187.85 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-7 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_property>=1                                |         2 points |   + ..... |
# | p_arrest>=5                                  |         1 points |   + ..... |
# | p_felony>=1                                  |         1 points |   + ..... |
# | p_pending_charge>=1                          |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 4                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:15 PM | 501 rows in lookup table
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | runnning initialization procedure
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | CPA produced 2 cuts
# 08/17/19 @ 04:15 PM | running naive rounding on 135 solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0248
# 08/17/19 @ 04:15 PM | rounding produced 1 integer solutions
# 08/17/19 @ 04:15 PM | best objective value is 0.0260
# 08/17/19 @ 04:15 PM | running sequential rounding on 135 solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0248
# 08/17/19 @ 04:15 PM | sequential rounding produced 1 integer solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0253
# 08/17/19 @ 04:15 PM | polishing 2 solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0253
# 08/17/19 @ 04:15 PM | polishing produced 1 integer solutions
# 08/17/19 @ 04:15 PM | initialization produced 2 feasible solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0253
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | completed initialization procedure
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | 501 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.024798539895197216
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.025333534224436498
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:15 PM | adding 134 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.0253.
# Tried aggregator 2 times.
# MIP Presolve eliminated 1 rows and 1 columns.
# Aggregator did 1 substitutions.
# Reduced MIP has 10 rows, 22 columns, and 20 nonzeros.
# Reduced MIP has 10 binaries, 11 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.02 ticks)
# Probing time = 0.00 sec. (0.00 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.01 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.0253        0.0248             2.11%
#       0     0        0.0248     1        0.0253        0.0248        0    2.11%
#       0     0        0.0248     1        0.0253      Fract: 1        1    2.11%
#       0     2        0.0248     2        0.0253        0.0248        1    2.11%                        0             0
# Elapsed time = 0.06 sec. (0.59 ticks, tree = 0.01 MB, solutions = 1)
# *   630+  132                            0.0253        0.0248             1.98%
#
# Gomory fractional cuts applied:  1
# User cuts applied:  149
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (0.60 ticks)
# Sequential b&c:
#   Real time             =    0.39 sec. (130.10 ticks)
#                           ------------
# Total (root+branch&cut) =    0.45 sec. (130.70 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-8 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_property>=1                                |         2 points |   + ..... |
# | p_arrest>=2                                  |         1 points |   + ..... |
# | p_felony>=1                                  |         1 points |   + ..... |
# | p_fta_two_year>=1                            |         1 points |   + ..... |
# | p_pending_charge>=1                          |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 5                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:15 PM | 501 rows in lookup table
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | runnning initialization procedure
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | CPA produced 2 cuts
# 08/17/19 @ 04:15 PM | running naive rounding on 167 solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0256
# 08/17/19 @ 04:15 PM | rounding produced 1 integer solutions
# 08/17/19 @ 04:15 PM | best objective value is 0.0263
# 08/17/19 @ 04:15 PM | running sequential rounding on 167 solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0256
# 08/17/19 @ 04:15 PM | sequential rounding produced 3 integer solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0261
# 08/17/19 @ 04:15 PM | polishing 4 solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0261
# 08/17/19 @ 04:15 PM | polishing produced 3 integer solutions
# 08/17/19 @ 04:15 PM | initialization produced 4 feasible solutions
# 08/17/19 @ 04:15 PM | best objective value: 0.0261
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | completed initialization procedure
# 08/17/19 @ 04:15 PM | ------------------------------------------------------------
# 08/17/19 @ 04:15 PM | 501 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.025629103541883153
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.02605529300266959
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:15 PM | adding 166 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.0261.
# Tried aggregator 2 times.
# MIP Presolve eliminated 1 rows and 1 columns.
# Aggregator did 1 substitutions.
# Reduced MIP has 10 rows, 22 columns, and 20 nonzeros.
# Reduced MIP has 10 binaries, 11 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.02 ticks)
# Probing time = 0.00 sec. (0.00 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.01 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.0261        0.0256             1.64%
#       0     0        0.0256     1        0.0261        0.0256        0    1.64%
#       0     0        0.0256     1        0.0261      Fract: 1        1    1.64%
#       0     2        0.0256     2        0.0261        0.0256        1    1.64%                        0             0
# Elapsed time = 0.06 sec. (0.65 ticks, tree = 0.01 MB, solutions = 1)
#
# Implied bound cuts applied:  1
# Gomory fractional cuts applied:  1
# User cuts applied:  127
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (0.66 ticks)
# Sequential b&c:
#   Real time             =    0.33 sec. (96.16 ticks)
#                           ------------
# Total (root+branch&cut) =    0.39 sec. (96.82 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-7 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_property>=1                                |         2 points |   + ..... |
# | p_felony>=1                                  |         1 points |   + ..... |
# | p_fta_two_year>=1                            |         1 points |   + ..... |
# | p_pending_charge>=1                          |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 4                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+

# %%
np.mean(train_auc), np.mean(test_auc)
# Out:
# (0.8345588729889863, 0.8296609171858751)

# %% [markdown]
# ### Save Results

# %%
#log model results to the model performance folder, as per standards
path = "C:\\Users\\binha\\Documents\\Duke\\Cynthia Research\\KY-analysis-mytrials\\KY Recidivism\\KY Results\\Models\\Six Month\\"                   
results = [["Property", np.mean(train_auc), np.std(train_auc), np.mean(test_auc), np.std(test_auc)]]

with open(path + 'Six Month RiskSLIM.csv', 'a') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(results)
