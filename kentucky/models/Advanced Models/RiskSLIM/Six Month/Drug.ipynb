# %%
import numpy as np
import pandas as pd
import RiskSLIM as risk
import csv

from riskslim.helper_functions import load_data_from_csv, print_model
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.utils import shuffle

# %% [markdown]
# ### Lasso Feature Selection

# %%
## load stumps data
data = pd.read_csv("C:/Users/binha/Documents/Duke/Cynthia Research/KY-analysis-mytrials/KY Recidivism/KY data/kentucky_stumps.csv")
X, Y = data.loc[:,:'current_violence>=1'], data['recid_drug_six_month'].values
cols = X.columns

# %%
## lasso
lasso = Lasso(random_state=816, alpha=0.001).fit(X, Y)
selected_features = cols[lasso.coef_ != 0].tolist()
len(selected_features), roc_auc_score(Y, lasso.predict(X))
# Out:
# (18, 0.7722008166199879)

# %% [markdown]
# #### subset features

# %%
### Subset features
selected_features.insert(0, 'recid_drug_six_month')
sub_data = data[selected_features]
sub_X, sub_Y = sub_data.iloc[:,1:], sub_data.iloc[:,0].values
sub_X.insert(0, '(Intercept)', 1)

# %% [markdown]
# ### Cross Validation

# %%
SLIM_X, SLIM_Y = sub_X.values, sub_Y.reshape(-1,1)
variable_names = sub_X.columns.tolist()
outcome_name = 'recid_drug_six_month'
sample_weights = np.repeat(1, len(sub_Y))

# %%
#cv = KFold(n_splits=5, random_state=816, shuffle=True)
cv = KFold(n_splits=5, random_state=816, shuffle=True)
train_auc, test_auc = [], []

i = 0
for train, test in cv.split(SLIM_X, SLIM_Y):
    
    ## subset train data & store test data
    X_train, Y_train = SLIM_X[train], SLIM_Y[train]
    X_test, Y_test = SLIM_X[test], SLIM_Y[test]
    sample_weights_train, sample_weights_test = sample_weights[train], sample_weights[test]

    ## create new data dictionary
    new_train_data = {
        'X': X_train,
        'Y': Y_train,
        'variable_names': variable_names,
        'outcome_name': outcome_name,
        'sample_weights': sample_weights_train
    }
        
    ## fit the model
    model_info, mip_info, lcpa_info = risk.risk_slim(new_train_data, max_coefficient=20, max_L0_value=10, 
                                                c0_value=1e-5, max_runtime=400)
    print_model(model_info['solution'], new_train_data)
    
    ## change data format
    X_train, X_test = X_train[:,1:], X_test[:,1:] ## remove the first column, which is "intercept"
    Y_train[Y_train == -1] = 0 ## change -1 to 0
    Y_test[Y_test == -1] = 0
    
    ## probability & accuracy
    train_prob = risk.riskslim_prediction(X_train, cols, model_info).reshape(-1,1)
    test_prob = risk.riskslim_prediction(X_test, cols, model_info).reshape(-1,1)
    
    ## AUC
    train_auc.append(roc_auc_score(Y_train, train_prob))
    test_auc.append(roc_auc_score(Y_test, test_prob))
# Out:
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:12 PM | 821 rows in lookup table
# 08/17/19 @ 04:12 PM | ------------------------------------------------------------
# 08/17/19 @ 04:12 PM | runnning initialization procedure
# 08/17/19 @ 04:12 PM | ------------------------------------------------------------
# 08/17/19 @ 04:12 PM | CPA produced 2 cuts
# 08/17/19 @ 04:12 PM | running naive rounding on 99 solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0929
# 08/17/19 @ 04:12 PM | rounding produced 4 integer solutions
# 08/17/19 @ 04:12 PM | best objective value is 0.0961
# 08/17/19 @ 04:12 PM | running sequential rounding on 99 solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0929
# 08/17/19 @ 04:12 PM | sequential rounding produced 3 integer solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0944
# 08/17/19 @ 04:12 PM | polishing 7 solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0944
# 08/17/19 @ 04:12 PM | polishing produced 5 integer solutions
# 08/17/19 @ 04:12 PM | initialization produced 7 feasible solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0944
# 08/17/19 @ 04:12 PM | ------------------------------------------------------------
# 08/17/19 @ 04:12 PM | completed initialization procedure
# 08/17/19 @ 04:12 PM | ------------------------------------------------------------
# 08/17/19 @ 04:12 PM | 821 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               400
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.092859295973217459
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.094361823542342266
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:12 PM | adding 206 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.0944.
# Tried aggregator 1 time.
# Reduced MIP has 20 rows, 40 columns, and 75 nonzeros.
# Reduced MIP has 18 binaries, 20 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.0944        0.0928             1.70%
#       0     0        0.0929     1        0.0944        0.0929        1    1.59%
#       0     2        0.0929     2        0.0944        0.0929        1    1.59%                        0             0
# Elapsed time = 0.09 sec. (0.92 ticks, tree = 0.01 MB, solutions = 1)
#    2200   568        0.0934    10        0.0944        0.0929    10660    1.59%          rho_16 D   2200    395     15
#    3825   509        0.0939    11        0.0944        0.0936    17856    0.83%           rho_1 U   3825   3824     15
#
# User cuts applied:  211
#
# Root node processing (before b&c):
#   Real time             =    0.09 sec. (0.93 ticks)
# Sequential b&c:
#   Real time             =    1.08 sec. (603.70 ticks)
#                           ------------
# Total (root+branch&cut) =    1.17 sec. (604.63 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-6 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_arrest>=4                                  |         1 points |   + ..... |
# | p_felony>=1                                  |         1 points |   + ..... |
# | p_misdemeanor>=1                             |         1 points |   + ..... |
# | p_drug>=1                                    |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 4                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:12 PM | 821 rows in lookup table
# 08/17/19 @ 04:12 PM | ------------------------------------------------------------
# 08/17/19 @ 04:12 PM | runnning initialization procedure
# 08/17/19 @ 04:12 PM | ------------------------------------------------------------
# 08/17/19 @ 04:12 PM | CPA produced 2 cuts
# 08/17/19 @ 04:12 PM | running naive rounding on 104 solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0920
# 08/17/19 @ 04:12 PM | rounding produced 5 integer solutions
# 08/17/19 @ 04:12 PM | best objective value is 0.0950
# 08/17/19 @ 04:12 PM | running sequential rounding on 104 solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0920
# 08/17/19 @ 04:12 PM | sequential rounding produced 5 integer solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0935
# 08/17/19 @ 04:12 PM | polishing 10 solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0935
# 08/17/19 @ 04:12 PM | polishing produced 5 integer solutions
# 08/17/19 @ 04:12 PM | initialization produced 10 feasible solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0935
# 08/17/19 @ 04:12 PM | ------------------------------------------------------------
# 08/17/19 @ 04:12 PM | completed initialization procedure
# 08/17/19 @ 04:12 PM | ------------------------------------------------------------
# 08/17/19 @ 04:12 PM | 821 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               400
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.092020536586059687
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.093483046503554934
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:12 PM | adding 203 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.0935.
# Tried aggregator 1 time.
# Reduced MIP has 20 rows, 40 columns, and 75 nonzeros.
# Reduced MIP has 18 binaries, 20 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.0935        0.0919             1.67%
#       0     0        0.0920     1        0.0935        0.0920        1    1.56%
#       0     2        0.0920     1        0.0935        0.0920        1    1.56%                        0             0
# Elapsed time = 0.06 sec. (0.92 ticks, tree = 0.01 MB, solutions = 1)
#    2172   515        0.0929     9        0.0935        0.0922    10705    1.41%           rho_1 U   2172   1582     13
#
# User cuts applied:  201
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (0.93 ticks)
# Sequential b&c:
#   Real time             =    0.97 sec. (432.85 ticks)
#                           ------------
# Total (root+branch&cut) =    1.03 sec. (433.79 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-6 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_arrest>=4                                  |         1 points |   + ..... |
# | p_felony>=1                                  |         1 points |   + ..... |
# | p_misdemeanor>=1                             |         1 points |   + ..... |
# | p_drug>=1                                    |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 4                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:12 PM | 821 rows in lookup table
# 08/17/19 @ 04:12 PM | ------------------------------------------------------------
# 08/17/19 @ 04:12 PM | runnning initialization procedure
# 08/17/19 @ 04:12 PM | ------------------------------------------------------------
# 08/17/19 @ 04:12 PM | CPA produced 2 cuts
# 08/17/19 @ 04:12 PM | running naive rounding on 96 solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0935
# 08/17/19 @ 04:12 PM | rounding produced 4 integer solutions
# 08/17/19 @ 04:12 PM | best objective value is 0.0951
# 08/17/19 @ 04:12 PM | running sequential rounding on 96 solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0935
# 08/17/19 @ 04:12 PM | sequential rounding produced 2 integer solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0949
# 08/17/19 @ 04:12 PM | polishing 6 solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0949
# 08/17/19 @ 04:12 PM | polishing produced 5 integer solutions
# 08/17/19 @ 04:12 PM | initialization produced 7 feasible solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0949
# 08/17/19 @ 04:12 PM | ------------------------------------------------------------
# 08/17/19 @ 04:12 PM | completed initialization procedure
# 08/17/19 @ 04:12 PM | ------------------------------------------------------------
# 08/17/19 @ 04:12 PM | 821 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               400
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.093371662826549684
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.094920812347495165
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:12 PM | adding 196 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.0949.
# Tried aggregator 1 time.
# Reduced MIP has 20 rows, 40 columns, and 75 nonzeros.
# Reduced MIP has 18 binaries, 20 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.04 ticks)
# Probing time = 0.02 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.0949        0.0933             1.74%
#       0     0        0.0934     1        0.0949        0.0934        1    1.63%
#       0     2        0.0934     2        0.0949        0.0934        1    1.63%                        0             0
# Elapsed time = 0.09 sec. (0.93 ticks, tree = 0.01 MB, solutions = 1)
#    2345   476        0.0947    10        0.0949        0.0934    11025    1.63%          rho_16 D   2345   2344     14
#    3780   422        0.0945    12        0.0949        0.0941    17579    0.84%           rho_0 D   3780   1761     14
#
# User cuts applied:  240
#
# Root node processing (before b&c):
#   Real time             =    0.09 sec. (0.94 ticks)
# Sequential b&c:
#   Real time             =    1.23 sec. (595.41 ticks)
#                           ------------
# Total (root+branch&cut) =    1.33 sec. (596.35 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-5 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_arrest>=4                                  |         1 points |   + ..... |
# | p_drug>=1                                    |         1 points |   + ..... |
# | p_pending_charge>=1                          |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:12 PM | 821 rows in lookup table
# 08/17/19 @ 04:12 PM | ------------------------------------------------------------
# 08/17/19 @ 04:12 PM | runnning initialization procedure
# 08/17/19 @ 04:12 PM | ------------------------------------------------------------
# 08/17/19 @ 04:12 PM | CPA produced 2 cuts
# 08/17/19 @ 04:12 PM | running naive rounding on 96 solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0916
# 08/17/19 @ 04:12 PM | rounding produced 4 integer solutions
# 08/17/19 @ 04:12 PM | best objective value is 0.0934
# 08/17/19 @ 04:12 PM | running sequential rounding on 96 solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0916
# 08/17/19 @ 04:12 PM | sequential rounding produced 3 integer solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0930
# 08/17/19 @ 04:12 PM | polishing 7 solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0930
# 08/17/19 @ 04:12 PM | polishing produced 5 integer solutions
# 08/17/19 @ 04:12 PM | initialization produced 8 feasible solutions
# 08/17/19 @ 04:12 PM | best objective value: 0.0930
# 08/17/19 @ 04:12 PM | ------------------------------------------------------------
# 08/17/19 @ 04:12 PM | completed initialization procedure
# 08/17/19 @ 04:12 PM | ------------------------------------------------------------
# 08/17/19 @ 04:12 PM | 821 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               400
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.091479449704207891
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.09298272216885814
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:12 PM | adding 191 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.0930.
# Tried aggregator 1 time.
# Reduced MIP has 20 rows, 40 columns, and 75 nonzeros.
# Reduced MIP has 18 binaries, 20 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.0930        0.0914             1.72%
#       0     0        0.0915     1        0.0930        0.0915        1    1.62%
#       0     0        0.0915     3        0.0930    MIRcuts: 1        4    1.62%
#       0     0        0.0915     2        0.0930   ZeroHalf: 1        5    1.62%
#       0     2        0.0915     4        0.0930        0.0915        5    1.62%                        0             0
# Elapsed time = 0.13 sec. (1.22 ticks, tree = 0.01 MB, solutions = 1)
#    2277   637        0.0915    10        0.0930        0.0915    11284    1.62%           rho_0 D   2277    863     11
#    3670   875        0.0928    10        0.0930        0.0917    19432    1.37%           rho_0 D   3670   3669     17
#    5125   553        cutoff              0.0930        0.0924    25495    0.63%          rho_10 U   5125   5123     25
#
# Implied bound cuts applied:  1
# User cuts applied:  236
#
# Root node processing (before b&c):
#   Real time             =    0.13 sec. (1.23 ticks)
# Sequential b&c:
#   Real time             =    2.20 sec. (849.74 ticks)
#                           ------------
# Total (root+branch&cut) =    2.33 sec. (850.97 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-6 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_arrest>=4                                  |         1 points |   + ..... |
# | p_felony>=1                                  |         1 points |   + ..... |
# | p_misdemeanor>=1                             |         1 points |   + ..... |
# | p_drug>=1                                    |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 4                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:13 PM | 821 rows in lookup table
# 08/17/19 @ 04:13 PM | ------------------------------------------------------------
# 08/17/19 @ 04:13 PM | runnning initialization procedure
# 08/17/19 @ 04:13 PM | ------------------------------------------------------------
# 08/17/19 @ 04:13 PM | CPA produced 2 cuts
# 08/17/19 @ 04:13 PM | running naive rounding on 90 solutions
# 08/17/19 @ 04:13 PM | best objective value: 0.0931
# 08/17/19 @ 04:13 PM | rounding produced 5 integer solutions
# 08/17/19 @ 04:13 PM | best objective value is 0.0947
# 08/17/19 @ 04:13 PM | running sequential rounding on 90 solutions
# 08/17/19 @ 04:13 PM | best objective value: 0.0931
# 08/17/19 @ 04:13 PM | sequential rounding produced 2 integer solutions
# 08/17/19 @ 04:13 PM | best objective value: 0.0947
# 08/17/19 @ 04:13 PM | polishing 7 solutions
# 08/17/19 @ 04:13 PM | best objective value: 0.0947
# 08/17/19 @ 04:13 PM | polishing produced 5 integer solutions
# 08/17/19 @ 04:13 PM | initialization produced 7 feasible solutions
# 08/17/19 @ 04:13 PM | best objective value: 0.0947
# 08/17/19 @ 04:13 PM | ------------------------------------------------------------
# 08/17/19 @ 04:13 PM | completed initialization procedure
# 08/17/19 @ 04:13 PM | ------------------------------------------------------------
# 08/17/19 @ 04:13 PM | 821 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               400
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.092963171008928674
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.094725341053376724
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:13 PM | adding 202 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.0947.
# Tried aggregator 1 time.
# Reduced MIP has 20 rows, 40 columns, and 75 nonzeros.
# Reduced MIP has 18 binaries, 20 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.04 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.0947        0.0929             1.97%
#       0     0        0.0930     1        0.0947        0.0930        1    1.86%
#       0     2        0.0930     2        0.0947        0.0930        1    1.86%                        0             0
# Elapsed time = 0.06 sec. (0.91 ticks, tree = 0.01 MB, solutions = 1)
# *   440+  143                            0.0947        0.0930             1.84%
# *   620+  215                            0.0947        0.0930             1.82%
# *  1200+  330                            0.0947        0.0930             1.81%
# *  1200+  327                            0.0946        0.0930             1.76%
#    1991   486        cutoff              0.0946        0.0930     9315    1.76%          rho_10 D   1991   1989     18
#    3285   536        cutoff              0.0946        0.0936    15833    1.09%           rho_9 U   3285   3284     24
# *  4157   178      integral     0        0.0946        0.0943    19234    0.35%
#
# User cuts applied:  249
#
# Root node processing (before b&c):
#   Real time             =    0.06 sec. (0.93 ticks)
# Sequential b&c:
#   Real time             =    1.14 sec. (663.07 ticks)
#                           ------------
# Total (root+branch&cut) =    1.20 sec. (664.00 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-6 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_arrest>=5                                  |         1 points |   + ..... |
# | p_felony>=1                                  |         1 points |   + ..... |
# | p_misdemeanor>=1                             |         1 points |   + ..... |
# | p_drug>=1                                    |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 4                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+

# %%
np.mean(train_auc), np.mean(test_auc)
# Out:
# (0.7371669533601263, 0.7345438569561222)

# %% [markdown]
# ### Save Results

# %%
#log model results to the model performance folder, as per standards
path = "C:\\Users\\binha\\Documents\\Duke\\Cynthia Research\\KY-analysis-mytrials\\KY Recidivism\\KY Results\\Models\\Six Month\\"                   
results = [["Drug", np.mean(train_auc), np.std(train_auc), np.mean(test_auc), np.std(test_auc)]]

with open(path + 'Six Month RiskSLIM.csv', 'a') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(results)
