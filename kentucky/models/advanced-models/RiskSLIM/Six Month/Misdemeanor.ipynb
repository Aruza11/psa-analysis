# %%
import numpy as np
import pandas as pd
import RiskSLIM as risk
import csv

from riskslim.helper_functions import load_data_from_csv, print_model
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.utils import shuffle

# %% [markdown]
# ### Lasso Feature Selection

# %%
## load stumps data
data = pd.read_csv("C:/Users/binha/Documents/Duke/Cynthia Research/KY-analysis-mytrials/KY Recidivism/KY data/kentucky_stumps.csv")
X, Y = data.loc[:,:'current_violence>=1'], data['recid_M_six_month'].values
cols = X.columns

# %%
## lasso
lasso = Lasso(random_state=816, alpha=0.001).fit(X, Y)
selected_features = cols[lasso.coef_ != 0].tolist()
len(selected_features), roc_auc_score(Y, lasso.predict(X))
# Out:
# (27, 0.7482263468143036)

# %% [markdown]
# #### subset features

# %%
### Subset features
selected_features.insert(0, 'recid_M_six_month')
sub_data = data[selected_features]
sub_X, sub_Y = sub_data.iloc[:,1:], sub_data.iloc[:,0].values
sub_X.insert(0, '(Intercept)', 1)

# %% [markdown]
# ### Cross Validation

# %%
SLIM_X, SLIM_Y = sub_X.values, sub_Y.reshape(-1,1)
variable_names = sub_X.columns.tolist()
outcome_name = 'recid_M_six_month'
sample_weights = np.repeat(1, len(sub_Y))

# %%
#cv = KFold(n_splits=5, random_state=816, shuffle=True)
cv = KFold(n_splits=5, random_state=816, shuffle=True)
train_auc, test_auc = [], []

i = 0
for train, test in cv.split(SLIM_X, SLIM_Y):
    
    ## subset train data & store test data
    X_train, Y_train = SLIM_X[train], SLIM_Y[train]
    X_test, Y_test = SLIM_X[test], SLIM_Y[test]
    sample_weights_train, sample_weights_test = sample_weights[train], sample_weights[test]

    ## create new data dictionary
    new_train_data = {
        'X': X_train,
        'Y': Y_train,
        'variable_names': variable_names,
        'outcome_name': outcome_name,
        'sample_weights': sample_weights_train
    }
        
    ## fit the model
    model_info, mip_info, lcpa_info = risk.risk_slim(new_train_data, max_coefficient=20, max_L0_value=10, 
                                                c0_value=1e-3, max_runtime=200)
    print_model(model_info['solution'], new_train_data)
    
    ## change data format
    X_train, X_test = X_train[:,1:], X_test[:,1:] ## remove the first column, which is "intercept"
    Y_train[Y_train == -1] = 0 ## change -1 to 0
    Y_test[Y_test == -1] = 0
    
    ## probability & accuracy
    train_prob = risk.riskslim_prediction(X_train, cols, model_info).reshape(-1,1)
    test_prob = risk.riskslim_prediction(X_test, cols, model_info).reshape(-1,1)
    
    ## AUC
    train_auc.append(roc_auc_score(Y_train, train_prob))
    test_auc.append(roc_auc_score(Y_test, test_prob))
# Out:
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:33 PM | 1181 rows in lookup table
# 08/17/19 @ 04:33 PM | ------------------------------------------------------------
# 08/17/19 @ 04:33 PM | runnning initialization procedure
# 08/17/19 @ 04:33 PM | ------------------------------------------------------------
# 08/17/19 @ 04:33 PM | CPA produced 2 cuts
# 08/17/19 @ 04:33 PM | running naive rounding on 84 solutions
# 08/17/19 @ 04:33 PM | best objective value: 0.1822
# 08/17/19 @ 04:33 PM | rounding produced 5 integer solutions
# 08/17/19 @ 04:33 PM | best objective value is 0.1893
# 08/17/19 @ 04:33 PM | running sequential rounding on 84 solutions
# 08/17/19 @ 04:33 PM | best objective value: 0.1822
# 08/17/19 @ 04:33 PM | sequential rounding produced 5 integer solutions
# 08/17/19 @ 04:33 PM | best objective value: 0.1887
# 08/17/19 @ 04:33 PM | polishing 10 solutions
# 08/17/19 @ 04:33 PM | best objective value: 0.1887
# 08/17/19 @ 04:33 PM | polishing produced 3 integer solutions
# 08/17/19 @ 04:33 PM | initialization produced 11 feasible solutions
# 08/17/19 @ 04:33 PM | best objective value: 0.1883
# 08/17/19 @ 04:33 PM | ------------------------------------------------------------
# 08/17/19 @ 04:33 PM | completed initialization procedure
# 08/17/19 @ 04:33 PM | ------------------------------------------------------------
# 08/17/19 @ 04:33 PM | 1181 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.18042703296875512
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.18833908635859681
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:33 PM | adding 255 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.1883.
# Tried aggregator 1 time.
# Reduced MIP has 29 rows, 58 columns, and 111 nonzeros.
# Reduced MIP has 27 binaries, 29 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.06 ticks)
# Probing time = 0.00 sec. (0.02 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.04 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.1883        0.1704             9.51%
#       0     0        0.1804     1        0.1883        0.1804        1    4.20%
#       0     0        0.1804     1        0.1883       Cuts: 2        4    4.20%
#       0     0        0.1804     1        0.1883      Fract: 1        5    4.20%
#       0     2        0.1804     2        0.1883        0.1804        5    4.20%                        0             0
# Elapsed time = 0.34 sec. (2.00 ticks, tree = 0.01 MB, solutions = 1)
#    1885   751        0.1825     5        0.1883        0.1804     9942    4.20%           rho_3 D   1885   1884     19
#    3020  1329        0.1805    16        0.1883        0.1804    16666    4.20%           rho_4 U   3020   3018     10
#    3996  1830        0.1827     8        0.1883        0.1804    22615    4.20%           rho_3 D   3996   3995     21
#    4903  2301        0.1807    24        0.1883        0.1804    28155    4.20%          rho_23 D   4903   4902     10
#    5739  2752        0.1832     9        0.1883        0.1804    33552    4.20%          rho_24 D   5739   5738     14
#    6527  3182        0.1806    26        0.1883        0.1804    38941    4.20%           rho_4 D   6527   5949     10
# *  6882  3207      integral     0        0.1878        0.1806    40728    3.86%
#    7430  3409        0.1833     7        0.1878        0.1807    43276    3.79%          rho_25 D   7430   7429     22
#    8355  3741        0.1863     7        0.1878        0.1809    47691    3.67%           rho_5 U   8355   8354     18
#    9166  3978        0.1849    13        0.1878        0.1812    51854    3.55%          rho_17 U   9166   5972     16
#   12755  5081        0.1873     9        0.1878        0.1819    68839    3.15%          rho_17 U  12755  12753     14
# Elapsed time = 9.02 sec. (3105.36 ticks, tree = 1.53 MB, solutions = 2)
#   16215  5853        cutoff              0.1878        0.1825    85060    2.82%          rho_27 U  16215  16214     25
#   19503  6487        0.1872     7        0.1878        0.1830    99311    2.57%          rho_25 N  19503  19502     27
#   22614  7048        0.1835    20        0.1878        0.1834   112818    2.34%          rho_15 D  22614  17193     17
#   25629  7510        0.1871    11        0.1878        0.1837   125850    2.17%          rho_11 D  25629  25627     26
#   28612  7908        cutoff              0.1878        0.1840   138240    2.02%          rho_10 U  28612  28611     19
# * 28706  7626      integral     0        0.1876        0.1840   138571    1.89%
#   31432  7781        cutoff              0.1876        0.1843   149969    1.75%           rho_3 N  31432  31431     21
#   34214  7883        cutoff              0.1876        0.1845   161137    1.63%           rho_6 U  34214  34213     25
#   36921  7929        0.1857     8        0.1876        0.1848   172061    1.50%           rho_3 D  36921  36920     17
#   39599  7829        0.1851    12        0.1876        0.1850   182500    1.39%          rho_11 D  39599  39597     21
#   42341  7753        cutoff              0.1876        0.1851   192529    1.30%          rho_27 U  42341  42340     21
# Elapsed time = 25.45 sec. (12643.19 ticks, tree = 2.30 MB, solutions = 3)
#   44970  7485        0.1873     7        0.1876        0.1853   202304    1.19%           rho_6 D  44970  44968     22
#   47538  7176        0.1870     7        0.1876        0.1855   211771    1.09%           rho_6 N  47538  24000     20
#   50075  6605        cutoff              0.1876        0.1858   220887    0.97%          rho_17 U  50075  10271     17
#   52592  6049        cutoff              0.1876        0.1860   229710    0.87%          rho_16 U  52592  52591     16
# * 54084  5452      integral     0        0.1875        0.1861   234796    0.76%
#   55134  5050        cutoff              0.1875        0.1862   238457    0.70%          rho_25 U  55134  55133     23
#   57616  3835        0.1871     5        0.1875        0.1865   246810    0.55%          rho_27 D  57616  57614     29
#   60115  1975        cutoff              0.1875        0.1869   253280    0.32%           rho_2 U  60115  53228     24
#
# Gomory fractional cuts applied:  1
# User cuts applied:  499
#
# Root node processing (before b&c):
#   Real time             =    0.33 sec. (2.05 ticks)
# Sequential b&c:
#   Real time             =   32.75 sec. (20087.03 ticks)
#                           ------------
# Total (root+branch&cut) =   33.08 sec. (20089.07 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_arrest>=2                                  |         1 points |   + ..... |
# | p_arrest>=7                                  |         1 points |   + ..... |
# | p_pending_charge>=1                          |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:33 PM | 1181 rows in lookup table
# 08/17/19 @ 04:33 PM | ------------------------------------------------------------
# 08/17/19 @ 04:33 PM | runnning initialization procedure
# 08/17/19 @ 04:33 PM | ------------------------------------------------------------
# 08/17/19 @ 04:34 PM | CPA produced 2 cuts
# 08/17/19 @ 04:34 PM | running naive rounding on 82 solutions
# 08/17/19 @ 04:34 PM | best objective value: 0.1819
# 08/17/19 @ 04:34 PM | rounding produced 5 integer solutions
# 08/17/19 @ 04:34 PM | best objective value is 0.2003
# 08/17/19 @ 04:34 PM | running sequential rounding on 82 solutions
# 08/17/19 @ 04:34 PM | best objective value: 0.1819
# 08/17/19 @ 04:34 PM | sequential rounding produced 6 integer solutions
# 08/17/19 @ 04:34 PM | best objective value: 0.1880
# 08/17/19 @ 04:34 PM | polishing 11 solutions
# 08/17/19 @ 04:34 PM | best objective value: 0.1880
# 08/17/19 @ 04:34 PM | polishing produced 5 integer solutions
# 08/17/19 @ 04:34 PM | initialization produced 13 feasible solutions
# 08/17/19 @ 04:34 PM | best objective value: 0.1880
# 08/17/19 @ 04:34 PM | ------------------------------------------------------------
# 08/17/19 @ 04:34 PM | completed initialization procedure
# 08/17/19 @ 04:34 PM | ------------------------------------------------------------
# 08/17/19 @ 04:34 PM | 1181 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.18042665142972841
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.1880387475285539
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:34 PM | adding 258 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.1880.
# Tried aggregator 1 time.
# Reduced MIP has 29 rows, 58 columns, and 111 nonzeros.
# Reduced MIP has 27 binaries, 29 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.06 ticks)
# Probing time = 0.00 sec. (0.02 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.04 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.1880        0.1704             9.37%
#       0     0        0.1804     1        0.1880        0.1804        1    4.05%
#       0     0        0.1804     1        0.1880       Cuts: 2        4    4.05%
#       0     0        0.1804     1        0.1880      Fract: 1        5    4.05%
#       0     2        0.1804     2        0.1880        0.1804        5    4.05%                        0             0
# Elapsed time = 0.13 sec. (2.01 ticks, tree = 0.01 MB, solutions = 1)
#    2016   906        0.1804    10        0.1880        0.1804    11333    4.05%          rho_13 U   2016   2015     16
#    3165  1443        0.1829    10        0.1880        0.1804    19322    4.05%          rho_13 U   3165   1104     16
#    4119  1879        0.1806    17        0.1880        0.1804    26486    4.05%         L0_norm U   4119   4117     16
#    5070  2309        0.1874     9        0.1880        0.1806    32809    3.94%           rho_6 D   5070   5068     22
#    6052  2623        cutoff              0.1880        0.1810    38377    3.75%         L0_norm D   6052   6050     17
#    6976  2920        0.1843    10        0.1880        0.1813    43331    3.58%          rho_27 D   6976   6975     25
#    7860  3228        0.1848    14        0.1880        0.1815    48036    3.45%           rho_3 D   7860   7858     27
#    8733  3471        0.1860    15        0.1880        0.1817    52551    3.35%          rho_13 D   8733   8732     15
#    9540  3702        0.1874     5        0.1880        0.1819    57119    3.24%          rho_24 D   9540   9539     18
#   12694  4397        0.1864    15        0.1880        0.1827    74607    2.82%          rho_25 D  12694  12693     26
# Elapsed time = 5.52 sec. (3102.65 ticks, tree = 1.38 MB, solutions = 1)
#   15523  4869        cutoff              0.1880        0.1834    91104    2.46%         L0_norm D  15523  15522     23
# * 16183  4824      integral     0        0.1878        0.1836    94811    2.26%
#   18085  4920        0.1872     9        0.1878        0.1841   105939    2.00%          rho_17 D  18085  18084     21
# * 19912  4708      integral     0        0.1877        0.1845   116416    1.68%
#   20450  4635        0.1848    12        0.1877        0.1846   119609    1.61%          rho_14 U  20450   5413     21
#   22701  4279        0.1858    15        0.1877        0.1852   132243    1.32%           rho_3 D  22701  17185     20
#   24864  3714        0.1865     9        0.1877        0.1857   144002    1.04%           rho_4 D  24864   3440     20
#   26941  2806        cutoff              0.1877        0.1862   154779    0.76%           rho_1 U  26941  13485     20
# * 28946  1365      integral     0        0.1876        0.1868   164069    0.40%
#   29023  1294        cutoff              0.1876        0.1868   164377    0.38%         L0_norm D  29023  23916     26
#
# Gomory fractional cuts applied:  1
# User cuts applied:  547
#
# Root node processing (before b&c):
#   Real time             =    0.13 sec. (2.06 ticks)
# Sequential b&c:
#   Real time             =   14.06 sec. (10382.98 ticks)
#                           ------------
# Total (root+branch&cut) =   14.19 sec. (10385.04 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_arrest>=2                                  |         1 points |   + ..... |
# | p_arrest>=7                                  |         1 points |   + ..... |
# | p_pending_charge>=1                          |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:34 PM | 1181 rows in lookup table
# 08/17/19 @ 04:34 PM | ------------------------------------------------------------
# 08/17/19 @ 04:34 PM | runnning initialization procedure
# 08/17/19 @ 04:34 PM | ------------------------------------------------------------
# 08/17/19 @ 04:34 PM | CPA produced 2 cuts
# 08/17/19 @ 04:34 PM | running naive rounding on 75 solutions
# 08/17/19 @ 04:34 PM | best objective value: 0.1832
# 08/17/19 @ 04:34 PM | rounding produced 5 integer solutions
# 08/17/19 @ 04:34 PM | best objective value is 0.1900
# 08/17/19 @ 04:34 PM | running sequential rounding on 75 solutions
# 08/17/19 @ 04:34 PM | best objective value: 0.1832
# 08/17/19 @ 04:34 PM | sequential rounding produced 6 integer solutions
# 08/17/19 @ 04:34 PM | best objective value: 0.1897
# 08/17/19 @ 04:34 PM | polishing 11 solutions
# 08/17/19 @ 04:34 PM | best objective value: 0.1897
# 08/17/19 @ 04:34 PM | polishing produced 5 integer solutions
# 08/17/19 @ 04:34 PM | initialization produced 10 feasible solutions
# 08/17/19 @ 04:34 PM | best objective value: 0.1897
# 08/17/19 @ 04:34 PM | ------------------------------------------------------------
# 08/17/19 @ 04:34 PM | completed initialization procedure
# 08/17/19 @ 04:34 PM | ------------------------------------------------------------
# 08/17/19 @ 04:34 PM | 1181 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.18198420469832249
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.18971342393112225
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:34 PM | adding 253 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.1897.
# Tried aggregator 1 time.
# Reduced MIP has 29 rows, 58 columns, and 111 nonzeros.
# Reduced MIP has 27 binaries, 29 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.06 ticks)
# Probing time = 0.00 sec. (0.02 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.04 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.1897        0.1720             9.35%
#       0     0        0.1820     1        0.1897        0.1820        1    4.07%
#       0     0        0.1820     1        0.1897       Cuts: 2        4    4.07%
#       0     0        0.1820     5        0.1897    MIRcuts: 1        7    4.07%
#       0     2        0.1820     1        0.1897        0.1820        7    4.07%                        0             0
# Elapsed time = 0.13 sec. (1.93 ticks, tree = 0.01 MB, solutions = 1)
#    2037   878        0.1879     7        0.1897        0.1820    10232    4.07%          rho_16 D   2037   2036      8
#    3129  1256        0.1825    15        0.1897        0.1820    17877    4.07%           rho_0 U   3129   3128     16
#    4090  1661        0.1865     7        0.1897        0.1820    24342    4.07%          rho_14 D   4090   4089     22
#    4981  2005        0.1873     5        0.1897        0.1820    29929    4.07%          rho_21 D   4981   4980     27
#    5822  2388        0.1833    12        0.1897        0.1820    35546    4.07%          rho_15 U   5822   5821     16
#    6646  2726        0.1839    15        0.1897        0.1822    40775    3.97%           rho_0 U   6646   6645     20
#    7549  3033        0.1862     7        0.1897        0.1825    45157    3.81%          rho_21 D   7549   7548     26
# *  7717  3004      integral     0        0.1893        0.1825    46080    3.58%
#    8400  3203        0.1853     9        0.1893        0.1828    49516    3.44%           rho_3 D   8400   8399     23
#    9237  3433        0.1882    13        0.1893        0.1830    53595    3.33%           rho_6 D   9237   9235     21
#   12418  4107        0.1876     7        0.1893        0.1837    68787    2.98%           rho_6 U  12418  12417     17
# Elapsed time = 5.22 sec. (3105.55 ticks, tree = 1.30 MB, solutions = 2)
#   15398  4645        0.1890     3        0.1893        0.1842    83122    2.68%          rho_14 N  15398   4670     26
#   18237  5014        0.1887     7        0.1893        0.1848    96609    2.41%           rho_4 D  18237  18236     20
#   20977  5196        0.1876     9        0.1893        0.1852   109279    2.16%          rho_22 U  20977  11078     25
#   23585  5295        cutoff              0.1893        0.1856   121301    1.94%           rho_2 U  23585  23584     24
# * 25524  5089      integral     0        0.1890        0.1859   129683    1.65%
#   26118  5064        cutoff              0.1890        0.1860   132156    1.60%          rho_21 U  26118  26117     27
#   28611  4920        0.1868    14        0.1890        0.1864   142656    1.42%          rho_14 D  28611  28610     18
#   31057  4640        0.1876     9        0.1890        0.1867   152882    1.25%          rho_14 D  31057  31056     19
#   33467  4155        0.1887     7        0.1890        0.1870   162594    1.06%          rho_11 N  33467  22286     28
#   35856  3509        cutoff              0.1890        0.1874   171628    0.85%          rho_16 U  35856  27831     15
#   38276  2472        cutoff              0.1890        0.1879   180223    0.60%          rho_21 U  38276  28113     26
# Elapsed time = 13.73 sec. (12643.95 ticks, tree = 0.95 MB, solutions = 3)
#   40731   657        cutoff              0.1890        0.1887   186595    0.19%          rho_21 U  40731  32004     25
#
# Implied bound cuts applied:  1
# Gomory fractional cuts applied:  1
# User cuts applied:  510
#
# Root node processing (before b&c):
#   Real time             =    0.13 sec. (1.98 ticks)
# Sequential b&c:
#   Real time             =   14.81 sec. (13842.74 ticks)
#                           ------------
# Total (root+branch&cut) =   14.94 sec. (13844.71 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_arrest>=2                                  |         1 points |   + ..... |
# | p_arrest>=7                                  |         1 points |   + ..... |
# | p_pending_charge>=1                          |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:34 PM | 1181 rows in lookup table
# 08/17/19 @ 04:34 PM | ------------------------------------------------------------
# 08/17/19 @ 04:34 PM | runnning initialization procedure
# 08/17/19 @ 04:34 PM | ------------------------------------------------------------
# 08/17/19 @ 04:34 PM | CPA produced 2 cuts
# 08/17/19 @ 04:34 PM | running naive rounding on 75 solutions
# 08/17/19 @ 04:34 PM | best objective value: 0.1809
# 08/17/19 @ 04:34 PM | rounding produced 5 integer solutions
# 08/17/19 @ 04:34 PM | best objective value is 0.1902
# 08/17/19 @ 04:34 PM | running sequential rounding on 75 solutions
# 08/17/19 @ 04:34 PM | best objective value: 0.1809
# 08/17/19 @ 04:34 PM | sequential rounding produced 6 integer solutions
# 08/17/19 @ 04:34 PM | best objective value: 0.1878
# 08/17/19 @ 04:34 PM | polishing 11 solutions
# 08/17/19 @ 04:34 PM | best objective value: 0.1878
# 08/17/19 @ 04:34 PM | polishing produced 5 integer solutions
# 08/17/19 @ 04:34 PM | initialization produced 13 feasible solutions
# 08/17/19 @ 04:34 PM | best objective value: 0.1870
# 08/17/19 @ 04:34 PM | ------------------------------------------------------------
# 08/17/19 @ 04:34 PM | completed initialization procedure
# 08/17/19 @ 04:34 PM | ------------------------------------------------------------
# 08/17/19 @ 04:35 PM | 1181 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.17946928649322944
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.18704762005365944
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:35 PM | adding 249 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.1870.
# Tried aggregator 1 time.
# Reduced MIP has 29 rows, 58 columns, and 111 nonzeros.
# Reduced MIP has 27 binaries, 29 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.06 ticks)
# Probing time = 0.00 sec. (0.02 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.04 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.1870        0.1695             9.40%
#       0     0        0.1795     1        0.1870        0.1795        1    4.05%
#       0     0        0.1795     1        0.1870       Cuts: 2        4    4.05%
#       0     0        0.1795     1        0.1870      Fract: 1        5    4.05%
#       0     2        0.1795     2        0.1870        0.1795        5    4.05%                        0             0
# Elapsed time = 0.11 sec. (1.99 ticks, tree = 0.01 MB, solutions = 1)
#    1930   818        0.1798    11        0.1870        0.1795    11907    4.05%           rho_4 U   1930   1929     23
#    3042  1270        0.1825    12        0.1870        0.1795    19926    4.05%          rho_14 U   3042   1381     18
#    4003  1645        0.1849     8        0.1870        0.1795    27331    4.05%          rho_15 D   4003   4001     25
#    4953  2056        0.1796    23        0.1870        0.1795    33679    4.05%           rho_0 U   4953   4952     10
#    5795  2430        0.1859     4        0.1870        0.1795    39654    4.03%         L0_norm U   5795   5794     23
#    6701  2766        0.1832     8        0.1870        0.1798    45135    3.88%         L0_norm U   6701   6700     16
# *  6865  2798      integral     0        0.1870        0.1798    45937    3.85%
#    7581  3060        0.1850     9        0.1870        0.1800    50252    3.77%          rho_24 U   7581   7580     17
#    8439  3326        0.1859     2        0.1870        0.1802    55375    3.63%          rho_14 U   8439   4569     13
#    9280  3629        0.1858     2        0.1870        0.1805    60279    3.51%         L0_norm D   9280   9278     23
# * 10743  4012      integral     0        0.1868        0.1808    68666    3.22%
#   12559  4510        0.1860     5        0.1868        0.1812    79579    3.00%           rho_9 D  12559  12557     25
# Elapsed time = 5.41 sec. (3103.30 ticks, tree = 1.40 MB, solutions = 3)
#   15639  5336        0.1867     4        0.1868        0.1817    98158    2.73%           rho_9 D  15639  15637     25
#   18621  5976        0.1838    12        0.1868        0.1822   115072    2.49%          rho_13 D  18621  18620     16
#   21239  6444        0.1849    14        0.1868        0.1826   130424    2.27%           rho_5 D  21239  12950     18
#   23905  6776        0.1852    13        0.1868        0.1829   145986    2.07%          rho_15 U  23905  23904     21
#   26481  7052        0.1866     7        0.1868        0.1833   160582    1.90%           rho_2 D  26481  26480     24
#   29047  7221        0.1853    20        0.1868        0.1836   175328    1.73%         L0_norm U  29047  29045     19
#   31532  7264        cutoff              0.1868        0.1839   189516    1.57%         L0_norm D  31532  31530     29
#   34011  7240        0.1863    16        0.1868        0.1842   202850    1.42%           rho_5 D  34011   2816     23
#   36396  7085        cutoff              0.1868        0.1844   215916    1.28%          rho_16 U  36396  29204     22
#   38660  6766        0.1861    14        0.1868        0.1847   228559    1.14%         L0_norm U  38660  38659     26
# Elapsed time = 15.98 sec. (12642.33 ticks, tree = 2.08 MB, solutions = 3)
#   40972  6333        cutoff              0.1868        0.1849   240570    1.01%         L0_norm D  40972  40970     19
#   43181  5666        cutoff              0.1868        0.1852   251903    0.87%         L0_norm D  43181  43179     26
#   45378  4804        0.1860    13        0.1868        0.1854   262985    0.74%           rho_0 D  45378  10125     25
#   47537  3724        0.1863     8        0.1868        0.1857   273409    0.59%           rho_3 N  47537  22651     27
#   49649  2320        cutoff              0.1868        0.1860   282716    0.43%          rho_17 U  49649  49648     23
#   51775   478        cutoff              0.1868        0.1866   290118    0.13%           rho_0 D  51775  37013     26
#
# Implied bound cuts applied:  1
# Gomory fractional cuts applied:  1
# User cuts applied:  544
#
# Root node processing (before b&c):
#   Real time             =    0.11 sec. (2.03 ticks)
# Sequential b&c:
#   Real time             =   20.48 sec. (18571.31 ticks)
#                           ------------
# Total (root+branch&cut) =   20.59 sec. (18573.34 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_arrest>=2                                  |         1 points |   + ..... |
# | p_arrest>=7                                  |         1 points |   + ..... |
# | p_pending_charge>=1                          |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# setting c0 = 0.0 to ensure that intercept is not penalized
# 08/17/19 @ 04:35 PM | 1181 rows in lookup table
# 08/17/19 @ 04:35 PM | ------------------------------------------------------------
# 08/17/19 @ 04:35 PM | runnning initialization procedure
# 08/17/19 @ 04:35 PM | ------------------------------------------------------------
# 08/17/19 @ 04:35 PM | CPA produced 2 cuts
# 08/17/19 @ 04:35 PM | running naive rounding on 85 solutions
# 08/17/19 @ 04:35 PM | best objective value: 0.1820
# 08/17/19 @ 04:35 PM | rounding produced 5 integer solutions
# 08/17/19 @ 04:35 PM | best objective value is 0.1886
# 08/17/19 @ 04:35 PM | running sequential rounding on 85 solutions
# 08/17/19 @ 04:35 PM | best objective value: 0.1820
# 08/17/19 @ 04:35 PM | sequential rounding produced 6 integer solutions
# 08/17/19 @ 04:35 PM | best objective value: 0.1883
# 08/17/19 @ 04:35 PM | polishing 11 solutions
# 08/17/19 @ 04:35 PM | best objective value: 0.1883
# 08/17/19 @ 04:35 PM | polishing produced 5 integer solutions
# 08/17/19 @ 04:35 PM | initialization produced 11 feasible solutions
# 08/17/19 @ 04:35 PM | best objective value: 0.1883
# 08/17/19 @ 04:35 PM | ------------------------------------------------------------
# 08/17/19 @ 04:35 PM | completed initialization procedure
# 08/17/19 @ 04:35 PM | ------------------------------------------------------------
# 08/17/19 @ 04:35 PM | 1181 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               200
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.18077197851164187
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.18825958966032083
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 08/17/19 @ 04:35 PM | adding 250 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.1883.
# Tried aggregator 1 time.
# Reduced MIP has 29 rows, 58 columns, and 111 nonzeros.
# Reduced MIP has 27 binaries, 29 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.06 ticks)
# Probing time = 0.00 sec. (0.02 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.04 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.1883        0.1708             9.29%
#       0     0        0.1808     1        0.1883        0.1808        1    3.98%
#       0     0        0.1808     1        0.1883       Cuts: 2        4    3.98%
#       0     0        0.1808     1        0.1883      Fract: 1        5    3.98%
#       0     2        0.1808     2        0.1883        0.1808        5    3.98%                        0             0
# Elapsed time = 0.13 sec. (1.99 ticks, tree = 0.01 MB, solutions = 1)
#    2165   989        cutoff              0.1883        0.1808    11657    3.98%          rho_11 U   2165   2164     25
#    3454  1529        0.1832    10        0.1883        0.1808    19405    3.98%          rho_24 D   3454   3453     10
#    4366  1913        0.1858     8        0.1883        0.1808    26413    3.98%           rho_2 D   4366   4364     25
#    5293  2271        0.1816    16        0.1883        0.1808    32246    3.98%          rho_14 U   5293   1601     11
#    6076  2552        0.1862    13        0.1883        0.1808    37754    3.98%          rho_17 U   6076   6075     18
#    6808  2855        cutoff              0.1883        0.1808    43070    3.98%          rho_24 U   6808   6807     17
#    7464  3155        cutoff              0.1883        0.1808    48566    3.98%           rho_3 U   7464   7463     23
#    8132  3463        0.1819    21        0.1883        0.1808    54008    3.97%           rho_4 D   8132   8131     15
#    8925  3764        0.1874    10        0.1883        0.1811    58466    3.83%          rho_13 N   8925   8924     31
#   12067  4702        0.1842    15        0.1883        0.1818    76519    3.45%           rho_1 U  12067   7478     19
# Elapsed time = 4.03 sec. (3103.24 ticks, tree = 1.43 MB, solutions = 1)
#   15032  5496        0.1853    19        0.1883        0.1823    93854    3.16%           rho_4 D  15032  15030     14
#   17878  6159        0.1876     5        0.1883        0.1828   109709    2.90%           rho_8 N  17878  17877     24
#   20494  6671        0.1871     9        0.1883        0.1832   124771    2.69%           rho_3 D  20494  20492     27
#   23014  7079        0.1862    12        0.1883        0.1836   138861    2.49%          rho_24 D  23014  23013     22
#   25377  7385        cutoff              0.1883        0.1839   152064    2.31%           rho_3 U  25377   7913     22
# * 27287  7507      integral     0        0.1881        0.1841   162312    2.13%
#   27733  7530        0.1874    11        0.1881        0.1842   164650    2.10%          rho_23 N  27733  27732     17
#   29971  7632        0.1862     5        0.1881        0.1845   177060    1.95%          rho_27 D  29971  29969     26
#   32207  7703        0.1850    14        0.1881        0.1847   189037    1.81%          rho_16 D  32207  28454     20
#   34426  7742        cutoff              0.1881        0.1850   200813    1.69%          rho_14 D  34426  34425     23
#   36603  7672        0.1881    12        0.1881        0.1852   212319    1.56%           rho_1 N  36603   3479     20
# Elapsed time = 11.86 sec. (12642.57 ticks, tree = 2.30 MB, solutions = 2)
#   38739  7613        0.1878     6        0.1881        0.1854   223312    1.44%          rho_22 D  38739  38737     27
#   40872  7344        0.1878     7        0.1881        0.1857   233805    1.31%           rho_0 N  40872  40871     30
#   42969  7043        0.1874    12        0.1881        0.1859   244331    1.19%           rho_3 N  42969  42968     21
#   45090  6630        0.1870     9        0.1881        0.1861   254043    1.08%           rho_7 D  45090  30612     28
#   47143  6095        0.1875     7        0.1881        0.1863   263800    0.97%          rho_13 N  47143  47142     16
#   49226  5354        cutoff              0.1881        0.1866   273161    0.83%          rho_22 U  49226  41612     22
#   51330  4373        cutoff              0.1881        0.1868   281953    0.69%          rho_25 U  51330  51329     30
#   53429  3048        0.1874     9        0.1881        0.1872   290013    0.51%          rho_22 D  53429  53428     27
# * 53961  2453      integral     0        0.1880        0.1873   291673    0.41%
#   55617   963        cutoff              0.1880        0.1877   295387    0.17%           rho_1 U  55617   6425     19
#
# Implied bound cuts applied:  3
# Gomory fractional cuts applied:  1
# User cuts applied:  554
#
# Root node processing (before b&c):
#   Real time             =    0.13 sec. (2.04 ticks)
# Sequential b&c:
#   Real time             =   21.91 sec. (21634.55 ticks)
#                           ------------
# Total (root+branch&cut) =   22.03 sec. (21636.59 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_arrest>=2                                  |         1 points |   + ..... |
# | p_arrest>=7                                  |         1 points |   + ..... |
# | p_pending_charge>=1                          |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 3                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+

# %%
np.mean(train_auc), np.mean(test_auc)
# Out:
# (0.7070619447554798, 0.7069725901402546)

# %% [markdown]
# ### Save Results

# %%
#log model results to the model performance folder, as per standards
path = "C:\\Users\\binha\\Documents\\Duke\\Cynthia Research\\KY-analysis-mytrials\\KY Recidivism\\KY Results\\Models\\Six Month\\"                   
results = [["Misdemeanor", np.mean(train_auc), np.std(train_auc), np.mean(test_auc), np.std(test_auc)]]

with open(path + 'Six Month RiskSLIM.csv', 'a') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(results)
