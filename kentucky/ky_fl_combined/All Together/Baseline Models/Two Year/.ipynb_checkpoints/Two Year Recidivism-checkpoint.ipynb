# %%
import os 
os.chdir('../../')
print("Current working directory is now: ", os.getcwd())

import pandas as pd
import numpy as np
import csv
import together_utils.baseline_functions as base
import together_utils.interpretable_functions as interpret

# restore saved variables
# %store -r summary_general2_ky_fl
# Out:
# Current working directory is now:  C:\Users\binha\Documents\Duke\Cynthia Research\psa-analysis - test2\kentucky\interpretable\ky_fl_combined\All Together
# C:\Users\binha\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning:
#
# The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
# no stored variable summary_general2_ky_fl

# %%
LogisticRegression?

# %%
data = pd.read_csv("C:/Users/Bin Han/Documents/cynthia/combined data")
x = data.loc[:,:'current_violence']
y = data['recid_two_year']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-417c753a638e> in <module>
# ----> 1 data = pd.read_csv("C:/Users/Bin Han/Documents/cynthia/combined data")
#       2 x = data.loc[:,:'current_violence']
#       3 y = data['recid_two_year']
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1904         kwds["usecols"] = self.usecols
#    1905
# -> 1906         self._reader = parsers.TextReader(src, **kwds)
#    1907         self.unnamed_cols = self._reader.unnamed_cols
#    1908
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'C:/Users/Bin Han/Documents/cynthia/combined data' does not exist: b'C:/Users/Bin Han/Documents/cynthia/combined data'

# %% [markdown]
# ### Model

# %%
#### Logistic
c = [1e-4, 1e-3, 1e-2, 1e-1]
logistic_summary = base.Logistic(X=x,
                                 Y=y,
                                 C=c,
                                 seed=816)

#### Lasso
c = [1e-4, 1e-3, 1e-2, 1e-1]
lasso_summary = base.Lasso(X=x,
                           Y=y, 
                           C=c,
                           seed=816)

#### LinearSVM
c = [1e-4, 1e-3, 1e-2, 1e-1]
svm_summary = base.LinearSVM(X=x,
                             Y=y,
                             C=c,
                             seed=816)

#### Random Forest
n_estimators =  [40,50]
depth = [9,10]
rf_summary = base.RF(X=x,
                     Y=y,
                     depth=depth, 
                     estimators=n_estimators, 
                     seed=816)

#### XGBoost
learning_rate = [0.05]
depth = [7]
n_estimators = [200]
xgb_summary = base.XGB(X=x,
                       Y=y,
                       learning_rate=learning_rate, 
                       depth=depth, 
                       estimators=n_estimators, 
                       seed=816)

#### save results
summary_general2_ky_fl = {"Logistic": logistic_summary,
                         "Lasso": lasso_summary,
                         "LinearSVM": svm_summary,
                         "RF": rf_summary,
                         "XGBoost": xgb_summary}
# %store summary_general2_ky_fl
# Out:
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# C:\Users\Bin Han\Documents\cynthia\psa-analysis - test\kentucky\models\ky_fl_combined\utils\model_selection.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   fl_test_x['y'] = fl_test_y  ## add response to covariates
# Stored 'summary_general2_ky_fl' (dict)

# %%
svm_summary['combined_holdout_auc'], svm_summary['ky_holdout_auc'], svm_summary['fl_holdout_auc']
# Out:
# ([0.7109292284259551,
#   0.7126047604261212,
#   0.7141353595233897,
#   0.7082579322189055,
#   0.7147293327199509],
#  [0.6840446827772186,
#   0.6855395004101106,
#   0.6827657666966065,
#   0.6802866493331503,
#   0.6860959845879069],
#  [0.6821443094261105,
#   0.682461171226836,
#   0.6829332953099172,
#   0.6824252602227538,
#   0.6822383117603257])

# %%
summary_general2_ky_fl
# Out:
# {'Logistic': {'best_param': [{'C': 0.1},
#    {'C': 0.1},
#    {'C': 0.1},
#    {'C': 0.1},
#    {'C': 0.1}],
#   'combined_holdout_auc': [0.7113351827500592,
#    0.7128101020511919,
#    0.714524935332123,
#    0.708472044475607,
#    0.7150660402842368],
#   'ky_holdout_auc': [0.6843305814800733,
#    0.6859592468986111,
#    0.6828455757069232,
#    0.6803592843127739,
#    0.686287984647383],
#   'fl_holdout_auc': [0.6825530611490465,
#    0.6827928199115956,
#    0.6833737332129259,
#    0.6829375201339268,
#    0.6826766372513295],
#   'auc_diffs': [0.00021310393456064336,
#    0.00024243056513895134,
#    0.00018713441601192482,
#    0.00022768861429056653,
#    0.00023624446029668622],
#   'fairness_overview': []},
#  'Lasso': {'best_param': [{'C': 0.1},
#    {'C': 0.1},
#    {'C': 0.1},
#    {'C': 0.1},
#    {'C': 0.1}],
#   'combined_holdout_auc': [0.7113684102698216,
#    0.7128128736462961,
#    0.7145495425586592,
#    0.7084964269491217,
#    0.7150447314752961],
#   'ky_holdout_auc': [0.6843063343599444,
#    0.6859239446573009,
#    0.6828629303797624,
#    0.6803538603889693,
#    0.6862580887477112],
#   'fl_holdout_auc': [0.6826343890112327,
#    0.6828318995336851,
#    0.683431824543059,
#    0.6829903304340479,
#    0.6826692438093126],
#   'auc_diffs': [0.0002147990966755442,
#    0.00024289394813425957,
#    0.00019081638405726853,
#    0.00022463839739661484,
#    0.00023374687512511816],
#   'fairness_overview': []},
#  'LinearSVM': {'best_param': [{'C': 0.001},
#    {'C': 0.001},
#    {'C': 0.001},
#    {'C': 0.001},
#    {'C': 0.001}],
#   'combined_holdout_auc': [0.7109292284259551,
#    0.7126047604261212,
#    0.7141353595233897,
#    0.7082579322189055,
#    0.7147293327199509],
#   'ky_holdout_auc': [0.6840446827772186,
#    0.6855395004101106,
#    0.6827657666966065,
#    0.6802866493331503,
#    0.6860959845879069],
#   'fl_holdout_auc': [0.6821443094261105,
#    0.682461171226836,
#    0.6829332953099172,
#    0.6824252602227538,
#    0.6822383117603257],
#   'auc_diffs': [0.00022183093116912023,
#    0.00022989293743780337,
#    0.00017473801790801602,
#    0.00019944686590922522,
#    0.00024216822352751688],
#   'fairness_overview': []},
#  'RF': {'best_param': [{'max_depth': 10, 'n_estimators': 50},
#    {'max_depth': 10, 'n_estimators': 50},
#    {'max_depth': 10, 'n_estimators': 50},
#    {'max_depth': 10, 'n_estimators': 50},
#    {'max_depth': 10, 'n_estimators': 40}],
#   'combined_holdout_auc': [0.845189511532094,
#    0.8478135788632726,
#    0.8477551202685247,
#    0.8475435466063945,
#    0.846123459017027],
#   'ky_holdout_auc': [0.7223963455987739,
#    0.7260269684042929,
#    0.7240265635012921,
#    0.7189846027043012,
#    0.7207595584307234],
#   'fl_holdout_auc': [0.9505389291127341,
#    0.9512127885422772,
#    0.9505114677566712,
#    0.9514483224808166,
#    0.9519912123660599],
#   'auc_diffs': [0.004563692429980781,
#    0.004723759821547491,
#    0.004642219723783869,
#    0.004668642781616605,
#    0.004814665328983558],
#   'fairness_overview': []},
#  'XGBoost': {'best_param': [{'learning_rate': 0.05,
#     'max_depth': 7,
#     'n_estimators': 200},
#    {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 200},
#    {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 200},
#    {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 200},
#    {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 200}],
#   'combined_holdout_auc': [0.8852278092607592,
#    0.8883587274382125,
#    0.8890110789278202,
#    0.888329575144463,
#    0.8830700041864581],
#   'ky_holdout_auc': [0.7280760888093706,
#    0.7330456963734435,
#    0.7294247188078512,
#    0.7295068528877307,
#    0.727434593923118],
#   'fl_holdout_auc': [0.9840106254323842,
#    0.9865629472372291,
#    0.9870128909942594,
#    0.9858706042026436,
#    0.9837064381036879],
#   'auc_diffs': [0.004209796128216925,
#    0.004224583057959919,
#    0.004364938983287825,
#    0.00445555945435161,
#    0.0043656087682550915],
#   'fairness_overview': []}}

# %%
combined_results = [np.mean(logistic_summary['combined_holdout_auc']), 
                    np.mean(lasso_summary['combined_holdout_auc']), 
                    np.mean(svm_summary['combined_holdout_auc']), 
                    np.mean(rf_summary['combined_holdout_auc']), 
                    np.mean(xgb_summary['combined_holdout_auc'])]

# %%
ky_results = [np.mean(logistic_summary['ky_holdout_auc']), 
                    np.mean(lasso_summary['ky_holdout_auc']), 
                    np.mean(svm_summary['ky_holdout_auc']), 
                    np.mean(rf_summary['ky_holdout_auc']), 
                    np.mean(xgb_summary['ky_holdout_auc'])]

# %%
gl_results = [np.mean(logistic_summary['fl_holdout_auc']), 
                    np.mean(lasso_summary['fl_holdout_auc']), 
                    np.mean(svm_summary['fl_holdout_auc']), 
                    np.mean(rf_summary['fl_holdout_auc']), 
                    np.mean(xgb_summary['fl_holdout_auc'])]

# %%
path = "C:/Users/Bin Han/Documents/cynthia/combined results/two_year/"
results = [["", "Logistic", "Lasso", "Linear SVM", "Random Forest", "XGBoost"],
           ["General", np.str((round(np.mean(logistic_summary['combined_holdout_auc']), 3))) + " (" + np.str(round(np.std(logistic_summary['combined_holdout_auc']), 3)) + ")", 
            np.str(round(np.mean(lasso_summary['combined_holdout_auc']),3)) + " (" + np.str(round(np.std(lasso_summary['combined_holdout_auc']), 3)) + ")", 
            np.str(round(np.mean(svm_summary['combined_holdout_auc']),3)) + " (" + np.str(round(np.std(svm_summary['combined_holdout_auc']), 3)) + ")", 
            np.str(round(np.mean(rf_summary['combined_holdout_auc']),3)) + " (" + np.str(round(np.std(rf_summary['combined_holdout_auc']), 3)) + ")", 
            np.str(round(np.mean(xgb_summary['combined_holdout_auc']),3)) + " (" + np.str(round(np.std(xgb_summary['combined_holdout_auc']), 3)) + ")"]]
with open(path + 'Combined Holdout Summary.csv', 'w') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(results)

# %%
path = "C:/Users/Bin Han/Documents/cynthia/combined results/two_year/"
results = [["", "Logistic", "Lasso", "Linear SVM", "Random Forest", "XGBoost"],
           ["General", np.str((round(np.mean(logistic_summary['ky_holdout_auc']), 3))) + " (" + np.str(round(np.std(logistic_summary['ky_holdout_auc']), 3)) + ")", 
            np.str(round(np.mean(lasso_summary['ky_holdout_auc']),3)) + " (" + np.str(round(np.std(lasso_summary['ky_holdout_auc']), 3)) + ")", 
            np.str(round(np.mean(svm_summary['ky_holdout_auc']),3)) + " (" + np.str(round(np.std(svm_summary['ky_holdout_auc']), 3)) + ")", 
            np.str(round(np.mean(rf_summary['ky_holdout_auc']),3)) + " (" + np.str(round(np.std(rf_summary['ky_holdout_auc']), 3)) + ")", 
            np.str(round(np.mean(xgb_summary['ky_holdout_auc']),3)) + " (" + np.str(round(np.std(xgb_summary['ky_holdout_auc']), 3)) + ")"]]
with open(path + 'KY Holdout Summary.csv', 'w') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(results)

# %%
path = "C:/Users/Bin Han/Documents/cynthia/combined results/two_year/"
results = [["", "Logistic", "Lasso", "Linear SVM", "Random Forest", "XGBoost"],
           ["General", np.str((round(np.mean(logistic_summary['fl_holdout_auc']), 3))) + " (" + np.str(round(np.std(logistic_summary['fl_holdout_auc']), 3)) + ")", 
            np.str(round(np.mean(lasso_summary['fl_holdout_auc']),3)) + " (" + np.str(round(np.std(lasso_summary['fl_holdout_auc']), 3)) + ")", 
            np.str(round(np.mean(svm_summary['fl_holdout_auc']),3)) + " (" + np.str(round(np.std(svm_summary['fl_holdout_auc']), 3)) + ")", 
            np.str(round(np.mean(rf_summary['fl_holdout_auc']),3)) + " (" + np.str(round(np.std(rf_summary['fl_holdout_auc']), 3)) + ")", 
            np.str(round(np.mean(xgb_summary['fl_holdout_auc']),3)) + " (" + np.str(round(np.std(xgb_summary['fl_holdout_auc']), 3)) + ")"]]
with open(path + 'FL Holdout Summary.csv', 'w') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(results)
